# %%
import numpy as np

# import vunet
# import vunet_simple as vunet
import vunet_1 as vunet

import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
from keras import backend as K
from keras.layers import Input
from keras.models import Model
from keras.optimizers import Adam

import h5py
import datetime
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.set_cmap('jet')

# %%
import tensorflow as tf
from keras import backend as K

# tf.session specification
# TensorFlow wizardry
config = tf.ConfigProto()

# Don't pre-allocate memory; allocate as-needed
config.gpu_options.allow_growth = True

# Only allow a total of half the GPU memory to be allocated
config.gpu_options.per_process_gpu_memory_fraction = 0.85

# Create a session with the above options specified.
K.tensorflow_backend.set_session(tf.Session(config=config))

# %% [markdown]
# #### Load/select data

# %%
model_string = 'vunet'
output_dir = 'saved_models/'
case_string = 'horizontal_16w'
data_dir = '/data/cees/zjin/cs231n/project/var-unet/data/'

# %%
# hf_r = h5py.File(data_dir + case_string + '.hdf5', 'r')
hf_r = h5py.File(data_dir + case_string + '_aug.hdf5', 'r') # augmented data
data_train = np.array(hf_r.get('data_train'))
data_eval = np.array(hf_r.get('data_eval'))
hf_r.close()

print(data_train.shape)
print(data_eval.shape)
# Out:
# (800, 128, 128, 3, 2)
# (200, 128, 128, 3, 2)

# %%
n_trial_data = 800
data_train_trial = data_train[:n_trial_data,...]
print(data_train_trial.shape)


n_eval_data = 200
data_eval_trial = data_eval[:n_eval_data,...]
print(data_eval_trial.shape)
# Out:
# (800, 128, 128, 3, 2)
# (200, 128, 128, 3, 2)

# %% [markdown]
# #### Visualize input data

# %%
for k in range (1):
    plt.figure(figsize=(12, 6))
    #
    plt.subplot(2,3,1)
    plt.imshow(data_train_trial[k,...,0, 0])
    plt.title('w')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,3,2)
    plt.imshow(data_train_trial[k,...,1, 0])
    plt.title('S')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,3,3)
    plt.imshow(data_train_trial[k,...,2, 0])
    plt.title('p')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,3,4)
    plt.imshow(data_train_trial[k,...,0, 1])
    plt.title('$w^{\prime}$')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,3,5)
    plt.imshow(data_train_trial[k,...,1, 1])
    plt.title('$S^{\prime}$')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,3,6)
    plt.imshow(data_train_trial[k,...,2, 1])
    plt.title('$p^{\prime}$')
    plt.colorbar(fraction=0.046)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Re-organize data

# %%
# data_train_trial shape (?, 128, 128, 3, 2)
train_x_y_hat0 = data_train_trial[..., 0]# xc
train_y_hat0 = data_train_trial[..., [0], 1] #c
train_x_hat0 = data_train_trial[..., 1:, 1] # x

print(train_x_y_hat0.shape)
print(train_y_hat0.shape)
print(train_x_hat0.shape)

eval_x_y_hat0 = data_eval_trial[..., 0]# xc
eval_y_hat0 = data_eval_trial[..., [0], 1] #c
eval_x_hat0 = data_eval_trial[..., 1:, 1] # x

print(eval_x_y_hat0.shape)
print(eval_y_hat0.shape)
print(eval_x_hat0.shape)

# eval_x_y_hat0, eval_y_hat0, eval_x_hat0
# Out:
# (800, 128, 128, 3)
# (800, 128, 128, 1)
# (800, 128, 128, 2)
# (200, 128, 128, 3)
# (200, 128, 128, 1)
# (200, 128, 128, 2)

# %% [markdown]
# #### Train forward pass v-unet

# %%
input_shape = (128, 128, 3) # [S,p,w], the old saturation, pressure and well location
w_shape = (128, 128, 1) # [w'], the new well location and injection/production time
output_shape = (128, 128, 2) # [S', p'], the new saturation and pressure

# %% [markdown]
# reload if necessary

# %%
# from importlib import reload
# reload(vunet)
# Out:
# <module 'vunet_1' from '/data/cees/zjin/cs231n/project/var-unet/vunet_1.py'>

# %%
# change the role of enc_up and dec_up
# model specifications
n_res_block = 1
n_low_res = 6
n_scales = 5

enc_up, hidden_shapes = vunet.create_enc_up(w_shape, n_scales = n_scales)
enc_down = vunet.create_enc_down(hidden_shapes[-1])
dec_up = vunet.create_dec_up(input_shape, n_scales = n_scales) # only c input
dec_down = vunet.create_dec_down(hidden_shapes, hidden_shapes[-1], output_shape, n_scales = n_scales,  n_low_res = n_low_res)

# %%
# save inital weights
enc_up.save_weights(output_dir + 'enc_up_init_' + case_string + '.h5' )
enc_down.save_weights(output_dir + 'enc_down_init_' + case_string + '.h5' )
dec_up.save_weights(output_dir + 'dec_up_init_' + case_string + '.h5' )
dec_down.save_weights(output_dir + 'dec_down_init_' + case_string + '.h5' )

# %%
xc = Input(shape=input_shape) # perm + well location
c = Input(shape=w_shape) # well location

hs = enc_up(c)
z_posterior_sample, z_posterior_mean = enc_down(hs[-1])
gs = dec_up(xc)
x_hat, z_piror_sample, z_piror_mean = dec_down([z_posterior_mean, *gs])

# %%
def likelihood_loss(x, x_hat):
    '''
    Reconstruction loss, L2 norm
    
    '''
    v = 0.1
    return K.mean(K.sum((K.batch_flatten(x) - K.batch_flatten(x_hat)) ** 2 / (2*v), axis=-1))

def latent_kl_loss(q, p):
    mean1 = q
    mean2 = p
    
    kl = 0.5 * (mean2 - mean1)**2
    kl = K.sum(kl, axis = [1,2,3])
    kl = K.mean(kl)
    return kl

# %%
x = Input(shape=output_shape) # target saturation, pressure

likelihood_loss_value = likelihood_loss(x, x_hat)
kl_loss = latent_kl_loss(z_posterior_mean, z_piror_mean)
kl_weight = 5.0
total_loss = likelihood_loss_value + kl_weight * kl_loss

# %% [markdown]
# ## Re-train start here

# %%
epoch = 100
learning_rate = 5e-4 # default 1e-3
decay = 1e-5 # default 1e-5
train_nr = data_train_trial.shape[0]
eval_nr = data_eval_trial.shape[0]

print('train_nr: ', train_nr)
print('eval_nr: ', eval_nr)

batch_size = 16
num_batch = int(train_nr/batch_size)
# Out:
# train_nr:  800
# eval_nr:  200

# %%
# in case of re-training, load initial weights
enc_up.load_weights(output_dir + 'enc_up_init_' + case_string + '.h5')
enc_down.load_weights(output_dir + 'enc_down_init_' + case_string + '.h5')
dec_up.load_weights(output_dir + 'dec_up_init_' + case_string + '.h5')
dec_down.load_weights(output_dir + 'dec_down_init_' + case_string + '.h5')

# %%
opt = Adam(lr=learning_rate, decay=decay)

trainable_weights = enc_up.trainable_weights + enc_down.trainable_weights + dec_up.trainable_weights + dec_down.trainable_weights

updates = opt.get_updates(total_loss, trainable_weights)

iterate = K.function([xc, c, x], [total_loss, likelihood_loss_value, kl_loss], updates=updates)

eval_loss = K.function([xc, c, x], [total_loss])

# %%
## used to generate log directory
currentDT = datetime.datetime.now()
current_time = str(currentDT).replace(" ", "-")[:-10]
print(current_time)
# Out:
# 2019-05-24-10:03

# %%
## log for tensorboard
def write_summary(value, tag, summary_writer, global_step):
    """
    Write a single summary value to tensorboard
    """
    summary = tf.Summary()
    summary.value.add(tag=tag, simple_value=value)
    summary_writer.add_summary(summary, global_step)

    
summary_writer = tf.summary.FileWriter('logs/' + model_string + '_bs%d_lr%.0e_ep%d_'%(batch_size, learning_rate, epoch)  + current_time)

# %%
for e in range(epoch):
    for ib in range(num_batch):
        ind0 = ib * batch_size
        n_itr = e * train_nr + ind0 + batch_size # for tensorboard output
        
        x_y_hat0_batch = train_x_y_hat0[ind0:ind0+batch_size, ...] #xc
        y_hat0_batch = train_y_hat0[ind0:ind0+batch_size, ...] # c: shape
        x_hat0_batch = train_x_hat0[ind0:ind0+batch_size, ...] # x
        
        train_losses = iterate([x_y_hat0_batch, y_hat0_batch, x_hat0_batch])
        ## -- K.function()
        ## -- Equivalent to:
        # train_losses = tf.session.run(feed_dict={xc: x_y_hat0_batch, c: y_hat0_batch, x: x_hat0_batch}, ...
        #                               fetches= [total_loss, likelihood_loss_value, kl_loss])
        # But output tensor for the updates operation is not returned.
        # For session.run(), the fetches should include a 'update' tensor, 
        # which is a tf operator that updates weights for each iteration.
        # Specifically, the 'update' tensor is defined as:
        # ---------------------------------
        # params = tf.trainable_variables()
        # gradients = tf.gradients(loss, params)
        # opt = tf.train.AdamOptimizer(learning_rate=FLAGS.learning_rate)
        # update = opt.apply_gradients(zip(gradients, params), global_step=global_step)
        # ---------------------------------
        # session.run() is with tf, and does not require Keras
        # K.function is a Keras API, which is more convient

        if ib % 10 == 0:
            print('Epoch %d/%d, Batch %d/%d, Total Loss %f, Likelihood Loss %f, KL Loss %f' % (e+1, epoch, ib+1, num_batch, train_losses[0], train_losses[1], train_losses[2]))
            write_summary(train_losses[0], 'train_loss', summary_writer, n_itr) # log for tensorboard
    
    eval_losses = eval_loss([eval_x_y_hat0, eval_y_hat0, eval_x_hat0])    
    write_summary(eval_losses[0], 'eval_loss', summary_writer, n_itr) # log for tensorboard
        

    print('====================================================')
    print('\n')
    print('Epoch %d/%d, Train Total Loss %f, Eval Total Loss %f' % (e + 1, epoch, train_losses[0], eval_losses[0]))
    print('\n')
    print('====================================================')

    
enc_up.save_weights(output_dir + 'enc_up_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
enc_down.save_weights(output_dir + 'enc_down_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
dec_up.save_weights(output_dir + 'dec_up_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
dec_down.save_weights(output_dir + 'dec_down_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
# Out:
# Epoch 1/100, Batch 1/50, Total Loss 13351.166992, Likelihood Loss 13301.279297, KL Loss 9.977544
# Epoch 1/100, Batch 11/50, Total Loss 3720.962158, Likelihood Loss 3713.683350, KL Loss 1.455781
# Epoch 1/100, Batch 21/50, Total Loss 3253.525879, Likelihood Loss 3247.934082, KL Loss 1.118353
# Epoch 1/100, Batch 31/50, Total Loss 3343.397949, Likelihood Loss 3339.767578, KL Loss 0.726074
# Epoch 1/100, Batch 41/50, Total Loss 2991.062256, Likelihood Loss 2987.769287, KL Loss 0.658572
# ====================================================
#
#
# Epoch 1/100, Train Total Loss 3076.359375, Eval Total Loss 2762.875488
#
#
# ====================================================
# Epoch 2/100, Batch 1/50, Total Loss 2919.188232, Likelihood Loss 2915.805420, KL Loss 0.676565
# Epoch 2/100, Batch 11/50, Total Loss 2567.682129, Likelihood Loss 2564.685059, KL Loss 0.599425
# Epoch 2/100, Batch 21/50, Total Loss 2624.314453, Likelihood Loss 2620.461670, KL Loss 0.770565
# Epoch 2/100, Batch 31/50, Total Loss 2921.577881, Likelihood Loss 2917.731201, KL Loss 0.769349
# Epoch 2/100, Batch 41/50, Total Loss 2551.718262, Likelihood Loss 2548.094238, KL Loss 0.724798
# ====================================================
#
#
# Epoch 2/100, Train Total Loss 2616.854248, Eval Total Loss 2470.105957
#
#
# ====================================================
# Epoch 3/100, Batch 1/50, Total Loss 2610.415283, Likelihood Loss 2605.905762, KL Loss 0.901928
# Epoch 3/100, Batch 11/50, Total Loss 2474.011963, Likelihood Loss 2469.524658, KL Loss 0.897475
# Epoch 3/100, Batch 21/50, Total Loss 2631.073486, Likelihood Loss 2625.350342, KL Loss 1.144611
# Epoch 3/100, Batch 31/50, Total Loss 2839.515381, Likelihood Loss 2834.049072, KL Loss 1.093278
# Epoch 3/100, Batch 41/50, Total Loss 2449.537109, Likelihood Loss 2445.910645, KL Loss 0.725303
# ====================================================
#
#
# Epoch 3/100, Train Total Loss 2541.315918, Eval Total Loss 2424.979980
#
#
# ====================================================
# Epoch 4/100, Batch 1/50, Total Loss 2593.624512, Likelihood Loss 2590.178711, KL Loss 0.689175
# Epoch 4/100, Batch 11/50, Total Loss 2302.656494, Likelihood Loss 2299.457520, KL Loss 0.639802
# Epoch 4/100, Batch 21/50, Total Loss 2524.834961, Likelihood Loss 2521.768555, KL Loss 0.613277
# Epoch 4/100, Batch 31/50, Total Loss 2795.290283, Likelihood Loss 2791.998047, KL Loss 0.658447
# Epoch 4/100, Batch 41/50, Total Loss 2451.539795, Likelihood Loss 2448.795410, KL Loss 0.548901
# ====================================================
#
#
# Epoch 4/100, Train Total Loss 2497.958984, Eval Total Loss 2398.774414
#
#
# ====================================================
# Epoch 5/100, Batch 1/50, Total Loss 2578.283203, Likelihood Loss 2575.329102, KL Loss 0.590832
# Epoch 5/100, Batch 11/50, Total Loss 2291.358887, Likelihood Loss 2288.128174, KL Loss 0.646118
# Epoch 5/100, Batch 21/50, Total Loss 2506.311768, Likelihood Loss 2503.074707, KL Loss 0.647410
# Epoch 5/100, Batch 31/50, Total Loss 2440.928711, Likelihood Loss 2436.221191, KL Loss 0.941524
# Epoch 5/100, Batch 41/50, Total Loss 2302.621582, Likelihood Loss 2287.474609, KL Loss 3.029402
# ====================================================
#
#
# Epoch 5/100, Train Total Loss 2230.859375, Eval Total Loss 2393.264160
#
#
# ====================================================
# Epoch 6/100, Batch 1/50, Total Loss 2566.717285, Likelihood Loss 2547.950195, KL Loss 3.753402
# Epoch 6/100, Batch 11/50, Total Loss 1967.468872, Likelihood Loss 1948.209229, KL Loss 3.851928
# Epoch 6/100, Batch 21/50, Total Loss 2223.868164, Likelihood Loss 2202.697754, KL Loss 4.234062
# Epoch 6/100, Batch 31/50, Total Loss 1935.314819, Likelihood Loss 1917.718750, KL Loss 3.519224
# Epoch 6/100, Batch 41/50, Total Loss 1759.733154, Likelihood Loss 1741.303345, KL Loss 3.685967
# ====================================================
#
#
# Epoch 6/100, Train Total Loss 1845.643555, Eval Total Loss 1649.128052
#
#
# ====================================================
# Epoch 7/100, Batch 1/50, Total Loss 1728.873535, Likelihood Loss 1713.818604, KL Loss 3.010976
# Epoch 7/100, Batch 11/50, Total Loss 1821.282593, Likelihood Loss 1803.473877, KL Loss 3.561746
# Epoch 7/100, Batch 21/50, Total Loss 1849.172363, Likelihood Loss 1835.729004, KL Loss 2.688678
# Epoch 7/100, Batch 31/50, Total Loss 1485.662598, Likelihood Loss 1465.229126, KL Loss 4.086700
# Epoch 7/100, Batch 41/50, Total Loss 1658.630737, Likelihood Loss 1634.483643, KL Loss 4.829415
# ====================================================
#
#
# Epoch 7/100, Train Total Loss 1576.030151, Eval Total Loss 1605.036743
#
#
# ====================================================
# Epoch 8/100, Batch 1/50, Total Loss 1652.182861, Likelihood Loss 1634.852295, KL Loss 3.466120
# Epoch 8/100, Batch 11/50, Total Loss 1444.042603, Likelihood Loss 1425.656250, KL Loss 3.677268
# Epoch 8/100, Batch 21/50, Total Loss 1631.592896, Likelihood Loss 1609.899292, KL Loss 4.338709
# Epoch 8/100, Batch 31/50, Total Loss 1177.463745, Likelihood Loss 1161.583862, KL Loss 3.175968
# Epoch 8/100, Batch 41/50, Total Loss 1205.715332, Likelihood Loss 1189.898315, KL Loss 3.163399
# ====================================================
#
#
# Epoch 8/100, Train Total Loss 1231.654419, Eval Total Loss 1171.248779
#
#
# ====================================================
# Epoch 9/100, Batch 1/50, Total Loss 1181.460938, Likelihood Loss 1166.141235, KL Loss 3.063934
# Epoch 9/100, Batch 11/50, Total Loss 1093.225342, Likelihood Loss 1076.115601, KL Loss 3.421950
# Epoch 9/100, Batch 21/50, Total Loss 1184.973755, Likelihood Loss 1164.143677, KL Loss 4.166020
# Epoch 9/100, Batch 31/50, Total Loss 1417.250854, Likelihood Loss 1399.195923, KL Loss 3.610975
# Epoch 9/100, Batch 41/50, Total Loss 1004.623962, Likelihood Loss 981.814514, KL Loss 4.561893
# ====================================================
#
#
# Epoch 9/100, Train Total Loss 1006.933594, Eval Total Loss 1036.489502
#
#
# ====================================================
# Epoch 10/100, Batch 1/50, Total Loss 972.597290, Likelihood Loss 953.658691, KL Loss 3.787721
# Epoch 10/100, Batch 11/50, Total Loss 886.419128, Likelihood Loss 868.456299, KL Loss 3.592571
# Epoch 10/100, Batch 21/50, Total Loss 942.848694, Likelihood Loss 919.633789, KL Loss 4.642982
# Epoch 10/100, Batch 31/50, Total Loss 1459.435791, Likelihood Loss 1442.836670, KL Loss 3.319820
# Epoch 10/100, Batch 41/50, Total Loss 815.078918, Likelihood Loss 793.381592, KL Loss 4.339466
# ====================================================
#
#
# Epoch 10/100, Train Total Loss 1066.602295, Eval Total Loss 1038.270142
#
#
# ====================================================
# Epoch 11/100, Batch 1/50, Total Loss 994.988342, Likelihood Loss 974.118774, KL Loss 4.173914
# Epoch 11/100, Batch 11/50, Total Loss 933.597778, Likelihood Loss 914.220642, KL Loss 3.875422
# Epoch 11/100, Batch 21/50, Total Loss 781.230591, Likelihood Loss 759.059448, KL Loss 4.434226
# Epoch 11/100, Batch 31/50, Total Loss 745.908508, Likelihood Loss 728.389771, KL Loss 3.503752
# Epoch 11/100, Batch 41/50, Total Loss 733.200562, Likelihood Loss 714.242676, KL Loss 3.791579
# ====================================================
#
#
# Epoch 11/100, Train Total Loss 724.554749, Eval Total Loss 945.484619
#
#
# ====================================================
# Epoch 12/100, Batch 1/50, Total Loss 821.268188, Likelihood Loss 802.739807, KL Loss 3.705677
# Epoch 12/100, Batch 11/50, Total Loss 673.416687, Likelihood Loss 656.138306, KL Loss 3.455680
# Epoch 12/100, Batch 21/50, Total Loss 997.917542, Likelihood Loss 973.465454, KL Loss 4.890421
# Epoch 12/100, Batch 31/50, Total Loss 682.536621, Likelihood Loss 664.614868, KL Loss 3.584348
# Epoch 12/100, Batch 41/50, Total Loss 810.159729, Likelihood Loss 791.155273, KL Loss 3.800886
# ====================================================
#
#
# Epoch 12/100, Train Total Loss 852.106628, Eval Total Loss 1064.242432
#
#
# ====================================================
# Epoch 13/100, Batch 1/50, Total Loss 964.752319, Likelihood Loss 943.506042, KL Loss 4.249253
# Epoch 13/100, Batch 11/50, Total Loss 627.792114, Likelihood Loss 606.795044, KL Loss 4.199411
# Epoch 13/100, Batch 21/50, Total Loss 612.932251, Likelihood Loss 589.384277, KL Loss 4.709590
# Epoch 13/100, Batch 31/50, Total Loss 683.279419, Likelihood Loss 667.890991, KL Loss 3.077684
# Epoch 13/100, Batch 41/50, Total Loss 570.224915, Likelihood Loss 552.259216, KL Loss 3.593137
# ====================================================
#
#
# Epoch 13/100, Train Total Loss 670.491699, Eval Total Loss 838.851868
#
#
# ====================================================
# Epoch 14/100, Batch 1/50, Total Loss 733.799438, Likelihood Loss 715.325928, KL Loss 3.694707
# Epoch 14/100, Batch 11/50, Total Loss 550.431152, Likelihood Loss 533.683838, KL Loss 3.349464
# Epoch 14/100, Batch 21/50, Total Loss 665.116577, Likelihood Loss 642.062073, KL Loss 4.610898
# Epoch 14/100, Batch 31/50, Total Loss 520.728394, Likelihood Loss 504.578796, KL Loss 3.229914
# Epoch 14/100, Batch 41/50, Total Loss 529.972839, Likelihood Loss 512.294922, KL Loss 3.535582
# ====================================================
#
#
# Epoch 14/100, Train Total Loss 558.196411, Eval Total Loss 745.435608
#
#
# ====================================================
# Epoch 15/100, Batch 1/50, Total Loss 604.928406, Likelihood Loss 588.708130, KL Loss 3.244054
# Epoch 15/100, Batch 11/50, Total Loss 540.397827, Likelihood Loss 524.484680, KL Loss 3.182633
# Epoch 15/100, Batch 21/50, Total Loss 472.314117, Likelihood Loss 450.767090, KL Loss 4.309408
# Epoch 15/100, Batch 31/50, Total Loss 534.120056, Likelihood Loss 518.232056, KL Loss 3.177604
# Epoch 15/100, Batch 41/50, Total Loss 439.213013, Likelihood Loss 421.111694, KL Loss 3.620264
# ====================================================
#
#
# Epoch 15/100, Train Total Loss 469.242371, Eval Total Loss 582.725220
#
#
# ====================================================
# Epoch 16/100, Batch 1/50, Total Loss 427.802582, Likelihood Loss 412.093353, KL Loss 3.141848
# Epoch 16/100, Batch 11/50, Total Loss 449.705841, Likelihood Loss 434.346191, KL Loss 3.071932
# Epoch 16/100, Batch 21/50, Total Loss 507.501190, Likelihood Loss 486.892609, KL Loss 4.121716
# Epoch 16/100, Batch 31/50, Total Loss 408.223572, Likelihood Loss 392.383057, KL Loss 3.168100
# Epoch 16/100, Batch 41/50, Total Loss 402.108643, Likelihood Loss 386.108673, KL Loss 3.199996
# ====================================================
#
#
# Epoch 16/100, Train Total Loss 427.219818, Eval Total Loss 563.158875
#
#
# ====================================================
# Epoch 17/100, Batch 1/50, Total Loss 392.446045, Likelihood Loss 376.528320, KL Loss 3.183546
# Epoch 17/100, Batch 11/50, Total Loss 413.533234, Likelihood Loss 398.794067, KL Loss 2.947833
# Epoch 17/100, Batch 21/50, Total Loss 483.177216, Likelihood Loss 463.360474, KL Loss 3.963347
# Epoch 17/100, Batch 31/50, Total Loss 503.601257, Likelihood Loss 486.706818, KL Loss 3.378885
# Epoch 17/100, Batch 41/50, Total Loss 443.446747, Likelihood Loss 424.693909, KL Loss 3.750570
# ====================================================
#
#
# Epoch 17/100, Train Total Loss 477.330963, Eval Total Loss 573.509888
#
#
# ====================================================
# Epoch 18/100, Batch 1/50, Total Loss 411.837982, Likelihood Loss 394.343048, KL Loss 3.498989
# Epoch 18/100, Batch 11/50, Total Loss 351.849701, Likelihood Loss 336.213928, KL Loss 3.127154
# Epoch 18/100, Batch 21/50, Total Loss 562.615601, Likelihood Loss 543.330505, KL Loss 3.857019
# Epoch 18/100, Batch 31/50, Total Loss 939.439819, Likelihood Loss 922.892334, KL Loss 3.309494
# Epoch 18/100, Batch 41/50, Total Loss 548.790527, Likelihood Loss 531.120361, KL Loss 3.534035
# ====================================================
#
#
# Epoch 18/100, Train Total Loss 743.978577, Eval Total Loss 658.666626
#
#
# ====================================================
# Epoch 19/100, Batch 1/50, Total Loss 505.566040, Likelihood Loss 486.837891, KL Loss 3.745631
# Epoch 19/100, Batch 11/50, Total Loss 461.191772, Likelihood Loss 441.546722, KL Loss 3.929009
# Epoch 19/100, Batch 21/50, Total Loss 782.581116, Likelihood Loss 761.196411, KL Loss 4.276938
# Epoch 19/100, Batch 31/50, Total Loss 492.788483, Likelihood Loss 477.359955, KL Loss 3.085708
# Epoch 19/100, Batch 41/50, Total Loss 710.815552, Likelihood Loss 689.836121, KL Loss 4.195884
# ====================================================
#
#
# Epoch 19/100, Train Total Loss 449.735291, Eval Total Loss 786.716614
#
#
# ====================================================
# Epoch 20/100, Batch 1/50, Total Loss 611.897400, Likelihood Loss 591.774292, KL Loss 4.024617
# Epoch 20/100, Batch 11/50, Total Loss 429.662354, Likelihood Loss 409.459381, KL Loss 4.040593
# Epoch 20/100, Batch 21/50, Total Loss 411.212128, Likelihood Loss 392.380066, KL Loss 3.766414
# Epoch 20/100, Batch 31/50, Total Loss 385.684814, Likelihood Loss 368.421997, KL Loss 3.452567
# Epoch 20/100, Batch 41/50, Total Loss 545.652039, Likelihood Loss 528.954834, KL Loss 3.339447
# ====================================================
#
#
# Epoch 20/100, Train Total Loss 424.548645, Eval Total Loss 609.872192
#
#
# ====================================================
# Epoch 21/100, Batch 1/50, Total Loss 446.999878, Likelihood Loss 431.308502, KL Loss 3.138276
# Epoch 21/100, Batch 11/50, Total Loss 388.182037, Likelihood Loss 369.792084, KL Loss 3.677989
# Epoch 21/100, Batch 21/50, Total Loss 526.450134, Likelihood Loss 506.975281, KL Loss 3.894965
# Epoch 21/100, Batch 31/50, Total Loss 355.419159, Likelihood Loss 339.426086, KL Loss 3.198616
# Epoch 21/100, Batch 41/50, Total Loss 364.389404, Likelihood Loss 347.623474, KL Loss 3.353185
# ====================================================
#
#
# Epoch 21/100, Train Total Loss 442.451935, Eval Total Loss 520.616699
#
#
# ====================================================
# Epoch 22/100, Batch 1/50, Total Loss 365.542908, Likelihood Loss 349.338013, KL Loss 3.240980
# Epoch 22/100, Batch 11/50, Total Loss 505.535034, Likelihood Loss 487.849548, KL Loss 3.537094
# Epoch 22/100, Batch 21/50, Total Loss 416.815002, Likelihood Loss 399.640198, KL Loss 3.434963
# Epoch 22/100, Batch 31/50, Total Loss 454.932983, Likelihood Loss 439.088287, KL Loss 3.168940
# Epoch 22/100, Batch 41/50, Total Loss 333.824921, Likelihood Loss 318.125946, KL Loss 3.139797
# ====================================================
#
#
# Epoch 22/100, Train Total Loss 340.666748, Eval Total Loss 621.852600
#
#
# ====================================================
# Epoch 23/100, Batch 1/50, Total Loss 455.670319, Likelihood Loss 440.012085, KL Loss 3.131646
# Epoch 23/100, Batch 11/50, Total Loss 293.743347, Likelihood Loss 278.208191, KL Loss 3.107032
# Epoch 23/100, Batch 21/50, Total Loss 506.630859, Likelihood Loss 490.546082, KL Loss 3.216956
# Epoch 23/100, Batch 31/50, Total Loss 352.603241, Likelihood Loss 336.708221, KL Loss 3.179002
# Epoch 23/100, Batch 41/50, Total Loss 387.911072, Likelihood Loss 371.838318, KL Loss 3.214553
# ====================================================
#
#
# Epoch 23/100, Train Total Loss 395.550293, Eval Total Loss 565.941406
#
#
# ====================================================
# Epoch 24/100, Batch 1/50, Total Loss 336.072418, Likelihood Loss 321.493042, KL Loss 2.915878
# Epoch 24/100, Batch 11/50, Total Loss 312.519897, Likelihood Loss 296.967590, KL Loss 3.110463
# Epoch 24/100, Batch 21/50, Total Loss 418.129608, Likelihood Loss 402.138489, KL Loss 3.198225
# Epoch 24/100, Batch 31/50, Total Loss 308.984070, Likelihood Loss 294.435791, KL Loss 2.909658
# Epoch 24/100, Batch 41/50, Total Loss 427.271545, Likelihood Loss 410.532715, KL Loss 3.347767
# ====================================================
#
#
# Epoch 24/100, Train Total Loss 335.917633, Eval Total Loss 564.094055
#
#
# ====================================================
# Epoch 25/100, Batch 1/50, Total Loss 359.628357, Likelihood Loss 344.991852, KL Loss 2.927300
# Epoch 25/100, Batch 11/50, Total Loss 339.458099, Likelihood Loss 322.679993, KL Loss 3.355621
# Epoch 25/100, Batch 21/50, Total Loss 388.505463, Likelihood Loss 371.841675, KL Loss 3.332760
# Epoch 25/100, Batch 31/50, Total Loss 406.315002, Likelihood Loss 392.175232, KL Loss 2.827953
# Epoch 25/100, Batch 41/50, Total Loss 555.555969, Likelihood Loss 539.778687, KL Loss 3.155453
# ====================================================
#
#
# Epoch 25/100, Train Total Loss 437.048920, Eval Total Loss 523.956787
#
#
# ====================================================
# Epoch 26/100, Batch 1/50, Total Loss 373.677979, Likelihood Loss 358.210052, KL Loss 3.093585
# Epoch 26/100, Batch 11/50, Total Loss 330.434296, Likelihood Loss 311.792114, KL Loss 3.728437
# Epoch 26/100, Batch 21/50, Total Loss 319.964447, Likelihood Loss 302.059387, KL Loss 3.581012
# Epoch 26/100, Batch 31/50, Total Loss 449.675842, Likelihood Loss 436.037903, KL Loss 2.727586
# Epoch 26/100, Batch 41/50, Total Loss 348.539520, Likelihood Loss 334.518433, KL Loss 2.804216
# ====================================================
#
#
# Epoch 26/100, Train Total Loss 468.533020, Eval Total Loss 640.070679
#
#
# ====================================================
# Epoch 27/100, Batch 1/50, Total Loss 545.983398, Likelihood Loss 528.285278, KL Loss 3.539624
# Epoch 27/100, Batch 11/50, Total Loss 355.225342, Likelihood Loss 337.081360, KL Loss 3.628799
# Epoch 27/100, Batch 21/50, Total Loss 359.453400, Likelihood Loss 341.967529, KL Loss 3.497171
# Epoch 27/100, Batch 31/50, Total Loss 362.124451, Likelihood Loss 346.981689, KL Loss 3.028552
# Epoch 27/100, Batch 41/50, Total Loss 340.266846, Likelihood Loss 323.929810, KL Loss 3.267405
# ====================================================
#
#
# Epoch 27/100, Train Total Loss 397.587646, Eval Total Loss 683.973938
#
#
# ====================================================
# Epoch 28/100, Batch 1/50, Total Loss 504.382385, Likelihood Loss 487.555298, KL Loss 3.365418
# Epoch 28/100, Batch 11/50, Total Loss 365.682281, Likelihood Loss 348.335052, KL Loss 3.469446
# Epoch 28/100, Batch 21/50, Total Loss 446.256989, Likelihood Loss 428.403992, KL Loss 3.570599
# Epoch 28/100, Batch 31/50, Total Loss 389.759613, Likelihood Loss 374.244934, KL Loss 3.102936
# Epoch 28/100, Batch 41/50, Total Loss 362.221405, Likelihood Loss 344.454773, KL Loss 3.553329
# ====================================================
#
#
# Epoch 28/100, Train Total Loss 345.819489, Eval Total Loss 610.586304
#
#
# ====================================================
# Epoch 29/100, Batch 1/50, Total Loss 398.874603, Likelihood Loss 383.488464, KL Loss 3.077228
# Epoch 29/100, Batch 11/50, Total Loss 450.255768, Likelihood Loss 430.760681, KL Loss 3.899017
# Epoch 29/100, Batch 21/50, Total Loss 419.526093, Likelihood Loss 401.001678, KL Loss 3.704885
# Epoch 29/100, Batch 31/50, Total Loss 418.835938, Likelihood Loss 403.120239, KL Loss 3.143137
# Epoch 29/100, Batch 41/50, Total Loss 584.709839, Likelihood Loss 567.890442, KL Loss 3.363881
# ====================================================
#
#
# Epoch 29/100, Train Total Loss 576.144775, Eval Total Loss 594.903259
#
#
# ====================================================
# Epoch 30/100, Batch 1/50, Total Loss 493.211121, Likelihood Loss 477.032776, KL Loss 3.235670
# Epoch 30/100, Batch 11/50, Total Loss 357.174011, Likelihood Loss 340.914246, KL Loss 3.251953
# Epoch 30/100, Batch 21/50, Total Loss 384.493835, Likelihood Loss 362.615662, KL Loss 4.375634
# Epoch 30/100, Batch 31/50, Total Loss 370.603912, Likelihood Loss 353.727783, KL Loss 3.375226
# Epoch 30/100, Batch 41/50, Total Loss 377.099182, Likelihood Loss 361.273499, KL Loss 3.165134
# ====================================================
#
#
# Epoch 30/100, Train Total Loss 408.441650, Eval Total Loss 659.553833
#
#
# ====================================================
# Epoch 31/100, Batch 1/50, Total Loss 481.029572, Likelihood Loss 465.841675, KL Loss 3.037581
# Epoch 31/100, Batch 11/50, Total Loss 297.891449, Likelihood Loss 282.558655, KL Loss 3.066557
# Epoch 31/100, Batch 21/50, Total Loss 255.954193, Likelihood Loss 238.167023, KL Loss 3.557436
# Epoch 31/100, Batch 31/50, Total Loss 287.343170, Likelihood Loss 271.690369, KL Loss 3.130561
# Epoch 31/100, Batch 41/50, Total Loss 256.175598, Likelihood Loss 241.014053, KL Loss 3.032308
# ====================================================
#
#
# Epoch 31/100, Train Total Loss 314.816589, Eval Total Loss 588.324341
#
#
# ====================================================
# Epoch 32/100, Batch 1/50, Total Loss 369.999512, Likelihood Loss 356.344299, KL Loss 2.731040
# Epoch 32/100, Batch 11/50, Total Loss 258.939392, Likelihood Loss 243.301697, KL Loss 3.127539
# Epoch 32/100, Batch 21/50, Total Loss 267.028076, Likelihood Loss 252.132141, KL Loss 2.979187
# Epoch 32/100, Batch 31/50, Total Loss 259.546875, Likelihood Loss 245.534302, KL Loss 2.802517
# Epoch 32/100, Batch 41/50, Total Loss 268.432251, Likelihood Loss 253.487823, KL Loss 2.988883
# ====================================================
#
#
# Epoch 32/100, Train Total Loss 406.750336, Eval Total Loss 537.838501
#
#
# ====================================================
# Epoch 33/100, Batch 1/50, Total Loss 336.332947, Likelihood Loss 324.495209, KL Loss 2.367548
# Epoch 33/100, Batch 11/50, Total Loss 396.220551, Likelihood Loss 379.809875, KL Loss 3.282135
# Epoch 33/100, Batch 21/50, Total Loss 358.022430, Likelihood Loss 344.100708, KL Loss 2.784345
# Epoch 33/100, Batch 31/50, Total Loss 236.206192, Likelihood Loss 222.256378, KL Loss 2.789964
# Epoch 33/100, Batch 41/50, Total Loss 240.391861, Likelihood Loss 226.012405, KL Loss 2.875892
# ====================================================
#
#
# Epoch 33/100, Train Total Loss 290.969849, Eval Total Loss 554.048279
#
#
# ====================================================
# Epoch 34/100, Batch 1/50, Total Loss 360.858887, Likelihood Loss 349.471558, KL Loss 2.277467
# Epoch 34/100, Batch 11/50, Total Loss 269.451172, Likelihood Loss 254.906555, KL Loss 2.908926
# Epoch 34/100, Batch 21/50, Total Loss 286.228851, Likelihood Loss 270.362183, KL Loss 3.173331
# Epoch 34/100, Batch 31/50, Total Loss 395.090759, Likelihood Loss 383.005371, KL Loss 2.417077
# Epoch 34/100, Batch 41/50, Total Loss 303.570801, Likelihood Loss 286.965942, KL Loss 3.320970
# ====================================================
#
#
# Epoch 34/100, Train Total Loss 258.234253, Eval Total Loss 459.417633
#
#
# ====================================================
# Epoch 35/100, Batch 1/50, Total Loss 285.001160, Likelihood Loss 272.037781, KL Loss 2.592673
# Epoch 35/100, Batch 11/50, Total Loss 276.827362, Likelihood Loss 262.973633, KL Loss 2.770745
# Epoch 35/100, Batch 21/50, Total Loss 461.016907, Likelihood Loss 443.404694, KL Loss 3.522443
# Epoch 35/100, Batch 31/50, Total Loss 387.702118, Likelihood Loss 374.862640, KL Loss 2.567893
# Epoch 35/100, Batch 41/50, Total Loss 374.687195, Likelihood Loss 360.402100, KL Loss 2.857021
# ====================================================
#
#
# Epoch 35/100, Train Total Loss 281.947815, Eval Total Loss 531.595093
#
#
# ====================================================
# Epoch 36/100, Batch 1/50, Total Loss 392.916351, Likelihood Loss 377.792603, KL Loss 3.024748
# Epoch 36/100, Batch 11/50, Total Loss 234.876602, Likelihood Loss 219.899658, KL Loss 2.995389
# Epoch 36/100, Batch 21/50, Total Loss 258.225128, Likelihood Loss 242.487976, KL Loss 3.147430
# Epoch 36/100, Batch 31/50, Total Loss 261.091675, Likelihood Loss 247.600128, KL Loss 2.698312
# Epoch 36/100, Batch 41/50, Total Loss 376.780090, Likelihood Loss 363.206848, KL Loss 2.714651
# ====================================================
#
#
# Epoch 36/100, Train Total Loss 308.167175, Eval Total Loss 452.789825
#
#
# ====================================================
# Epoch 37/100, Batch 1/50, Total Loss 248.244354, Likelihood Loss 234.711426, KL Loss 2.706586
# Epoch 37/100, Batch 11/50, Total Loss 259.866669, Likelihood Loss 245.485641, KL Loss 2.876205
# Epoch 37/100, Batch 21/50, Total Loss 228.462891, Likelihood Loss 213.588287, KL Loss 2.974921
# Epoch 37/100, Batch 31/50, Total Loss 274.843689, Likelihood Loss 262.021973, KL Loss 2.564344
# Epoch 37/100, Batch 41/50, Total Loss 318.713928, Likelihood Loss 304.391357, KL Loss 2.864515
# ====================================================
#
#
# Epoch 37/100, Train Total Loss 370.460815, Eval Total Loss 502.534149
#
#
# ====================================================
# Epoch 38/100, Batch 1/50, Total Loss 283.665375, Likelihood Loss 271.139984, KL Loss 2.505076
# Epoch 38/100, Batch 11/50, Total Loss 252.591034, Likelihood Loss 237.464508, KL Loss 3.025305
# Epoch 38/100, Batch 21/50, Total Loss 309.262024, Likelihood Loss 293.964844, KL Loss 3.059439
# Epoch 38/100, Batch 31/50, Total Loss 222.086945, Likelihood Loss 207.832581, KL Loss 2.850874
# Epoch 38/100, Batch 41/50, Total Loss 400.653778, Likelihood Loss 387.607300, KL Loss 2.609294
# ====================================================
#
#
# Epoch 38/100, Train Total Loss 481.847687, Eval Total Loss 793.883301
#
#
# ====================================================
# Epoch 39/100, Batch 1/50, Total Loss 573.154968, Likelihood Loss 559.816406, KL Loss 2.667711
# Epoch 39/100, Batch 11/50, Total Loss 395.641327, Likelihood Loss 381.616638, KL Loss 2.804938
# Epoch 39/100, Batch 21/50, Total Loss 274.783752, Likelihood Loss 257.634186, KL Loss 3.429916
# Epoch 39/100, Batch 31/50, Total Loss 233.326416, Likelihood Loss 219.690399, KL Loss 2.727202
# Epoch 39/100, Batch 41/50, Total Loss 244.244812, Likelihood Loss 229.775681, KL Loss 2.893826
# ====================================================
#
#
# Epoch 39/100, Train Total Loss 288.522217, Eval Total Loss 806.142334
#
#
# ====================================================
# Epoch 40/100, Batch 1/50, Total Loss 463.881897, Likelihood Loss 450.161102, KL Loss 2.744160
# Epoch 40/100, Batch 11/50, Total Loss 367.808014, Likelihood Loss 353.434692, KL Loss 2.874665
# Epoch 40/100, Batch 21/50, Total Loss 415.629822, Likelihood Loss 397.920471, KL Loss 3.541868
# Epoch 40/100, Batch 31/50, Total Loss 289.554749, Likelihood Loss 276.131714, KL Loss 2.684610
# Epoch 40/100, Batch 41/50, Total Loss 217.781815, Likelihood Loss 201.549179, KL Loss 3.246528
# ====================================================
#
#
# Epoch 40/100, Train Total Loss 198.018646, Eval Total Loss 605.497803
#
#
# ====================================================
# Epoch 41/100, Batch 1/50, Total Loss 284.547913, Likelihood Loss 271.387421, KL Loss 2.632101
# Epoch 41/100, Batch 11/50, Total Loss 274.450531, Likelihood Loss 260.996704, KL Loss 2.690763
# Epoch 41/100, Batch 21/50, Total Loss 397.738586, Likelihood Loss 381.001953, KL Loss 3.347328
# Epoch 41/100, Batch 31/50, Total Loss 399.198090, Likelihood Loss 386.661438, KL Loss 2.507328
# Epoch 41/100, Batch 41/50, Total Loss 310.779785, Likelihood Loss 293.912170, KL Loss 3.373526
# ====================================================
#
#
# Epoch 41/100, Train Total Loss 283.163361, Eval Total Loss 542.600159
#
#
# ====================================================
# Epoch 42/100, Batch 1/50, Total Loss 284.310547, Likelihood Loss 270.277100, KL Loss 2.806692
# Epoch 42/100, Batch 11/50, Total Loss 318.533783, Likelihood Loss 304.044312, KL Loss 2.897897
# Epoch 42/100, Batch 21/50, Total Loss 361.161926, Likelihood Loss 343.913818, KL Loss 3.449623
# Epoch 42/100, Batch 31/50, Total Loss 284.969421, Likelihood Loss 270.408875, KL Loss 2.912109
# Epoch 42/100, Batch 41/50, Total Loss 350.873077, Likelihood Loss 335.628021, KL Loss 3.049013
# ====================================================
#
#
# Epoch 42/100, Train Total Loss 261.841675, Eval Total Loss 602.869690
#
#
# ====================================================
# Epoch 43/100, Batch 1/50, Total Loss 357.650879, Likelihood Loss 341.745789, KL Loss 3.181016
# Epoch 43/100, Batch 11/50, Total Loss 269.884125, Likelihood Loss 253.061783, KL Loss 3.364470
# Epoch 43/100, Batch 21/50, Total Loss 296.917542, Likelihood Loss 277.924622, KL Loss 3.798583
# Epoch 43/100, Batch 31/50, Total Loss 403.185303, Likelihood Loss 386.078125, KL Loss 3.421437
# Epoch 43/100, Batch 41/50, Total Loss 315.248383, Likelihood Loss 297.120483, KL Loss 3.625582
# ====================================================
#
#
# Epoch 43/100, Train Total Loss 497.926331, Eval Total Loss 511.870361
#
#
# ====================================================
# Epoch 44/100, Batch 1/50, Total Loss 326.091888, Likelihood Loss 309.896667, KL Loss 3.239044
# Epoch 44/100, Batch 11/50, Total Loss 353.055634, Likelihood Loss 332.388916, KL Loss 4.133342
# Epoch 44/100, Batch 21/50, Total Loss 429.150085, Likelihood Loss 411.065979, KL Loss 3.616820
# Epoch 44/100, Batch 31/50, Total Loss 449.065369, Likelihood Loss 430.519714, KL Loss 3.709129
# Epoch 44/100, Batch 41/50, Total Loss 495.826904, Likelihood Loss 476.677704, KL Loss 3.829840
# ====================================================
#
#
# Epoch 44/100, Train Total Loss 340.966278, Eval Total Loss 540.215698
#
#
# ====================================================
# Epoch 45/100, Batch 1/50, Total Loss 376.787079, Likelihood Loss 361.979126, KL Loss 2.961588
# Epoch 45/100, Batch 11/50, Total Loss 298.559479, Likelihood Loss 280.469757, KL Loss 3.617945
# Epoch 45/100, Batch 21/50, Total Loss 347.426636, Likelihood Loss 330.888184, KL Loss 3.307687
# Epoch 45/100, Batch 31/50, Total Loss 293.164703, Likelihood Loss 278.107208, KL Loss 3.011499
# Epoch 45/100, Batch 41/50, Total Loss 322.860413, Likelihood Loss 305.022461, KL Loss 3.567591
# ====================================================
#
#
# Epoch 45/100, Train Total Loss 232.627136, Eval Total Loss 429.914551
#
#
# ====================================================
# Epoch 46/100, Batch 1/50, Total Loss 213.264999, Likelihood Loss 199.257233, KL Loss 2.801552
# Epoch 46/100, Batch 11/50, Total Loss 250.106476, Likelihood Loss 235.990906, KL Loss 2.823114
# Epoch 46/100, Batch 21/50, Total Loss 220.021545, Likelihood Loss 204.826416, KL Loss 3.039026
# Epoch 46/100, Batch 31/50, Total Loss 218.939133, Likelihood Loss 205.932953, KL Loss 2.601236
# Epoch 46/100, Batch 41/50, Total Loss 223.832825, Likelihood Loss 209.660767, KL Loss 2.834411
# ====================================================
#
#
# Epoch 46/100, Train Total Loss 258.473785, Eval Total Loss 435.059235
#
#
# ====================================================
# Epoch 47/100, Batch 1/50, Total Loss 245.468063, Likelihood Loss 231.479797, KL Loss 2.797654
# Epoch 47/100, Batch 11/50, Total Loss 216.120514, Likelihood Loss 203.608673, KL Loss 2.502369
# Epoch 47/100, Batch 21/50, Total Loss 255.254623, Likelihood Loss 242.012299, KL Loss 2.648464
# Epoch 47/100, Batch 31/50, Total Loss 199.208328, Likelihood Loss 186.521912, KL Loss 2.537282
# Epoch 47/100, Batch 41/50, Total Loss 175.508698, Likelihood Loss 161.932068, KL Loss 2.715327
# ====================================================
#
#
# Epoch 47/100, Train Total Loss 218.562302, Eval Total Loss 499.057251
#
#
# ====================================================
# Epoch 48/100, Batch 1/50, Total Loss 277.690460, Likelihood Loss 264.747375, KL Loss 2.588614
# Epoch 48/100, Batch 11/50, Total Loss 174.608597, Likelihood Loss 161.244598, KL Loss 2.672801
# Epoch 48/100, Batch 21/50, Total Loss 357.562714, Likelihood Loss 345.152649, KL Loss 2.482012
# Epoch 48/100, Batch 31/50, Total Loss 309.553192, Likelihood Loss 298.129852, KL Loss 2.284667
# Epoch 48/100, Batch 41/50, Total Loss 187.219391, Likelihood Loss 172.792511, KL Loss 2.885375
# ====================================================
#
#
# Epoch 48/100, Train Total Loss 193.572205, Eval Total Loss 510.230530
#
#
# ====================================================
# Epoch 49/100, Batch 1/50, Total Loss 264.045959, Likelihood Loss 250.982239, KL Loss 2.612741
# Epoch 49/100, Batch 11/50, Total Loss 296.905487, Likelihood Loss 282.501404, KL Loss 2.880819
# Epoch 49/100, Batch 21/50, Total Loss 220.885086, Likelihood Loss 206.376831, KL Loss 2.901650
# Epoch 49/100, Batch 31/50, Total Loss 356.185669, Likelihood Loss 344.586792, KL Loss 2.319775
# Epoch 49/100, Batch 41/50, Total Loss 435.289368, Likelihood Loss 422.753479, KL Loss 2.507179
# ====================================================
#
#
# Epoch 49/100, Train Total Loss 408.892242, Eval Total Loss 495.357208
#
#
# ====================================================
# Epoch 50/100, Batch 1/50, Total Loss 273.489655, Likelihood Loss 260.155090, KL Loss 2.666912
# Epoch 50/100, Batch 11/50, Total Loss 181.400650, Likelihood Loss 167.989136, KL Loss 2.682303
# Epoch 50/100, Batch 21/50, Total Loss 381.733612, Likelihood Loss 364.529175, KL Loss 3.440889
# Epoch 50/100, Batch 31/50, Total Loss 309.406891, Likelihood Loss 295.843384, KL Loss 2.712703
# Epoch 50/100, Batch 41/50, Total Loss 196.317642, Likelihood Loss 182.932449, KL Loss 2.677040
# ====================================================
#
#
# Epoch 50/100, Train Total Loss 189.233688, Eval Total Loss 551.114807
#
#
# ====================================================
# Epoch 51/100, Batch 1/50, Total Loss 295.695129, Likelihood Loss 284.322876, KL Loss 2.274449
# Epoch 51/100, Batch 11/50, Total Loss 198.331558, Likelihood Loss 184.971039, KL Loss 2.672103
# Epoch 51/100, Batch 21/50, Total Loss 179.344391, Likelihood Loss 165.322098, KL Loss 2.804459
# Epoch 51/100, Batch 31/50, Total Loss 180.191330, Likelihood Loss 167.131897, KL Loss 2.611887
# Epoch 51/100, Batch 41/50, Total Loss 207.806168, Likelihood Loss 194.711349, KL Loss 2.618964
# ====================================================
#
#
# Epoch 51/100, Train Total Loss 200.006210, Eval Total Loss 419.619690
#
#
# ====================================================
# Epoch 52/100, Batch 1/50, Total Loss 154.480988, Likelihood Loss 142.874237, KL Loss 2.321351
# Epoch 52/100, Batch 11/50, Total Loss 154.535034, Likelihood Loss 141.836746, KL Loss 2.539656
# Epoch 52/100, Batch 21/50, Total Loss 177.077682, Likelihood Loss 164.172806, KL Loss 2.580975
# Epoch 52/100, Batch 31/50, Total Loss 160.021774, Likelihood Loss 148.757034, KL Loss 2.252947
# Epoch 52/100, Batch 41/50, Total Loss 163.245682, Likelihood Loss 151.357361, KL Loss 2.377663
# ====================================================
#
#
# Epoch 52/100, Train Total Loss 206.842850, Eval Total Loss 473.217529
#
#
# ====================================================
# Epoch 53/100, Batch 1/50, Total Loss 203.438202, Likelihood Loss 191.070068, KL Loss 2.473626
# Epoch 53/100, Batch 11/50, Total Loss 211.856293, Likelihood Loss 198.904251, KL Loss 2.590409
# Epoch 53/100, Batch 21/50, Total Loss 255.310486, Likelihood Loss 241.760895, KL Loss 2.709920
# Epoch 53/100, Batch 31/50, Total Loss 230.575104, Likelihood Loss 219.637405, KL Loss 2.187540
# Epoch 53/100, Batch 41/50, Total Loss 197.889511, Likelihood Loss 185.861969, KL Loss 2.405509
# ====================================================
#
#
# Epoch 53/100, Train Total Loss 207.038589, Eval Total Loss 415.343109
#
#
# ====================================================
# Epoch 54/100, Batch 1/50, Total Loss 173.499344, Likelihood Loss 161.259430, KL Loss 2.447983
# Epoch 54/100, Batch 11/50, Total Loss 292.691620, Likelihood Loss 277.502838, KL Loss 3.037758
# Epoch 54/100, Batch 21/50, Total Loss 363.770386, Likelihood Loss 346.948792, KL Loss 3.364318
# Epoch 54/100, Batch 31/50, Total Loss 325.517975, Likelihood Loss 312.932098, KL Loss 2.517174
# Epoch 54/100, Batch 41/50, Total Loss 259.027771, Likelihood Loss 244.591034, KL Loss 2.887348
# ====================================================
#
#
# Epoch 54/100, Train Total Loss 258.658478, Eval Total Loss 461.194214
#
#
# ====================================================
# Epoch 55/100, Batch 1/50, Total Loss 282.797180, Likelihood Loss 271.442230, KL Loss 2.270987
# Epoch 55/100, Batch 11/50, Total Loss 283.898560, Likelihood Loss 268.295929, KL Loss 3.120528
# Epoch 55/100, Batch 21/50, Total Loss 359.311401, Likelihood Loss 343.076660, KL Loss 3.246951
# Epoch 55/100, Batch 31/50, Total Loss 356.007751, Likelihood Loss 341.746094, KL Loss 2.852334
# Epoch 55/100, Batch 41/50, Total Loss 312.535797, Likelihood Loss 298.182556, KL Loss 2.870647
# ====================================================
#
#
# Epoch 55/100, Train Total Loss 244.635345, Eval Total Loss 431.872437
#
#
# ====================================================
# Epoch 56/100, Batch 1/50, Total Loss 227.934753, Likelihood Loss 213.501251, KL Loss 2.886702
# Epoch 56/100, Batch 11/50, Total Loss 194.146194, Likelihood Loss 179.834015, KL Loss 2.862435
# Epoch 56/100, Batch 21/50, Total Loss 189.917694, Likelihood Loss 173.740097, KL Loss 3.235519
# Epoch 56/100, Batch 31/50, Total Loss 250.689941, Likelihood Loss 237.975250, KL Loss 2.542938
# Epoch 56/100, Batch 41/50, Total Loss 324.645905, Likelihood Loss 308.752075, KL Loss 3.178766
# ====================================================
#
#
# Epoch 56/100, Train Total Loss 276.064514, Eval Total Loss 535.367493
#
#
# ====================================================
# Epoch 57/100, Batch 1/50, Total Loss 309.775909, Likelihood Loss 296.052704, KL Loss 2.744643
# Epoch 57/100, Batch 11/50, Total Loss 204.871643, Likelihood Loss 189.893280, KL Loss 2.995673
# Epoch 57/100, Batch 21/50, Total Loss 211.124039, Likelihood Loss 195.627487, KL Loss 3.099311
# Epoch 57/100, Batch 31/50, Total Loss 263.649323, Likelihood Loss 252.420166, KL Loss 2.245833
# Epoch 57/100, Batch 41/50, Total Loss 314.144928, Likelihood Loss 299.045074, KL Loss 3.019973
# ====================================================
#
#
# Epoch 57/100, Train Total Loss 181.573334, Eval Total Loss 554.697388
#
#
# ====================================================
# Epoch 58/100, Batch 1/50, Total Loss 267.221710, Likelihood Loss 254.372009, KL Loss 2.569940
# Epoch 58/100, Batch 11/50, Total Loss 261.181396, Likelihood Loss 244.997101, KL Loss 3.236857
# Epoch 58/100, Batch 21/50, Total Loss 254.005814, Likelihood Loss 238.655457, KL Loss 3.070072
# Epoch 58/100, Batch 31/50, Total Loss 214.539047, Likelihood Loss 202.597412, KL Loss 2.388327
# Epoch 58/100, Batch 41/50, Total Loss 249.537994, Likelihood Loss 236.684326, KL Loss 2.570734
# ====================================================
#
#
# Epoch 58/100, Train Total Loss 196.051315, Eval Total Loss 420.950684
#
#
# ====================================================
# Epoch 59/100, Batch 1/50, Total Loss 161.847382, Likelihood Loss 149.652863, KL Loss 2.438902
# Epoch 59/100, Batch 11/50, Total Loss 224.655716, Likelihood Loss 209.730530, KL Loss 2.985037
# Epoch 59/100, Batch 21/50, Total Loss 275.565247, Likelihood Loss 259.934784, KL Loss 3.126094
# Epoch 59/100, Batch 31/50, Total Loss 245.003235, Likelihood Loss 232.020172, KL Loss 2.596611
# Epoch 59/100, Batch 41/50, Total Loss 191.518448, Likelihood Loss 178.964508, KL Loss 2.510787
# ====================================================
#
#
# Epoch 59/100, Train Total Loss 255.863861, Eval Total Loss 422.175110
#
#
# ====================================================
# Epoch 60/100, Batch 1/50, Total Loss 189.527100, Likelihood Loss 177.386353, KL Loss 2.428150
# Epoch 60/100, Batch 11/50, Total Loss 305.464966, Likelihood Loss 291.862488, KL Loss 2.720498
# Epoch 60/100, Batch 21/50, Total Loss 257.328735, Likelihood Loss 241.635193, KL Loss 3.138707
# Epoch 60/100, Batch 31/50, Total Loss 272.888977, Likelihood Loss 259.730957, KL Loss 2.631605
# Epoch 60/100, Batch 41/50, Total Loss 222.589676, Likelihood Loss 207.173187, KL Loss 3.083297
# ====================================================
#
#
# Epoch 60/100, Train Total Loss 271.801117, Eval Total Loss 461.918152
#
#
# ====================================================
# Epoch 61/100, Batch 1/50, Total Loss 252.209534, Likelihood Loss 240.201309, KL Loss 2.401646
# Epoch 61/100, Batch 11/50, Total Loss 229.490005, Likelihood Loss 216.062531, KL Loss 2.685495
# Epoch 61/100, Batch 21/50, Total Loss 211.310547, Likelihood Loss 197.071228, KL Loss 2.847865
# Epoch 61/100, Batch 31/50, Total Loss 287.702393, Likelihood Loss 273.984741, KL Loss 2.743531
# Epoch 61/100, Batch 41/50, Total Loss 260.613464, Likelihood Loss 244.533890, KL Loss 3.215913
# ====================================================
#
#
# Epoch 61/100, Train Total Loss 251.057922, Eval Total Loss 573.247681
#
#
# ====================================================
# Epoch 62/100, Batch 1/50, Total Loss 344.267761, Likelihood Loss 329.950470, KL Loss 2.863461
# Epoch 62/100, Batch 11/50, Total Loss 214.444885, Likelihood Loss 199.567123, KL Loss 2.975554
# Epoch 62/100, Batch 21/50, Total Loss 248.369934, Likelihood Loss 231.878815, KL Loss 3.298224
# Epoch 62/100, Batch 31/50, Total Loss 282.026764, Likelihood Loss 269.964600, KL Loss 2.412435
# Epoch 62/100, Batch 41/50, Total Loss 305.801727, Likelihood Loss 289.538574, KL Loss 3.252630
# ====================================================
#
#
# Epoch 62/100, Train Total Loss 256.482147, Eval Total Loss 524.515747
#
#
# ====================================================
# Epoch 63/100, Batch 1/50, Total Loss 268.445435, Likelihood Loss 253.598969, KL Loss 2.969295
# Epoch 63/100, Batch 11/50, Total Loss 270.413422, Likelihood Loss 251.985352, KL Loss 3.685612
# Epoch 63/100, Batch 21/50, Total Loss 254.113541, Likelihood Loss 234.821960, KL Loss 3.858316
# Epoch 63/100, Batch 31/50, Total Loss 323.628662, Likelihood Loss 311.394562, KL Loss 2.446820
# Epoch 63/100, Batch 41/50, Total Loss 310.517853, Likelihood Loss 293.546692, KL Loss 3.394230
# ====================================================
#
#
# Epoch 63/100, Train Total Loss 474.768036, Eval Total Loss 630.933105
#
#
# ====================================================
# Epoch 64/100, Batch 1/50, Total Loss 376.399780, Likelihood Loss 360.996094, KL Loss 3.080736
# Epoch 64/100, Batch 11/50, Total Loss 287.075897, Likelihood Loss 271.109253, KL Loss 3.193329
# Epoch 64/100, Batch 21/50, Total Loss 275.363831, Likelihood Loss 256.563263, KL Loss 3.760114
# Epoch 64/100, Batch 31/50, Total Loss 296.007019, Likelihood Loss 281.506012, KL Loss 2.900203
# Epoch 64/100, Batch 41/50, Total Loss 266.297791, Likelihood Loss 250.949127, KL Loss 3.069735
# ====================================================
#
#
# Epoch 64/100, Train Total Loss 370.597260, Eval Total Loss 593.032532
#
#
# ====================================================
# Epoch 65/100, Batch 1/50, Total Loss 312.826416, Likelihood Loss 296.169250, KL Loss 3.331432
# Epoch 65/100, Batch 11/50, Total Loss 279.154510, Likelihood Loss 264.283691, KL Loss 2.974163
# Epoch 65/100, Batch 21/50, Total Loss 435.072754, Likelihood Loss 418.074036, KL Loss 3.399746
# Epoch 65/100, Batch 31/50, Total Loss 463.878540, Likelihood Loss 450.662506, KL Loss 2.643208
# Epoch 65/100, Batch 41/50, Total Loss 404.474213, Likelihood Loss 388.442627, KL Loss 3.206316
# ====================================================
#
#
# Epoch 65/100, Train Total Loss 330.324158, Eval Total Loss 728.461121
#
#
# ====================================================
# Epoch 66/100, Batch 1/50, Total Loss 406.474518, Likelihood Loss 392.076965, KL Loss 2.879508
# Epoch 66/100, Batch 11/50, Total Loss 232.959625, Likelihood Loss 214.309509, KL Loss 3.730024
# Epoch 66/100, Batch 21/50, Total Loss 355.748535, Likelihood Loss 338.976807, KL Loss 3.354343
# Epoch 66/100, Batch 31/50, Total Loss 479.058014, Likelihood Loss 464.165131, KL Loss 2.978576
# Epoch 66/100, Batch 41/50, Total Loss 331.299591, Likelihood Loss 315.684692, KL Loss 3.122983
# ====================================================
#
#
# Epoch 66/100, Train Total Loss 236.387756, Eval Total Loss 602.106079
#
#
# ====================================================
# Epoch 67/100, Batch 1/50, Total Loss 271.222870, Likelihood Loss 256.351013, KL Loss 2.974372
# Epoch 67/100, Batch 11/50, Total Loss 194.154968, Likelihood Loss 173.902115, KL Loss 4.050571
# Epoch 67/100, Batch 21/50, Total Loss 387.690277, Likelihood Loss 368.924438, KL Loss 3.753165
# Epoch 67/100, Batch 31/50, Total Loss 310.216339, Likelihood Loss 295.478943, KL Loss 2.947480
# Epoch 67/100, Batch 41/50, Total Loss 238.249695, Likelihood Loss 222.426804, KL Loss 3.164579
# ====================================================
#
#
# Epoch 67/100, Train Total Loss 284.267426, Eval Total Loss 659.449463
#
#
# ====================================================
# Epoch 68/100, Batch 1/50, Total Loss 335.196014, Likelihood Loss 317.761353, KL Loss 3.486933
# Epoch 68/100, Batch 11/50, Total Loss 190.710403, Likelihood Loss 171.486023, KL Loss 3.844876
# Epoch 68/100, Batch 21/50, Total Loss 262.010559, Likelihood Loss 241.902130, KL Loss 4.021685
# Epoch 68/100, Batch 31/50, Total Loss 192.769577, Likelihood Loss 178.301727, KL Loss 2.893569
# Epoch 68/100, Batch 41/50, Total Loss 451.067078, Likelihood Loss 434.309937, KL Loss 3.351431
# ====================================================
#
#
# Epoch 68/100, Train Total Loss 328.988770, Eval Total Loss 632.082947
#
#
# ====================================================
# Epoch 69/100, Batch 1/50, Total Loss 338.667114, Likelihood Loss 321.410828, KL Loss 3.451258
# Epoch 69/100, Batch 11/50, Total Loss 267.112762, Likelihood Loss 246.808105, KL Loss 4.060932
# Epoch 69/100, Batch 21/50, Total Loss 325.243988, Likelihood Loss 304.456970, KL Loss 4.157405
# Epoch 69/100, Batch 31/50, Total Loss 216.369553, Likelihood Loss 200.582916, KL Loss 3.157327
# Epoch 69/100, Batch 41/50, Total Loss 518.402832, Likelihood Loss 499.612061, KL Loss 3.758160
# ====================================================
#
#
# Epoch 69/100, Train Total Loss 424.395813, Eval Total Loss 617.751587
#
#
# ====================================================
# Epoch 70/100, Batch 1/50, Total Loss 429.508850, Likelihood Loss 412.793304, KL Loss 3.343111
# Epoch 70/100, Batch 11/50, Total Loss 438.983551, Likelihood Loss 418.185333, KL Loss 4.159641
# Epoch 70/100, Batch 21/50, Total Loss 258.717072, Likelihood Loss 239.837082, KL Loss 3.775998
# Epoch 70/100, Batch 31/50, Total Loss 336.280701, Likelihood Loss 320.027161, KL Loss 3.250707
# Epoch 70/100, Batch 41/50, Total Loss 305.879822, Likelihood Loss 288.504944, KL Loss 3.474976
# ====================================================
#
#
# Epoch 70/100, Train Total Loss 378.289948, Eval Total Loss 625.273132
#
#
# ====================================================
# Epoch 71/100, Batch 1/50, Total Loss 434.837708, Likelihood Loss 417.875549, KL Loss 3.392430
# Epoch 71/100, Batch 11/50, Total Loss 277.655884, Likelihood Loss 259.994080, KL Loss 3.532363
# Epoch 71/100, Batch 21/50, Total Loss 236.065567, Likelihood Loss 219.927078, KL Loss 3.227697
# Epoch 71/100, Batch 31/50, Total Loss 287.692047, Likelihood Loss 274.616089, KL Loss 2.615191
# Epoch 71/100, Batch 41/50, Total Loss 208.136047, Likelihood Loss 193.700043, KL Loss 2.887201
# ====================================================
#
#
# Epoch 71/100, Train Total Loss 265.076965, Eval Total Loss 501.716827
#
#
# ====================================================
# Epoch 72/100, Batch 1/50, Total Loss 272.294800, Likelihood Loss 256.318359, KL Loss 3.195285
# Epoch 72/100, Batch 11/50, Total Loss 205.816895, Likelihood Loss 192.717712, KL Loss 2.619838
# Epoch 72/100, Batch 21/50, Total Loss 261.546417, Likelihood Loss 246.476288, KL Loss 3.014026
# Epoch 72/100, Batch 31/50, Total Loss 292.470551, Likelihood Loss 280.679016, KL Loss 2.358307
# Epoch 72/100, Batch 41/50, Total Loss 208.088242, Likelihood Loss 194.975403, KL Loss 2.622568
# ====================================================
#
#
# Epoch 72/100, Train Total Loss 211.184036, Eval Total Loss 460.188751
#
#
# ====================================================
# Epoch 73/100, Batch 1/50, Total Loss 242.621475, Likelihood Loss 229.667786, KL Loss 2.590739
# Epoch 73/100, Batch 11/50, Total Loss 206.324326, Likelihood Loss 194.063171, KL Loss 2.452229
# Epoch 73/100, Batch 21/50, Total Loss 263.797394, Likelihood Loss 251.271393, KL Loss 2.505201
# Epoch 73/100, Batch 31/50, Total Loss 198.882187, Likelihood Loss 186.924545, KL Loss 2.391528
# Epoch 73/100, Batch 41/50, Total Loss 189.378021, Likelihood Loss 175.377792, KL Loss 2.800046
# ====================================================
#
#
# Epoch 73/100, Train Total Loss 184.192505, Eval Total Loss 458.952728
#
#
# ====================================================
# Epoch 74/100, Batch 1/50, Total Loss 188.226974, Likelihood Loss 175.178207, KL Loss 2.609753
# Epoch 74/100, Batch 11/50, Total Loss 138.199463, Likelihood Loss 124.080093, KL Loss 2.823873
# ...
# Epoch 76/100, Batch 41/50, Total Loss 157.690399, Likelihood Loss 145.028961, KL Loss 2.532287
# ====================================================
#
#
# Epoch 76/100, Train Total Loss 209.843155, Eval Total Loss 458.499908
#
#
# ====================================================
# Epoch 77/100, Batch 1/50, Total Loss 191.977249, Likelihood Loss 181.409760, KL Loss 2.113497
# Epoch 77/100, Batch 11/50, Total Loss 239.042618, Likelihood Loss 228.686981, KL Loss 2.071127
# Epoch 77/100, Batch 21/50, Total Loss 193.506073, Likelihood Loss 179.562988, KL Loss 2.788616
# Epoch 77/100, Batch 31/50, Total Loss 188.941010, Likelihood Loss 177.852722, KL Loss 2.217658
# Epoch 77/100, Batch 41/50, Total Loss 193.904556, Likelihood Loss 178.493118, KL Loss 3.082287
# ====================================================
#
#
# Epoch 77/100, Train Total Loss 165.639420, Eval Total Loss 454.783356
#
#
# ====================================================
# Epoch 78/100, Batch 1/50, Total Loss 160.750656, Likelihood Loss 150.626831, KL Loss 2.024765
# Epoch 78/100, Batch 11/50, Total Loss 193.225220, Likelihood Loss 180.359772, KL Loss 2.573090
# Epoch 78/100, Batch 21/50, Total Loss 197.194016, Likelihood Loss 184.397568, KL Loss 2.559290
# Epoch 78/100, Batch 31/50, Total Loss 277.325714, Likelihood Loss 265.965149, KL Loss 2.272114
# Epoch 78/100, Batch 41/50, Total Loss 164.732971, Likelihood Loss 151.604996, KL Loss 2.625596
# ====================================================
#
#
# Epoch 78/100, Train Total Loss 299.538696, Eval Total Loss 584.263000
#
#
# ====================================================
# Epoch 79/100, Batch 1/50, Total Loss 282.079926, Likelihood Loss 272.142609, KL Loss 1.987462
# Epoch 79/100, Batch 11/50, Total Loss 175.651047, Likelihood Loss 162.952057, KL Loss 2.539797
# Epoch 79/100, Batch 21/50, Total Loss 209.914825, Likelihood Loss 196.598267, KL Loss 2.663313
# Epoch 79/100, Batch 31/50, Total Loss 191.823853, Likelihood Loss 180.970032, KL Loss 2.170764
# Epoch 79/100, Batch 41/50, Total Loss 243.514542, Likelihood Loss 232.463943, KL Loss 2.210119
# ====================================================
#
#
# Epoch 79/100, Train Total Loss 263.534271, Eval Total Loss 741.493835
#
#
# ====================================================
# Epoch 80/100, Batch 1/50, Total Loss 370.293640, Likelihood Loss 360.521271, KL Loss 1.954476
# Epoch 80/100, Batch 11/50, Total Loss 185.041229, Likelihood Loss 171.130234, KL Loss 2.782199
# Epoch 80/100, Batch 21/50, Total Loss 282.032257, Likelihood Loss 266.613892, KL Loss 3.083674
# Epoch 80/100, Batch 31/50, Total Loss 172.703918, Likelihood Loss 161.162766, KL Loss 2.308230
# Epoch 80/100, Batch 41/50, Total Loss 235.733185, Likelihood Loss 224.971970, KL Loss 2.152244
# ====================================================
#
#
# Epoch 80/100, Train Total Loss 210.471344, Eval Total Loss 590.943054
#
#
# ====================================================
# Epoch 81/100, Batch 1/50, Total Loss 246.557007, Likelihood Loss 234.985580, KL Loss 2.314286
# Epoch 81/100, Batch 11/50, Total Loss 293.367401, Likelihood Loss 276.696716, KL Loss 3.334136
# Epoch 81/100, Batch 21/50, Total Loss 233.126053, Likelihood Loss 217.618454, KL Loss 3.101521
# Epoch 81/100, Batch 31/50, Total Loss 189.333984, Likelihood Loss 178.331543, KL Loss 2.200489
# Epoch 81/100, Batch 41/50, Total Loss 256.312653, Likelihood Loss 243.632477, KL Loss 2.536033
# ====================================================
#
#
# Epoch 81/100, Train Total Loss 233.548080, Eval Total Loss 514.019104
#
#
# ====================================================
# Epoch 82/100, Batch 1/50, Total Loss 225.954498, Likelihood Loss 213.675201, KL Loss 2.455858
# Epoch 82/100, Batch 11/50, Total Loss 267.439911, Likelihood Loss 251.831039, KL Loss 3.121777
# Epoch 82/100, Batch 21/50, Total Loss 198.115234, Likelihood Loss 184.276031, KL Loss 2.767841
# Epoch 82/100, Batch 31/50, Total Loss 251.527618, Likelihood Loss 242.235291, KL Loss 1.858467
# Epoch 82/100, Batch 41/50, Total Loss 217.053162, Likelihood Loss 202.701630, KL Loss 2.870307
# ====================================================
#
#
# Epoch 82/100, Train Total Loss 231.158356, Eval Total Loss 564.873657
#
#
# ====================================================
# Epoch 83/100, Batch 1/50, Total Loss 275.652863, Likelihood Loss 264.210327, KL Loss 2.288506
# Epoch 83/100, Batch 11/50, Total Loss 185.093445, Likelihood Loss 169.410767, KL Loss 3.136535
# Epoch 83/100, Batch 21/50, Total Loss 226.150543, Likelihood Loss 213.941422, KL Loss 2.441825
# Epoch 83/100, Batch 31/50, Total Loss 216.962524, Likelihood Loss 205.180801, KL Loss 2.356343
# Epoch 83/100, Batch 41/50, Total Loss 223.833176, Likelihood Loss 212.116425, KL Loss 2.343349
# ====================================================
#
#
# Epoch 83/100, Train Total Loss 187.618896, Eval Total Loss 610.799683
#
#
# ====================================================
# Epoch 84/100, Batch 1/50, Total Loss 258.235474, Likelihood Loss 244.881409, KL Loss 2.670815
# Epoch 84/100, Batch 11/50, Total Loss 155.978973, Likelihood Loss 143.109802, KL Loss 2.573833
# Epoch 84/100, Batch 21/50, Total Loss 209.028778, Likelihood Loss 195.888336, KL Loss 2.628088
# Epoch 84/100, Batch 31/50, Total Loss 165.335556, Likelihood Loss 153.366226, KL Loss 2.393866
# Epoch 84/100, Batch 41/50, Total Loss 248.452576, Likelihood Loss 235.284576, KL Loss 2.633599
# ====================================================
#
#
# Epoch 84/100, Train Total Loss 189.413696, Eval Total Loss 492.508270
#
#
# ====================================================
# Epoch 85/100, Batch 1/50, Total Loss 156.355591, Likelihood Loss 144.901245, KL Loss 2.290868
# Epoch 85/100, Batch 11/50, Total Loss 229.700104, Likelihood Loss 217.427170, KL Loss 2.454586
# Epoch 85/100, Batch 21/50, Total Loss 175.049728, Likelihood Loss 161.942291, KL Loss 2.621488
# Epoch 85/100, Batch 31/50, Total Loss 237.954041, Likelihood Loss 225.025940, KL Loss 2.585619
# Epoch 85/100, Batch 41/50, Total Loss 164.452972, Likelihood Loss 153.069168, KL Loss 2.276761
# ====================================================
#
#
# Epoch 85/100, Train Total Loss 223.107651, Eval Total Loss 538.372864
#
#
# ====================================================
# Epoch 86/100, Batch 1/50, Total Loss 212.518250, Likelihood Loss 202.059235, KL Loss 2.091804
# Epoch 86/100, Batch 11/50, Total Loss 174.226501, Likelihood Loss 160.797699, KL Loss 2.685760
# Epoch 86/100, Batch 21/50, Total Loss 213.423264, Likelihood Loss 199.156143, KL Loss 2.853424
# Epoch 86/100, Batch 31/50, Total Loss 172.452316, Likelihood Loss 161.483612, KL Loss 2.193740
# Epoch 86/100, Batch 41/50, Total Loss 169.437500, Likelihood Loss 158.958008, KL Loss 2.095900
# ====================================================
#
#
# Epoch 86/100, Train Total Loss 179.210159, Eval Total Loss 531.745911
#
#
# ====================================================
# Epoch 87/100, Batch 1/50, Total Loss 187.476242, Likelihood Loss 176.680557, KL Loss 2.159137
# Epoch 87/100, Batch 11/50, Total Loss 183.102951, Likelihood Loss 169.478424, KL Loss 2.724907
# Epoch 87/100, Batch 21/50, Total Loss 241.956741, Likelihood Loss 227.985443, KL Loss 2.794259
# Epoch 87/100, Batch 31/50, Total Loss 136.786911, Likelihood Loss 126.405853, KL Loss 2.076213
# Epoch 87/100, Batch 41/50, Total Loss 220.960709, Likelihood Loss 211.412415, KL Loss 1.909659
# ====================================================
#
#
# Epoch 87/100, Train Total Loss 177.279709, Eval Total Loss 481.268280
#
#
# ====================================================
# Epoch 88/100, Batch 1/50, Total Loss 155.984741, Likelihood Loss 143.475067, KL Loss 2.501936
# Epoch 88/100, Batch 11/50, Total Loss 238.081360, Likelihood Loss 223.748566, KL Loss 2.866560
# Epoch 88/100, Batch 21/50, Total Loss 190.252640, Likelihood Loss 176.830292, KL Loss 2.684470
# Epoch 88/100, Batch 31/50, Total Loss 217.494064, Likelihood Loss 207.112671, KL Loss 2.076279
# Epoch 88/100, Batch 41/50, Total Loss 249.379227, Likelihood Loss 239.106903, KL Loss 2.054464
# ====================================================
#
#
# Epoch 88/100, Train Total Loss 232.587906, Eval Total Loss 504.621674
#
#
# ====================================================
# Epoch 89/100, Batch 1/50, Total Loss 201.682007, Likelihood Loss 187.793793, KL Loss 2.777642
# Epoch 89/100, Batch 11/50, Total Loss 219.542816, Likelihood Loss 204.799866, KL Loss 2.948589
# Epoch 89/100, Batch 21/50, Total Loss 185.913773, Likelihood Loss 173.649704, KL Loss 2.452815
# Epoch 89/100, Batch 31/50, Total Loss 255.111954, Likelihood Loss 243.547394, KL Loss 2.312912
# Epoch 89/100, Batch 41/50, Total Loss 289.571533, Likelihood Loss 277.828064, KL Loss 2.348695
# ====================================================
#
#
# Epoch 89/100, Train Total Loss 201.813217, Eval Total Loss 531.018250
#
#
# ====================================================
# Epoch 90/100, Batch 1/50, Total Loss 225.978241, Likelihood Loss 211.752579, KL Loss 2.845134
# Epoch 90/100, Batch 11/50, Total Loss 224.230438, Likelihood Loss 206.419006, KL Loss 3.562288
# Epoch 90/100, Batch 21/50, Total Loss 199.259018, Likelihood Loss 186.977753, KL Loss 2.456253
# Epoch 90/100, Batch 31/50, Total Loss 263.642029, Likelihood Loss 249.096252, KL Loss 2.909155
# Epoch 90/100, Batch 41/50, Total Loss 237.070923, Likelihood Loss 225.294083, KL Loss 2.355370
# ====================================================
#
#
# Epoch 90/100, Train Total Loss 265.163147, Eval Total Loss 560.553894
#
#
# ====================================================
# Epoch 91/100, Batch 1/50, Total Loss 284.950043, Likelihood Loss 268.246277, KL Loss 3.340754
# Epoch 91/100, Batch 11/50, Total Loss 253.340881, Likelihood Loss 233.543549, KL Loss 3.959467
# Epoch 91/100, Batch 21/50, Total Loss 214.347595, Likelihood Loss 200.626541, KL Loss 2.744210
# Epoch 91/100, Batch 31/50, Total Loss 254.005508, Likelihood Loss 236.439575, KL Loss 3.513187
# Epoch 91/100, Batch 41/50, Total Loss 212.962326, Likelihood Loss 197.593628, KL Loss 3.073739
# ====================================================
#
#
# Epoch 91/100, Train Total Loss 323.106659, Eval Total Loss 725.349731
#
#
# ====================================================
# Epoch 92/100, Batch 1/50, Total Loss 428.141205, Likelihood Loss 411.249542, KL Loss 3.378332
# Epoch 92/100, Batch 11/50, Total Loss 223.588867, Likelihood Loss 203.494171, KL Loss 4.018938
# Epoch 92/100, Batch 21/50, Total Loss 242.496521, Likelihood Loss 227.557053, KL Loss 2.987893
# Epoch 92/100, Batch 31/50, Total Loss 262.909515, Likelihood Loss 247.033508, KL Loss 3.175200
# Epoch 92/100, Batch 41/50, Total Loss 512.059875, Likelihood Loss 494.004578, KL Loss 3.611064
# ====================================================
#
#
# Epoch 92/100, Train Total Loss 258.187286, Eval Total Loss 657.729248
#
#
# ====================================================
# Epoch 93/100, Batch 1/50, Total Loss 310.698395, Likelihood Loss 283.344025, KL Loss 5.470876
# Epoch 93/100, Batch 11/50, Total Loss 223.132309, Likelihood Loss 188.277679, KL Loss 6.970926
# Epoch 93/100, Batch 21/50, Total Loss 242.653397, Likelihood Loss 219.111160, KL Loss 4.708447
# Epoch 93/100, Batch 31/50, Total Loss 228.861267, Likelihood Loss 210.669830, KL Loss 3.638287
# Epoch 93/100, Batch 41/50, Total Loss 257.410187, Likelihood Loss 236.602386, KL Loss 4.161561
# ====================================================
#
#
# Epoch 93/100, Train Total Loss 228.234695, Eval Total Loss 602.947388
#
#
# ====================================================
# Epoch 94/100, Batch 1/50, Total Loss 259.175262, Likelihood Loss 238.948898, KL Loss 4.045271
# Epoch 94/100, Batch 11/50, Total Loss 204.747574, Likelihood Loss 182.077087, KL Loss 4.534098
# Epoch 94/100, Batch 21/50, Total Loss 299.274841, Likelihood Loss 280.174255, KL Loss 3.820119
# Epoch 94/100, Batch 31/50, Total Loss 176.295502, Likelihood Loss 161.672394, KL Loss 2.924621
# Epoch 94/100, Batch 41/50, Total Loss 358.008820, Likelihood Loss 338.388428, KL Loss 3.924077
# ====================================================
#
#
# Epoch 94/100, Train Total Loss 271.028595, Eval Total Loss 534.876526
#
#
# ====================================================
# Epoch 95/100, Batch 1/50, Total Loss 247.748825, Likelihood Loss 231.148941, KL Loss 3.319977
# Epoch 95/100, Batch 11/50, Total Loss 243.194366, Likelihood Loss 222.754303, KL Loss 4.088012
# Epoch 95/100, Batch 21/50, Total Loss 254.240753, Likelihood Loss 238.192993, KL Loss 3.209553
# Epoch 95/100, Batch 31/50, Total Loss 226.515884, Likelihood Loss 212.291641, KL Loss 2.844849
# Epoch 95/100, Batch 41/50, Total Loss 199.710281, Likelihood Loss 182.793793, KL Loss 3.383296
# ====================================================
#
#
# Epoch 95/100, Train Total Loss 259.506195, Eval Total Loss 576.313049
#
#
# ====================================================
# Epoch 96/100, Batch 1/50, Total Loss 263.463715, Likelihood Loss 244.917969, KL Loss 3.709149
# Epoch 96/100, Batch 11/50, Total Loss 213.687836, Likelihood Loss 197.463654, KL Loss 3.244837
# Epoch 96/100, Batch 21/50, Total Loss 199.299316, Likelihood Loss 181.934189, KL Loss 3.473025
# Epoch 96/100, Batch 31/50, Total Loss 184.463974, Likelihood Loss 172.226593, KL Loss 2.447477
# Epoch 96/100, Batch 41/50, Total Loss 185.457718, Likelihood Loss 167.582306, KL Loss 3.575082
# ====================================================
#
#
# Epoch 96/100, Train Total Loss 180.518661, Eval Total Loss 537.401001
#
#
# ====================================================
# Epoch 97/100, Batch 1/50, Total Loss 190.853241, Likelihood Loss 174.660141, KL Loss 3.238619
# Epoch 97/100, Batch 11/50, Total Loss 250.230270, Likelihood Loss 237.277405, KL Loss 2.590574
# Epoch 97/100, Batch 21/50, Total Loss 193.294022, Likelihood Loss 176.050720, KL Loss 3.448662
# Epoch 97/100, Batch 31/50, Total Loss 261.750244, Likelihood Loss 248.154068, KL Loss 2.719235
# Epoch 97/100, Batch 41/50, Total Loss 371.105988, Likelihood Loss 349.962402, KL Loss 4.228720
# ====================================================
#
#
# Epoch 97/100, Train Total Loss 200.770111, Eval Total Loss 499.093903
#
#
# ====================================================
# Epoch 98/100, Batch 1/50, Total Loss 165.240311, Likelihood Loss 148.955933, KL Loss 3.256875
# Epoch 98/100, Batch 11/50, Total Loss 259.285461, Likelihood Loss 245.753754, KL Loss 2.706343
# Epoch 98/100, Batch 21/50, Total Loss 211.144073, Likelihood Loss 188.895111, KL Loss 4.449793
# Epoch 98/100, Batch 31/50, Total Loss 282.369293, Likelihood Loss 266.548340, KL Loss 3.164190
# Epoch 98/100, Batch 41/50, Total Loss 164.821136, Likelihood Loss 149.180069, KL Loss 3.128212
# ====================================================
#
#
# Epoch 98/100, Train Total Loss 423.341339, Eval Total Loss 620.870667
#
#
# ====================================================
# Epoch 99/100, Batch 1/50, Total Loss 338.515747, Likelihood Loss 323.378571, KL Loss 3.027434
# Epoch 99/100, Batch 11/50, Total Loss 225.978699, Likelihood Loss 212.399368, KL Loss 2.715865
# Epoch 99/100, Batch 21/50, Total Loss 307.229156, Likelihood Loss 285.117188, KL Loss 4.422396
# Epoch 99/100, Batch 31/50, Total Loss 216.560974, Likelihood Loss 202.745941, KL Loss 2.763006
# Epoch 99/100, Batch 41/50, Total Loss 230.453720, Likelihood Loss 218.167328, KL Loss 2.457278
# ====================================================
#
#
# Epoch 99/100, Train Total Loss 247.291412, Eval Total Loss 674.291931
#
#
# ====================================================
# Epoch 100/100, Batch 1/50, Total Loss 299.560211, Likelihood Loss 285.498962, KL Loss 2.812251
# Epoch 100/100, Batch 11/50, Total Loss 258.613434, Likelihood Loss 240.865189, KL Loss 3.549649
# Epoch 100/100, Batch 21/50, Total Loss 229.519974, Likelihood Loss 211.660645, KL Loss 3.571867
# Epoch 100/100, Batch 31/50, Total Loss 176.902710, Likelihood Loss 162.889526, KL Loss 2.802636
# Epoch 100/100, Batch 41/50, Total Loss 165.730240, Likelihood Loss 153.473267, KL Loss 2.451394
# ====================================================
#
#
# Epoch 100/100, Train Total Loss 166.500534, Eval Total Loss 548.013977
#
#
# ====================================================
