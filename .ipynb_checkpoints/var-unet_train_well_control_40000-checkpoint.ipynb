# %%
import numpy as np
# import vunet
import vunet_simple as vunet
import os
os.environ["CUDA_VISIBLE_DEVICES"]="0"
from keras import backend as K
from keras.layers import Input
from keras.models import Model
from keras.optimizers import Adam
from keras.callbacks import TensorBoard
import h5py
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.set_cmap('jet')

# %%
import tensorflow as tf
from keras import backend as K

# tf.session specification
# TensorFlow wizardry
config = tf.ConfigProto()

# Don't pre-allocate memory; allocate as-needed
config.gpu_options.allow_growth = True

# Only allow a total of half the GPU memory to be allocated
config.gpu_options.per_process_gpu_memory_fraction = 0.85

# Create a session with the above options specified.
K.tensorflow_backend.set_session(tf.Session(config=config))

# %% [markdown]
# # Load data

# %%
output_dir = 'saved_models/'
case_string = 'well_control_128x128'

# %%
data_dir = '/data/cees/gegewen/well_control_data/'

hf_r = h5py.File(data_dir + 'train_' + case_string + '_40000.hdf5', 'r')
# hf_r = h5py.File(data_dir + 'train_' + case_string + '_400.hdf5', 'r')
train_x = np.array(hf_r.get('k'))
train_y = np.array(hf_r.get('S'))
hf_r.close()

# %%
hf_w = h5py.File(data_dir + 'test_' + case_string + '_8000.hdf5', 'r')
# hf_w = h5py.File(data_dir + 'test_' + case_string + '_80.hdf5', 'r')
test_x = np.array(hf_w.get('k'))
test_y = np.array(hf_w.get('S'))
hf_w.close()

# %%
print('train_x shape is ', train_x.shape)
print('train_y shape is ', train_y.shape)
print('test_x shape is ', test_x.shape)
print('test_y shape is ', test_y.shape)
# Out:
# train_x shape is  (40000, 128, 128, 2)
# train_y shape is  (40000, 128, 128, 1)
# test_x shape is  (8000, 128, 128, 2)
# test_y shape is  (8000, 128, 128, 1)

# %%
train_x = train_x[:10000, ...]
train_y = train_y[:10000, ...]
test_x = test_x[:100, ...]
test_y = test_y[:100, ...]
print('train_x shape is ', train_x.shape)
print('train_y shape is ', train_y.shape)
print('test_x shape ', test_x.shape)
print('test_y shape ', test_y.shape)
# Out:
# train_x shape is  (10000, 128, 128, 2)
# train_y shape is  (10000, 128, 128, 1)
# test_x shape  (100, 128, 128, 2)
# test_y shape  (100, 128, 128, 1)

# %% [markdown]
# ### Plot training dataset

# %%
for k in range(5):
    plt.figure(k,figsize=(15,3))
    
    plt.subplot(1,5,1)
    plt.title('k (mD)')
    plt.imshow(train_x[k, :, :, 0] * 1000)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,2)
    plt.title('Injection (day)')
    plot_k = train_x[k, :, :, 1]
    plt.imshow(plot_k)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,3)
    plt.title('SG (true)')
    plt.imshow(train_y[k, :, :, 0].reshape(128, 128))
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Plot test dataset

# %%
for k in range(5):
    plt.figure(k,figsize=(15,3))
    
    plt.subplot(1,5,1)
    plt.title('k (mD)')
    plt.imshow(test_x[k, :, :, 0] * 1000)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,2)
    plt.title('Injection (day)')
    plot_k = test_x[k, :, :, 1]
    plt.imshow(plot_k)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,3)
    plt.title('SG (true)')
    plt.imshow(test_y[k, :, :, 0].reshape(128, 128))
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Training starts here
# ### Bypass this part if you only want test

# %%
# from importlib import reload
# reload(vunet)
# Out:
# <module 'vunet_simple' from '/data/cees/zjin/cs231n/project/var-unet/vunet_simple.py'>

# %%
input_shape = (128, 128, 2)
output_shape = (128, 128, 1)

# %%
## Original v-unet implementation
# enc_up, hidden_shapes = vunet.create_enc_up(input_shape, n_scales = 5, n_res_blk = 1)
# # enc_up.summary()

# latent_shape = hidden_shapes[-1]

# enc_down = vunet.create_enc_down(latent_shape)
# # enc_down.summary()

# dec_up = vunet.create_dec_up(output_shape, n_scales = 5, n_res_blk = 1) # only c input
# # dec_up.summary()

# dec_down = vunet.create_dec_down(hidden_shapes, latent_shape, n_scales = 5, n_res_blk = 1)
# # dec_down.summary()

# %%
# change the role of enc_up and dec_up
enc_up, hidden_shapes = vunet.create_enc_up(output_shape, n_scales = 5)
enc_down = vunet.create_enc_down(hidden_shapes[-1])
dec_up = vunet.create_dec_up(input_shape, n_scales = 5) # only c input
dec_down = vunet.create_dec_down(hidden_shapes, hidden_shapes[-1], n_scales = 5)

# %% [markdown]
# #### Train forward pass v-unet

# %%
# xc = Input(shape=input_shape) # perm + well location
# c = Input(shape=output_shape) # well location

# hs = enc_up(xc)
# z_posterior_sample, z_posterior_mean = enc_down(hs[-1])
# gs = dec_up(c)
# # x_hat, z_piror_sample, z_piror_mean = dec_down([z_posterior_sample, *gs])
# x_hat, z_piror_sample, z_piror_mean = dec_down([z_posterior_mean, *gs])

# %%
xc = Input(shape=input_shape) # perm + well location
c = Input(shape=output_shape) # well location

hs = enc_up(c)
z_posterior_sample, z_posterior_mean = enc_down(hs[-1])
gs = dec_up(xc)
x_hat, z_piror_sample, z_piror_mean = dec_down([z_posterior_mean, *gs])

# %%
def likelihood_loss(x, x_hat):
    '''
    Reconstruction loss, L2 norm
    
    '''
    v = 0.1
    return K.mean(K.sum((K.batch_flatten(x) - K.batch_flatten(x_hat)) ** 2 / (2*v), axis=-1))

def latent_kl_loss(q, p):
    mean1 = q
    mean2 = p
    
    kl = 0.5 * (mean2 - mean1)**2
    kl = K.sum(kl, axis = [1,2,3])
    kl = K.mean(kl)
    return kl

# %%
x = Input(shape=output_shape) # target saturation

likelihood_loss_value = likelihood_loss(x, x_hat)
kl_loss = latent_kl_loss(z_posterior_mean, z_piror_mean)
kl_weight = 5.0
total_loss = likelihood_loss_value + kl_weight * kl_loss

# %%
epoch = 150
learning_rate = 5e-4
train_nr = train_x.shape[0]
test_nr = test_x.shape[0]
batch_size = 16
num_batch = int(train_nr/batch_size)

# %%
opt = Adam(lr=learning_rate)

trainable_weights = enc_up.trainable_weights + enc_down.trainable_weights + dec_up.trainable_weights + dec_down.trainable_weights

updates = opt.get_updates(total_loss, trainable_weights)

iterate = K.function([xc, c, x], [total_loss, likelihood_loss_value, kl_loss], updates=updates)

eval_loss = K.function([xc, c, x], [total_loss])

# %%
train_loss_record = []
test_loss_record =[]

for e in range(epoch):
    for ib in range(num_batch):
        ind0 = ib * batch_size
        x_batch = train_x[ind0:ind0+batch_size, ...]
        y_batch = train_y[ind0:ind0+batch_size, ...]
        
        train_losses = iterate([x_batch, x_batch[:,:,:,[1]], y_batch])
#         print(train_losses)
        if ib % 100 == 0:
            print('Epoch %d/%d, Batch %d/%d, Total Loss %f, Likelihood Loss %f, KL Loss %f' % (e+1, epoch, ib+1, num_batch, train_losses[0], train_losses[1], train_losses[2]))
        
        eval_losses = eval_loss([test_x, test_x[:,:,:,[1]], test_y])
        
    train_loss_record.append(train_losses[0])
    test_loss_record.append(eval_losses[0])
    
    print('====================================================')
    print('\n')
    print('Epoch %d/%d, Train Total Loss %f, Eval Total Loss %f' % (e + 1, epoch, train_losses[0], eval_losses[0]))
    print('\n')
    print('====================================================')
enc_up.save_weights(output_dir + 'enc_up_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
enc_down.save_weights(output_dir + 'enc_down_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
dec_up.save_weights(output_dir + 'dec_up_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
dec_down.save_weights(output_dir + 'dec_down_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
# Out:
# Epoch 1/150, Batch 1/625, Total Loss 3773.170166, Likelihood Loss 3770.324463, KL Loss 0.569148
# Epoch 1/150, Batch 101/625, Total Loss 433.230896, Likelihood Loss 428.707245, KL Loss 0.904728
# Epoch 1/150, Batch 201/625, Total Loss 194.274048, Likelihood Loss 192.279724, KL Loss 0.398866
# Epoch 1/150, Batch 301/625, Total Loss 115.707779, Likelihood Loss 114.138023, KL Loss 0.313951
# Epoch 1/150, Batch 401/625, Total Loss 141.540268, Likelihood Loss 139.697754, KL Loss 0.368503
# Epoch 1/150, Batch 501/625, Total Loss 114.769173, Likelihood Loss 113.275635, KL Loss 0.298707
# Epoch 1/150, Batch 601/625, Total Loss 103.760284, Likelihood Loss 101.950455, KL Loss 0.361965
# ====================================================
#
#
# Epoch 1/150, Train Total Loss 100.341141, Eval Total Loss 130.092026
#
#
# ====================================================
# Epoch 2/150, Batch 1/625, Total Loss 126.689270, Likelihood Loss 124.836197, KL Loss 0.370614
# Epoch 2/150, Batch 101/625, Total Loss 148.630203, Likelihood Loss 147.026215, KL Loss 0.320797
# Epoch 2/150, Batch 201/625, Total Loss 79.713608, Likelihood Loss 78.162697, KL Loss 0.310183
# Epoch 2/150, Batch 301/625, Total Loss 58.697285, Likelihood Loss 57.616623, KL Loss 0.216132
# Epoch 2/150, Batch 401/625, Total Loss 90.694656, Likelihood Loss 89.055504, KL Loss 0.327830
# Epoch 2/150, Batch 501/625, Total Loss 79.837173, Likelihood Loss 78.664360, KL Loss 0.234562
# Epoch 2/150, Batch 601/625, Total Loss 75.677284, Likelihood Loss 74.127792, KL Loss 0.309898
# ====================================================
#
#
# Epoch 2/150, Train Total Loss 72.494911, Eval Total Loss 90.274612
#
#
# ====================================================
# Epoch 3/150, Batch 1/625, Total Loss 86.192352, Likelihood Loss 84.538933, KL Loss 0.330684
# Epoch 3/150, Batch 101/625, Total Loss 92.316071, Likelihood Loss 90.952599, KL Loss 0.272695
# Epoch 3/150, Batch 201/625, Total Loss 57.439865, Likelihood Loss 56.013165, KL Loss 0.285340
# Epoch 3/150, Batch 301/625, Total Loss 44.939537, Likelihood Loss 43.947613, KL Loss 0.198385
# Epoch 3/150, Batch 401/625, Total Loss 97.145180, Likelihood Loss 95.515396, KL Loss 0.325957
# Epoch 3/150, Batch 501/625, Total Loss 51.203655, Likelihood Loss 50.051582, KL Loss 0.230415
# Epoch 3/150, Batch 601/625, Total Loss 61.073570, Likelihood Loss 59.479065, KL Loss 0.318901
# ====================================================
#
#
# Epoch 3/150, Train Total Loss 52.195400, Eval Total Loss 57.936516
#
#
# ====================================================
# Epoch 4/150, Batch 1/625, Total Loss 56.342819, Likelihood Loss 54.635830, KL Loss 0.341398
# Epoch 4/150, Batch 101/625, Total Loss 74.422653, Likelihood Loss 73.035202, KL Loss 0.277491
# Epoch 4/150, Batch 201/625, Total Loss 48.336765, Likelihood Loss 47.057571, KL Loss 0.255839
# Epoch 4/150, Batch 301/625, Total Loss 40.014366, Likelihood Loss 39.110977, KL Loss 0.180678
# Epoch 4/150, Batch 401/625, Total Loss 72.560913, Likelihood Loss 71.043106, KL Loss 0.303562
# Epoch 4/150, Batch 501/625, Total Loss 41.973419, Likelihood Loss 40.879902, KL Loss 0.218703
# Epoch 4/150, Batch 601/625, Total Loss 44.918587, Likelihood Loss 43.487869, KL Loss 0.286143
# ====================================================
#
#
# Epoch 4/150, Train Total Loss 50.502670, Eval Total Loss 44.621746
#
#
# ====================================================
# Epoch 5/150, Batch 1/625, Total Loss 41.398354, Likelihood Loss 39.817184, KL Loss 0.316233
# Epoch 5/150, Batch 101/625, Total Loss 56.504456, Likelihood Loss 55.108280, KL Loss 0.279235
# Epoch 5/150, Batch 201/625, Total Loss 38.652397, Likelihood Loss 37.343304, KL Loss 0.261819
# Epoch 5/150, Batch 301/625, Total Loss 32.756882, Likelihood Loss 31.874195, KL Loss 0.176537
# Epoch 5/150, Batch 401/625, Total Loss 54.840824, Likelihood Loss 53.464661, KL Loss 0.275233
# Epoch 5/150, Batch 501/625, Total Loss 31.558384, Likelihood Loss 30.356434, KL Loss 0.240390
# Epoch 5/150, Batch 601/625, Total Loss 34.187534, Likelihood Loss 32.675388, KL Loss 0.302429
# ====================================================
#
#
# Epoch 5/150, Train Total Loss 37.328064, Eval Total Loss 43.891998
#
#
# ====================================================
# Epoch 6/150, Batch 1/625, Total Loss 43.977825, Likelihood Loss 42.270828, KL Loss 0.341399
# Epoch 6/150, Batch 101/625, Total Loss 37.457138, Likelihood Loss 36.075218, KL Loss 0.276384
# Epoch 6/150, Batch 201/625, Total Loss 33.703499, Likelihood Loss 32.354885, KL Loss 0.269723
# Epoch 6/150, Batch 301/625, Total Loss 25.702627, Likelihood Loss 24.927843, KL Loss 0.154957
# Epoch 6/150, Batch 401/625, Total Loss 37.775047, Likelihood Loss 36.516418, KL Loss 0.251725
# Epoch 6/150, Batch 501/625, Total Loss 30.801918, Likelihood Loss 29.732971, KL Loss 0.213789
# Epoch 6/150, Batch 601/625, Total Loss 30.340866, Likelihood Loss 28.942270, KL Loss 0.279719
# ====================================================
#
#
# Epoch 6/150, Train Total Loss 33.608799, Eval Total Loss 38.814644
#
#
# ====================================================
# Epoch 7/150, Batch 1/625, Total Loss 38.323719, Likelihood Loss 36.761883, KL Loss 0.312367
# Epoch 7/150, Batch 101/625, Total Loss 34.119785, Likelihood Loss 32.888107, KL Loss 0.246336
# Epoch 7/150, Batch 201/625, Total Loss 33.760643, Likelihood Loss 32.614082, KL Loss 0.229312
# Epoch 7/150, Batch 301/625, Total Loss 29.675339, Likelihood Loss 28.953264, KL Loss 0.144415
# Epoch 7/150, Batch 401/625, Total Loss 32.382515, Likelihood Loss 31.174810, KL Loss 0.241541
# Epoch 7/150, Batch 501/625, Total Loss 31.884588, Likelihood Loss 30.853403, KL Loss 0.206237
# Epoch 7/150, Batch 601/625, Total Loss 71.076881, Likelihood Loss 69.734764, KL Loss 0.268423
# ====================================================
#
#
# Epoch 7/150, Train Total Loss 35.676708, Eval Total Loss 44.499817
#
#
# ====================================================
# Epoch 8/150, Batch 1/625, Total Loss 43.300743, Likelihood Loss 41.593231, KL Loss 0.341503
# Epoch 8/150, Batch 101/625, Total Loss 38.158615, Likelihood Loss 36.907944, KL Loss 0.250134
# Epoch 8/150, Batch 201/625, Total Loss 33.489777, Likelihood Loss 32.185318, KL Loss 0.260892
# Epoch 8/150, Batch 301/625, Total Loss 23.742970, Likelihood Loss 22.986288, KL Loss 0.151336
# Epoch 8/150, Batch 401/625, Total Loss 45.328167, Likelihood Loss 44.105751, KL Loss 0.244483
# Epoch 8/150, Batch 501/625, Total Loss 25.142433, Likelihood Loss 24.117222, KL Loss 0.205042
# Epoch 8/150, Batch 601/625, Total Loss 27.156279, Likelihood Loss 25.803772, KL Loss 0.270501
# ====================================================
#
#
# Epoch 8/150, Train Total Loss 45.435150, Eval Total Loss 36.082298
#
#
# ====================================================
# Epoch 9/150, Batch 1/625, Total Loss 32.540485, Likelihood Loss 30.901913, KL Loss 0.327715
# Epoch 9/150, Batch 101/625, Total Loss 33.967476, Likelihood Loss 32.720184, KL Loss 0.249458
# Epoch 9/150, Batch 201/625, Total Loss 29.397099, Likelihood Loss 28.161816, KL Loss 0.247057
# Epoch 9/150, Batch 301/625, Total Loss 19.836246, Likelihood Loss 19.082474, KL Loss 0.150755
# Epoch 9/150, Batch 401/625, Total Loss 50.567226, Likelihood Loss 49.364388, KL Loss 0.240567
# Epoch 9/150, Batch 501/625, Total Loss 22.978010, Likelihood Loss 21.893881, KL Loss 0.216826
# Epoch 9/150, Batch 601/625, Total Loss 39.884998, Likelihood Loss 38.490887, KL Loss 0.278822
# ====================================================
#
#
# Epoch 9/150, Train Total Loss 27.945856, Eval Total Loss 33.519035
#
#
# ====================================================
# Epoch 10/150, Batch 1/625, Total Loss 30.112827, Likelihood Loss 28.519363, KL Loss 0.318693
# Epoch 10/150, Batch 101/625, Total Loss 42.086399, Likelihood Loss 40.726406, KL Loss 0.271999
# Epoch 10/150, Batch 201/625, Total Loss 25.959307, Likelihood Loss 24.703560, KL Loss 0.251149
# Epoch 10/150, Batch 301/625, Total Loss 21.214293, Likelihood Loss 20.457123, KL Loss 0.151434
# Epoch 10/150, Batch 401/625, Total Loss 30.244934, Likelihood Loss 29.045694, KL Loss 0.239848
# Epoch 10/150, Batch 501/625, Total Loss 20.652832, Likelihood Loss 19.716469, KL Loss 0.187273
# Epoch 10/150, Batch 601/625, Total Loss 39.013084, Likelihood Loss 37.673035, KL Loss 0.268010
# ====================================================
#
#
# Epoch 10/150, Train Total Loss 25.639183, Eval Total Loss 32.725121
#
#
# ====================================================
# Epoch 11/150, Batch 1/625, Total Loss 39.816299, Likelihood Loss 38.178009, KL Loss 0.327658
# Epoch 11/150, Batch 101/625, Total Loss 29.297905, Likelihood Loss 28.034449, KL Loss 0.252691
# Epoch 11/150, Batch 201/625, Total Loss 20.901123, Likelihood Loss 19.759523, KL Loss 0.228320
# Epoch 11/150, Batch 301/625, Total Loss 20.194551, Likelihood Loss 19.448315, KL Loss 0.149247
# Epoch 11/150, Batch 401/625, Total Loss 27.042662, Likelihood Loss 25.865589, KL Loss 0.235415
# Epoch 11/150, Batch 501/625, Total Loss 19.735676, Likelihood Loss 18.875221, KL Loss 0.172091
# Epoch 11/150, Batch 601/625, Total Loss 29.655403, Likelihood Loss 28.263033, KL Loss 0.278474
# ====================================================
#
#
# Epoch 11/150, Train Total Loss 38.529266, Eval Total Loss 38.281937
#
#
# ====================================================
# Epoch 12/150, Batch 1/625, Total Loss 35.259052, Likelihood Loss 33.651421, KL Loss 0.321526
# Epoch 12/150, Batch 101/625, Total Loss 24.927351, Likelihood Loss 23.668732, KL Loss 0.251724
# Epoch 12/150, Batch 201/625, Total Loss 19.409929, Likelihood Loss 18.311676, KL Loss 0.219651
# Epoch 12/150, Batch 301/625, Total Loss 18.476408, Likelihood Loss 17.781433, KL Loss 0.138995
# Epoch 12/150, Batch 401/625, Total Loss 29.407454, Likelihood Loss 28.265759, KL Loss 0.228339
# Epoch 12/150, Batch 501/625, Total Loss 20.962048, Likelihood Loss 20.036369, KL Loss 0.185136
# Epoch 12/150, Batch 601/625, Total Loss 31.290396, Likelihood Loss 30.070784, KL Loss 0.243923
# ====================================================
#
#
# Epoch 12/150, Train Total Loss 29.014851, Eval Total Loss 27.995205
#
#
# ====================================================
# Epoch 13/150, Batch 1/625, Total Loss 27.368641, Likelihood Loss 25.868324, KL Loss 0.300063
# Epoch 13/150, Batch 101/625, Total Loss 22.561916, Likelihood Loss 21.277485, KL Loss 0.256886
# Epoch 13/150, Batch 201/625, Total Loss 27.067787, Likelihood Loss 25.756559, KL Loss 0.262246
# Epoch 13/150, Batch 301/625, Total Loss 18.481709, Likelihood Loss 17.834358, KL Loss 0.129470
# Epoch 13/150, Batch 401/625, Total Loss 24.074875, Likelihood Loss 22.794518, KL Loss 0.256071
# Epoch 13/150, Batch 501/625, Total Loss 18.408195, Likelihood Loss 17.500292, KL Loss 0.181581
# Epoch 13/150, Batch 601/625, Total Loss 36.195675, Likelihood Loss 34.865456, KL Loss 0.266044
# ====================================================
#
#
# Epoch 13/150, Train Total Loss 25.690840, Eval Total Loss 28.629539
#
#
# ====================================================
# Epoch 14/150, Batch 1/625, Total Loss 29.967619, Likelihood Loss 28.417667, KL Loss 0.309990
# Epoch 14/150, Batch 101/625, Total Loss 26.501816, Likelihood Loss 25.212276, KL Loss 0.257908
# Epoch 14/150, Batch 201/625, Total Loss 27.157509, Likelihood Loss 25.822250, KL Loss 0.267052
# Epoch 14/150, Batch 301/625, Total Loss 22.130445, Likelihood Loss 21.419880, KL Loss 0.142113
# Epoch 14/150, Batch 401/625, Total Loss 27.003004, Likelihood Loss 25.752689, KL Loss 0.250063
# Epoch 14/150, Batch 501/625, Total Loss 19.673944, Likelihood Loss 18.683041, KL Loss 0.198181
# Epoch 14/150, Batch 601/625, Total Loss 19.375668, Likelihood Loss 18.144812, KL Loss 0.246171
# ====================================================
#
#
# Epoch 14/150, Train Total Loss 23.018063, Eval Total Loss 29.619600
#
#
# ====================================================
# Epoch 15/150, Batch 1/625, Total Loss 27.215673, Likelihood Loss 25.932810, KL Loss 0.256573
# Epoch 15/150, Batch 101/625, Total Loss 22.645315, Likelihood Loss 21.388781, KL Loss 0.251307
# Epoch 15/150, Batch 201/625, Total Loss 23.503599, Likelihood Loss 22.269430, KL Loss 0.246834
# Epoch 15/150, Batch 301/625, Total Loss 24.462200, Likelihood Loss 23.763187, KL Loss 0.139803
# Epoch 15/150, Batch 401/625, Total Loss 32.542290, Likelihood Loss 31.447754, KL Loss 0.218907
# Epoch 15/150, Batch 501/625, Total Loss 20.828741, Likelihood Loss 19.798847, KL Loss 0.205979
# Epoch 15/150, Batch 601/625, Total Loss 18.290453, Likelihood Loss 17.173033, KL Loss 0.223484
# ====================================================
#
#
# Epoch 15/150, Train Total Loss 22.058075, Eval Total Loss 27.287657
#
#
# ====================================================
# Epoch 16/150, Batch 1/625, Total Loss 22.702343, Likelihood Loss 21.365158, KL Loss 0.267437
# Epoch 16/150, Batch 101/625, Total Loss 28.636395, Likelihood Loss 27.467361, KL Loss 0.233806
# Epoch 16/150, Batch 201/625, Total Loss 20.093470, Likelihood Loss 18.904125, KL Loss 0.237869
# Epoch 16/150, Batch 301/625, Total Loss 18.624462, Likelihood Loss 17.951481, KL Loss 0.134596
# Epoch 16/150, Batch 401/625, Total Loss 23.373003, Likelihood Loss 22.352932, KL Loss 0.204014
# Epoch 16/150, Batch 501/625, Total Loss 14.749745, Likelihood Loss 13.872028, KL Loss 0.175543
# Epoch 16/150, Batch 601/625, Total Loss 19.541798, Likelihood Loss 18.434063, KL Loss 0.221547
# ====================================================
#
#
# Epoch 16/150, Train Total Loss 21.083439, Eval Total Loss 28.432224
#
#
# ====================================================
# Epoch 17/150, Batch 1/625, Total Loss 25.182926, Likelihood Loss 23.987820, KL Loss 0.239021
# Epoch 17/150, Batch 101/625, Total Loss 22.666199, Likelihood Loss 21.440798, KL Loss 0.245080
# Epoch 17/150, Batch 201/625, Total Loss 22.048599, Likelihood Loss 20.911669, KL Loss 0.227386
# Epoch 17/150, Batch 301/625, Total Loss 17.417856, Likelihood Loss 16.764687, KL Loss 0.130634
# Epoch 17/150, Batch 401/625, Total Loss 24.420397, Likelihood Loss 23.328909, KL Loss 0.218297
# Epoch 17/150, Batch 501/625, Total Loss 18.441763, Likelihood Loss 17.528694, KL Loss 0.182614
# Epoch 17/150, Batch 601/625, Total Loss 19.068048, Likelihood Loss 18.036530, KL Loss 0.206304
# ====================================================
#
#
# Epoch 17/150, Train Total Loss 24.174849, Eval Total Loss 30.473692
#
#
# ====================================================
# Epoch 18/150, Batch 1/625, Total Loss 23.707178, Likelihood Loss 22.487911, KL Loss 0.243853
# Epoch 18/150, Batch 101/625, Total Loss 21.499002, Likelihood Loss 20.333164, KL Loss 0.233168
# Epoch 18/150, Batch 201/625, Total Loss 19.545595, Likelihood Loss 18.417385, KL Loss 0.225642
# Epoch 18/150, Batch 301/625, Total Loss 25.770258, Likelihood Loss 25.110048, KL Loss 0.132042
# Epoch 18/150, Batch 401/625, Total Loss 26.193485, Likelihood Loss 25.070156, KL Loss 0.224666
# Epoch 18/150, Batch 501/625, Total Loss 19.197409, Likelihood Loss 18.233068, KL Loss 0.192868
# Epoch 18/150, Batch 601/625, Total Loss 20.754272, Likelihood Loss 19.646378, KL Loss 0.221579
# ====================================================
#
#
# Epoch 18/150, Train Total Loss 23.036291, Eval Total Loss 27.696558
#
#
# ====================================================
# Epoch 19/150, Batch 1/625, Total Loss 20.254002, Likelihood Loss 18.960009, KL Loss 0.258799
# Epoch 19/150, Batch 101/625, Total Loss 22.414778, Likelihood Loss 21.247326, KL Loss 0.233490
# Epoch 19/150, Batch 201/625, Total Loss 19.246887, Likelihood Loss 18.059109, KL Loss 0.237556
# Epoch 19/150, Batch 301/625, Total Loss 18.192966, Likelihood Loss 17.537399, KL Loss 0.131114
# Epoch 19/150, Batch 401/625, Total Loss 21.977449, Likelihood Loss 20.898499, KL Loss 0.215790
# Epoch 19/150, Batch 501/625, Total Loss 17.934879, Likelihood Loss 17.104921, KL Loss 0.165992
# Epoch 19/150, Batch 601/625, Total Loss 22.402151, Likelihood Loss 21.338398, KL Loss 0.212750
# ====================================================
#
#
# Epoch 19/150, Train Total Loss 25.308086, Eval Total Loss 29.679317
#
#
# ====================================================
# Epoch 20/150, Batch 1/625, Total Loss 20.561909, Likelihood Loss 19.274914, KL Loss 0.257399
# Epoch 20/150, Batch 101/625, Total Loss 16.971443, Likelihood Loss 15.765093, KL Loss 0.241270
# Epoch 20/150, Batch 201/625, Total Loss 22.709854, Likelihood Loss 21.506729, KL Loss 0.240625
# Epoch 20/150, Batch 301/625, Total Loss 19.009218, Likelihood Loss 18.340767, KL Loss 0.133690
# Epoch 20/150, Batch 401/625, Total Loss 20.661819, Likelihood Loss 19.581718, KL Loss 0.216020
# Epoch 20/150, Batch 501/625, Total Loss 15.244494, Likelihood Loss 14.312754, KL Loss 0.186348
# Epoch 20/150, Batch 601/625, Total Loss 19.229656, Likelihood Loss 18.166309, KL Loss 0.212669
# ====================================================
#
#
# Epoch 20/150, Train Total Loss 25.508299, Eval Total Loss 23.770681
#
#
# ====================================================
# Epoch 21/150, Batch 1/625, Total Loss 20.088667, Likelihood Loss 18.700745, KL Loss 0.277585
# Epoch 21/150, Batch 101/625, Total Loss 18.907694, Likelihood Loss 17.763283, KL Loss 0.228882
# Epoch 21/150, Batch 201/625, Total Loss 18.755201, Likelihood Loss 17.551157, KL Loss 0.240809
# Epoch 21/150, Batch 301/625, Total Loss 16.402502, Likelihood Loss 15.820759, KL Loss 0.116349
# Epoch 21/150, Batch 401/625, Total Loss 33.346008, Likelihood Loss 32.332680, KL Loss 0.202666
# Epoch 21/150, Batch 501/625, Total Loss 16.316261, Likelihood Loss 15.454638, KL Loss 0.172325
# Epoch 21/150, Batch 601/625, Total Loss 17.153936, Likelihood Loss 16.203075, KL Loss 0.190172
# ====================================================
#
#
# Epoch 21/150, Train Total Loss 19.468699, Eval Total Loss 22.708790
#
#
# ====================================================
# Epoch 22/150, Batch 1/625, Total Loss 18.231300, Likelihood Loss 17.000931, KL Loss 0.246074
# Epoch 22/150, Batch 101/625, Total Loss 15.946901, Likelihood Loss 14.876566, KL Loss 0.214067
# Epoch 22/150, Batch 201/625, Total Loss 14.899160, Likelihood Loss 13.865139, KL Loss 0.206804
# Epoch 22/150, Batch 301/625, Total Loss 16.768581, Likelihood Loss 16.131603, KL Loss 0.127396
# Epoch 22/150, Batch 401/625, Total Loss 19.511377, Likelihood Loss 18.558428, KL Loss 0.190590
# Epoch 22/150, Batch 501/625, Total Loss 14.153627, Likelihood Loss 13.345707, KL Loss 0.161584
# Epoch 22/150, Batch 601/625, Total Loss 17.023046, Likelihood Loss 16.096012, KL Loss 0.185407
# ====================================================
#
#
# Epoch 22/150, Train Total Loss 15.811641, Eval Total Loss 21.486292
#
#
# ====================================================
# Epoch 23/150, Batch 1/625, Total Loss 15.613087, Likelihood Loss 14.484594, KL Loss 0.225699
# Epoch 23/150, Batch 101/625, Total Loss 15.057829, Likelihood Loss 13.996908, KL Loss 0.212184
# Epoch 23/150, Batch 201/625, Total Loss 12.567284, Likelihood Loss 11.596756, KL Loss 0.194105
# Epoch 23/150, Batch 301/625, Total Loss 13.276237, Likelihood Loss 12.701975, KL Loss 0.114852
# Epoch 23/150, Batch 401/625, Total Loss 19.107405, Likelihood Loss 18.223705, KL Loss 0.176740
# Epoch 23/150, Batch 501/625, Total Loss 13.677647, Likelihood Loss 12.945744, KL Loss 0.146381
# Epoch 23/150, Batch 601/625, Total Loss 18.515053, Likelihood Loss 17.584475, KL Loss 0.186116
# ====================================================
#
#
# Epoch 23/150, Train Total Loss 18.818491, Eval Total Loss 24.432356
#
#
# ====================================================
# Epoch 24/150, Batch 1/625, Total Loss 18.124916, Likelihood Loss 17.027382, KL Loss 0.219507
# Epoch 24/150, Batch 101/625, Total Loss 14.248023, Likelihood Loss 13.214052, KL Loss 0.206794
# Epoch 24/150, Batch 201/625, Total Loss 15.753863, Likelihood Loss 14.761119, KL Loss 0.198549
# Epoch 24/150, Batch 301/625, Total Loss 14.481842, Likelihood Loss 13.899232, KL Loss 0.116522
# Epoch 24/150, Batch 401/625, Total Loss 20.209372, Likelihood Loss 19.319471, KL Loss 0.177980
# Epoch 24/150, Batch 501/625, Total Loss 16.952574, Likelihood Loss 16.203648, KL Loss 0.149785
# Epoch 24/150, Batch 601/625, Total Loss 21.991064, Likelihood Loss 21.136929, KL Loss 0.170827
# ====================================================
#
#
# Epoch 24/150, Train Total Loss 16.774448, Eval Total Loss 21.419561
#
#
# ====================================================
# Epoch 25/150, Batch 1/625, Total Loss 15.856614, Likelihood Loss 14.776766, KL Loss 0.215970
# Epoch 25/150, Batch 101/625, Total Loss 21.466570, Likelihood Loss 20.475050, KL Loss 0.198304
# Epoch 25/150, Batch 201/625, Total Loss 13.995188, Likelihood Loss 13.065113, KL Loss 0.186015
# Epoch 25/150, Batch 301/625, Total Loss 16.281631, Likelihood Loss 15.709728, KL Loss 0.114381
# Epoch 25/150, Batch 401/625, Total Loss 20.572119, Likelihood Loss 19.662329, KL Loss 0.181958
# Epoch 25/150, Batch 501/625, Total Loss 16.891676, Likelihood Loss 16.206076, KL Loss 0.137120
# Epoch 25/150, Batch 601/625, Total Loss 15.653481, Likelihood Loss 14.702551, KL Loss 0.190186
# ====================================================
#
#
# Epoch 25/150, Train Total Loss 16.829933, Eval Total Loss 22.311371
#
#
# ====================================================
# Epoch 26/150, Batch 1/625, Total Loss 15.036572, Likelihood Loss 13.975149, KL Loss 0.212285
# Epoch 26/150, Batch 101/625, Total Loss 22.330008, Likelihood Loss 21.370670, KL Loss 0.191868
# Epoch 26/150, Batch 201/625, Total Loss 16.369322, Likelihood Loss 15.435963, KL Loss 0.186672
# Epoch 26/150, Batch 301/625, Total Loss 25.301189, Likelihood Loss 24.546955, KL Loss 0.150847
# Epoch 26/150, Batch 401/625, Total Loss 20.356268, Likelihood Loss 19.375250, KL Loss 0.196204
# Epoch 26/150, Batch 501/625, Total Loss 15.765656, Likelihood Loss 14.957151, KL Loss 0.161701
# Epoch 26/150, Batch 601/625, Total Loss 14.675407, Likelihood Loss 13.712618, KL Loss 0.192558
# ====================================================
#
#
# Epoch 26/150, Train Total Loss 19.220446, Eval Total Loss 24.991386
#
#
# ====================================================
# Epoch 27/150, Batch 1/625, Total Loss 17.597164, Likelihood Loss 16.444218, KL Loss 0.230589
# Epoch 27/150, Batch 101/625, Total Loss 17.758419, Likelihood Loss 16.713160, KL Loss 0.209052
# Epoch 27/150, Batch 201/625, Total Loss 14.515444, Likelihood Loss 13.504736, KL Loss 0.202142
# Epoch 27/150, Batch 301/625, Total Loss 16.860102, Likelihood Loss 16.231550, KL Loss 0.125710
# Epoch 27/150, Batch 401/625, Total Loss 19.997986, Likelihood Loss 19.017143, KL Loss 0.196169
# Epoch 27/150, Batch 501/625, Total Loss 15.356071, Likelihood Loss 14.531063, KL Loss 0.165002
# Epoch 27/150, Batch 601/625, Total Loss 16.151665, Likelihood Loss 15.193662, KL Loss 0.191600
# ====================================================
#
#
# Epoch 27/150, Train Total Loss 16.082344, Eval Total Loss 20.367683
#
#
# ====================================================
# Epoch 28/150, Batch 1/625, Total Loss 16.524906, Likelihood Loss 15.360762, KL Loss 0.232829
# Epoch 28/150, Batch 101/625, Total Loss 15.393235, Likelihood Loss 14.354294, KL Loss 0.207788
# Epoch 28/150, Batch 201/625, Total Loss 13.543488, Likelihood Loss 12.569384, KL Loss 0.194821
# Epoch 28/150, Batch 301/625, Total Loss 11.547091, Likelihood Loss 10.992231, KL Loss 0.110972
# Epoch 28/150, Batch 401/625, Total Loss 17.900707, Likelihood Loss 17.044621, KL Loss 0.171217
# Epoch 28/150, Batch 501/625, Total Loss 16.340996, Likelihood Loss 15.631973, KL Loss 0.141804
# Epoch 28/150, Batch 601/625, Total Loss 17.695169, Likelihood Loss 16.816175, KL Loss 0.175799
# ====================================================
#
#
# Epoch 28/150, Train Total Loss 15.109693, Eval Total Loss 20.549076
#
#
# ====================================================
# Epoch 29/150, Batch 1/625, Total Loss 16.648975, Likelihood Loss 15.609943, KL Loss 0.207806
# Epoch 29/150, Batch 101/625, Total Loss 13.411396, Likelihood Loss 12.455070, KL Loss 0.191265
# Epoch 29/150, Batch 201/625, Total Loss 12.533379, Likelihood Loss 11.676881, KL Loss 0.171300
# Epoch 29/150, Batch 301/625, Total Loss 12.805743, Likelihood Loss 12.280487, KL Loss 0.105051
# Epoch 29/150, Batch 401/625, Total Loss 17.621571, Likelihood Loss 16.749321, KL Loss 0.174450
# Epoch 29/150, Batch 501/625, Total Loss 14.024967, Likelihood Loss 13.332375, KL Loss 0.138518
# Epoch 29/150, Batch 601/625, Total Loss 11.666982, Likelihood Loss 10.810501, KL Loss 0.171296
# ====================================================
#
#
# Epoch 29/150, Train Total Loss 13.726924, Eval Total Loss 21.677896
#
#
# ====================================================
# Epoch 30/150, Batch 1/625, Total Loss 16.324785, Likelihood Loss 15.395586, KL Loss 0.185840
# Epoch 30/150, Batch 101/625, Total Loss 14.435468, Likelihood Loss 13.526524, KL Loss 0.181789
# Epoch 30/150, Batch 201/625, Total Loss 11.652348, Likelihood Loss 10.774496, KL Loss 0.175570
# Epoch 30/150, Batch 301/625, Total Loss 11.948221, Likelihood Loss 11.414991, KL Loss 0.106646
# Epoch 30/150, Batch 401/625, Total Loss 16.203461, Likelihood Loss 15.397280, KL Loss 0.161236
# Epoch 30/150, Batch 501/625, Total Loss 13.140644, Likelihood Loss 12.491951, KL Loss 0.129739
# Epoch 30/150, Batch 601/625, Total Loss 16.868153, Likelihood Loss 16.022276, KL Loss 0.169175
# ====================================================
#
#
# Epoch 30/150, Train Total Loss 18.677164, Eval Total Loss 23.331667
#
#
# ====================================================
# Epoch 31/150, Batch 1/625, Total Loss 16.811110, Likelihood Loss 15.852539, KL Loss 0.191714
# Epoch 31/150, Batch 101/625, Total Loss 14.104782, Likelihood Loss 13.179243, KL Loss 0.185108
# Epoch 31/150, Batch 201/625, Total Loss 15.031044, Likelihood Loss 14.141636, KL Loss 0.177882
# Epoch 31/150, Batch 301/625, Total Loss 13.007724, Likelihood Loss 12.501884, KL Loss 0.101168
# Epoch 31/150, Batch 401/625, Total Loss 14.952838, Likelihood Loss 14.116312, KL Loss 0.167305
# Epoch 31/150, Batch 501/625, Total Loss 16.121622, Likelihood Loss 15.446722, KL Loss 0.134980
# Epoch 31/150, Batch 601/625, Total Loss 19.147209, Likelihood Loss 18.270992, KL Loss 0.175244
# ====================================================
#
#
# Epoch 31/150, Train Total Loss 15.834900, Eval Total Loss 21.026670
#
#
# ====================================================
# Epoch 32/150, Batch 1/625, Total Loss 15.230461, Likelihood Loss 14.191191, KL Loss 0.207854
# Epoch 32/150, Batch 101/625, Total Loss 14.905025, Likelihood Loss 13.921006, KL Loss 0.196804
# Epoch 32/150, Batch 201/625, Total Loss 17.484177, Likelihood Loss 16.573275, KL Loss 0.182180
# Epoch 32/150, Batch 301/625, Total Loss 13.028795, Likelihood Loss 12.442242, KL Loss 0.117311
# Epoch 32/150, Batch 401/625, Total Loss 20.317944, Likelihood Loss 19.395603, KL Loss 0.184468
# Epoch 32/150, Batch 501/625, Total Loss 18.097626, Likelihood Loss 17.348263, KL Loss 0.149873
# Epoch 32/150, Batch 601/625, Total Loss 17.931791, Likelihood Loss 17.087219, KL Loss 0.168914
# ====================================================
#
#
# Epoch 32/150, Train Total Loss 18.824648, Eval Total Loss 18.886274
#
#
# ====================================================
# Epoch 33/150, Batch 1/625, Total Loss 16.461411, Likelihood Loss 15.479164, KL Loss 0.196449
# Epoch 33/150, Batch 101/625, Total Loss 15.534945, Likelihood Loss 14.417633, KL Loss 0.223462
# Epoch 33/150, Batch 201/625, Total Loss 14.926334, Likelihood Loss 14.061046, KL Loss 0.173058
# Epoch 33/150, Batch 301/625, Total Loss 11.519923, Likelihood Loss 11.002468, KL Loss 0.103491
# Epoch 33/150, Batch 401/625, Total Loss 19.225256, Likelihood Loss 18.420036, KL Loss 0.161044
# Epoch 33/150, Batch 501/625, Total Loss 12.505322, Likelihood Loss 11.817313, KL Loss 0.137602
# Epoch 33/150, Batch 601/625, Total Loss 12.104587, Likelihood Loss 11.244371, KL Loss 0.172043
# ====================================================
#
#
# Epoch 33/150, Train Total Loss 13.609336, Eval Total Loss 19.071939
#
#
# ====================================================
# Epoch 34/150, Batch 1/625, Total Loss 15.416114, Likelihood Loss 14.497999, KL Loss 0.183623
# Epoch 34/150, Batch 101/625, Total Loss 12.859676, Likelihood Loss 11.961109, KL Loss 0.179713
# Epoch 34/150, Batch 201/625, Total Loss 13.484965, Likelihood Loss 12.633265, KL Loss 0.170340
# Epoch 34/150, Batch 301/625, Total Loss 10.307266, Likelihood Loss 9.809298, KL Loss 0.099594
# Epoch 34/150, Batch 401/625, Total Loss 16.090660, Likelihood Loss 15.311913, KL Loss 0.155750
# Epoch 34/150, Batch 501/625, Total Loss 11.138293, Likelihood Loss 10.482548, KL Loss 0.131149
# Epoch 34/150, Batch 601/625, Total Loss 16.131762, Likelihood Loss 15.287244, KL Loss 0.168904
# ====================================================
#
#
# Epoch 34/150, Train Total Loss 16.124166, Eval Total Loss 20.424967
#
#
# ====================================================
# Epoch 35/150, Batch 1/625, Total Loss 16.613327, Likelihood Loss 15.660373, KL Loss 0.190591
# Epoch 35/150, Batch 101/625, Total Loss 15.710536, Likelihood Loss 14.796118, KL Loss 0.182884
# Epoch 35/150, Batch 201/625, Total Loss 13.234567, Likelihood Loss 12.352489, KL Loss 0.176415
# Epoch 35/150, Batch 301/625, Total Loss 10.391142, Likelihood Loss 9.891746, KL Loss 0.099879
# Epoch 35/150, Batch 401/625, Total Loss 14.795381, Likelihood Loss 13.957378, KL Loss 0.167600
# Epoch 35/150, Batch 501/625, Total Loss 14.531758, Likelihood Loss 13.796934, KL Loss 0.146965
# Epoch 35/150, Batch 601/625, Total Loss 13.821093, Likelihood Loss 12.901775, KL Loss 0.183863
# ====================================================
#
#
# Epoch 35/150, Train Total Loss 17.847462, Eval Total Loss 21.620722
#
#
# ====================================================
# Epoch 36/150, Batch 1/625, Total Loss 13.414763, Likelihood Loss 12.398420, KL Loss 0.203269
# Epoch 36/150, Batch 101/625, Total Loss 16.432869, Likelihood Loss 15.534924, KL Loss 0.179589
# Epoch 36/150, Batch 201/625, Total Loss 13.152604, Likelihood Loss 12.287033, KL Loss 0.173114
# Epoch 36/150, Batch 301/625, Total Loss 10.863458, Likelihood Loss 10.416354, KL Loss 0.089421
# Epoch 36/150, Batch 401/625, Total Loss 14.666664, Likelihood Loss 13.860975, KL Loss 0.161138
# Epoch 36/150, Batch 501/625, Total Loss 11.671374, Likelihood Loss 11.084764, KL Loss 0.117322
# Epoch 36/150, Batch 601/625, Total Loss 11.685980, Likelihood Loss 10.844991, KL Loss 0.168198
# ====================================================
#
#
# Epoch 36/150, Train Total Loss 19.799135, Eval Total Loss 24.189991
#
#
# ====================================================
# Epoch 37/150, Batch 1/625, Total Loss 14.031682, Likelihood Loss 13.067842, KL Loss 0.192768
# Epoch 37/150, Batch 101/625, Total Loss 14.537466, Likelihood Loss 13.652727, KL Loss 0.176948
# Epoch 37/150, Batch 201/625, Total Loss 10.404358, Likelihood Loss 9.538261, KL Loss 0.173219
# Epoch 37/150, Batch 301/625, Total Loss 10.997000, Likelihood Loss 10.506799, KL Loss 0.098040
# Epoch 37/150, Batch 401/625, Total Loss 18.069298, Likelihood Loss 17.297813, KL Loss 0.154297
# Epoch 37/150, Batch 501/625, Total Loss 12.992103, Likelihood Loss 12.344746, KL Loss 0.129471
# Epoch 37/150, Batch 601/625, Total Loss 17.794331, Likelihood Loss 16.948988, KL Loss 0.169068
# ====================================================
#
#
# Epoch 37/150, Train Total Loss 14.239693, Eval Total Loss 19.909895
#
#
# ====================================================
# Epoch 38/150, Batch 1/625, Total Loss 12.733507, Likelihood Loss 11.802996, KL Loss 0.186102
# Epoch 38/150, Batch 101/625, Total Loss 19.803568, Likelihood Loss 18.929710, KL Loss 0.174771
# Epoch 38/150, Batch 201/625, Total Loss 12.236929, Likelihood Loss 11.309155, KL Loss 0.185555
# Epoch 38/150, Batch 301/625, Total Loss 12.274829, Likelihood Loss 11.771003, KL Loss 0.100765
# Epoch 38/150, Batch 401/625, Total Loss 15.841468, Likelihood Loss 15.060437, KL Loss 0.156206
# Epoch 38/150, Batch 501/625, Total Loss 10.224771, Likelihood Loss 9.577339, KL Loss 0.129487
# Epoch 38/150, Batch 601/625, Total Loss 14.112639, Likelihood Loss 13.209164, KL Loss 0.180695
# ====================================================
#
#
# Epoch 38/150, Train Total Loss 12.352038, Eval Total Loss 17.116411
#
#
# ====================================================
# Epoch 39/150, Batch 1/625, Total Loss 11.271773, Likelihood Loss 10.287483, KL Loss 0.196858
# Epoch 39/150, Batch 101/625, Total Loss 15.822548, Likelihood Loss 14.899998, KL Loss 0.184510
# Epoch 39/150, Batch 201/625, Total Loss 10.735334, Likelihood Loss 9.855684, KL Loss 0.175930
# Epoch 39/150, Batch 301/625, Total Loss 12.141870, Likelihood Loss 11.642559, KL Loss 0.099862
# Epoch 39/150, Batch 401/625, Total Loss 17.855759, Likelihood Loss 16.975941, KL Loss 0.175963
# Epoch 39/150, Batch 501/625, Total Loss 14.043435, Likelihood Loss 13.392130, KL Loss 0.130261
# Epoch 39/150, Batch 601/625, Total Loss 18.106941, Likelihood Loss 17.295965, KL Loss 0.162195
# ====================================================
#
#
# Epoch 39/150, Train Total Loss 15.687572, Eval Total Loss 17.719250
#
#
# ====================================================
# Epoch 40/150, Batch 1/625, Total Loss 12.674685, Likelihood Loss 11.698891, KL Loss 0.195159
# Epoch 40/150, Batch 101/625, Total Loss 15.271065, Likelihood Loss 14.365410, KL Loss 0.181131
# Epoch 40/150, Batch 201/625, Total Loss 15.280744, Likelihood Loss 14.427959, KL Loss 0.170557
# Epoch 40/150, Batch 301/625, Total Loss 12.994893, Likelihood Loss 12.567476, KL Loss 0.085483
# Epoch 40/150, Batch 401/625, Total Loss 17.005398, Likelihood Loss 16.266634, KL Loss 0.147753
# Epoch 40/150, Batch 501/625, Total Loss 9.415222, Likelihood Loss 8.822250, KL Loss 0.118594
# Epoch 40/150, Batch 601/625, Total Loss 14.359811, Likelihood Loss 13.599112, KL Loss 0.152140
# ====================================================
#
#
# Epoch 40/150, Train Total Loss 13.987194, Eval Total Loss 21.285978
#
#
# ====================================================
# Epoch 41/150, Batch 1/625, Total Loss 16.257948, Likelihood Loss 15.385983, KL Loss 0.174393
# Epoch 41/150, Batch 101/625, Total Loss 11.797513, Likelihood Loss 10.918125, KL Loss 0.175878
# Epoch 41/150, Batch 201/625, Total Loss 13.607539, Likelihood Loss 12.788910, KL Loss 0.163726
# Epoch 41/150, Batch 301/625, Total Loss 8.646347, Likelihood Loss 8.208112, KL Loss 0.087647
# Epoch 41/150, Batch 401/625, Total Loss 13.246800, Likelihood Loss 12.552280, KL Loss 0.138904
# Epoch 41/150, Batch 501/625, Total Loss 10.602931, Likelihood Loss 9.983479, KL Loss 0.123890
# Epoch 41/150, Batch 601/625, Total Loss 17.413485, Likelihood Loss 16.615116, KL Loss 0.159674
# ====================================================
#
#
# Epoch 41/150, Train Total Loss 12.197075, Eval Total Loss 20.330872
#
#
# ====================================================
# Epoch 42/150, Batch 1/625, Total Loss 14.221911, Likelihood Loss 13.316892, KL Loss 0.181004
# Epoch 42/150, Batch 101/625, Total Loss 14.088880, Likelihood Loss 13.250265, KL Loss 0.167723
# Epoch 42/150, Batch 201/625, Total Loss 10.362094, Likelihood Loss 9.578893, KL Loss 0.156640
# Epoch 42/150, Batch 301/625, Total Loss 9.925463, Likelihood Loss 9.478607, KL Loss 0.089371
# Epoch 42/150, Batch 401/625, Total Loss 13.794992, Likelihood Loss 13.125629, KL Loss 0.133873
# Epoch 42/150, Batch 501/625, Total Loss 11.026845, Likelihood Loss 10.426456, KL Loss 0.120078
# Epoch 42/150, Batch 601/625, Total Loss 18.155355, Likelihood Loss 17.422716, KL Loss 0.146528
# ====================================================
#
#
# Epoch 42/150, Train Total Loss 13.603550, Eval Total Loss 19.320364
#
#
# ====================================================
# Epoch 43/150, Batch 1/625, Total Loss 13.163748, Likelihood Loss 12.252337, KL Loss 0.182282
# Epoch 43/150, Batch 101/625, Total Loss 13.714289, Likelihood Loss 12.884450, KL Loss 0.165968
# Epoch 43/150, Batch 201/625, Total Loss 10.980797, Likelihood Loss 10.267746, KL Loss 0.142610
# Epoch 43/150, Batch 301/625, Total Loss 9.484776, Likelihood Loss 9.007490, KL Loss 0.095457
# Epoch 43/150, Batch 401/625, Total Loss 18.860479, Likelihood Loss 18.151375, KL Loss 0.141821
# Epoch 43/150, Batch 501/625, Total Loss 12.989613, Likelihood Loss 12.378660, KL Loss 0.122190
# Epoch 43/150, Batch 601/625, Total Loss 14.123178, Likelihood Loss 13.325056, KL Loss 0.159624
# ====================================================
#
#
# Epoch 43/150, Train Total Loss 17.573488, Eval Total Loss 19.095894
#
#
# ====================================================
# Epoch 44/150, Batch 1/625, Total Loss 13.680443, Likelihood Loss 12.777792, KL Loss 0.180530
# Epoch 44/150, Batch 101/625, Total Loss 12.262229, Likelihood Loss 11.469341, KL Loss 0.158577
# Epoch 44/150, Batch 201/625, Total Loss 10.118654, Likelihood Loss 9.375851, KL Loss 0.148561
# Epoch 44/150, Batch 301/625, Total Loss 14.292307, Likelihood Loss 13.790092, KL Loss 0.100443
# Epoch 44/150, Batch 401/625, Total Loss 13.173553, Likelihood Loss 12.446528, KL Loss 0.145405
# Epoch 44/150, Batch 501/625, Total Loss 14.281214, Likelihood Loss 13.712524, KL Loss 0.113738
# Epoch 44/150, Batch 601/625, Total Loss 11.455972, Likelihood Loss 10.742403, KL Loss 0.142714
# ====================================================
#
#
# Epoch 44/150, Train Total Loss 14.003839, Eval Total Loss 15.735214
#
#
# ====================================================
# Epoch 45/150, Batch 1/625, Total Loss 11.499392, Likelihood Loss 10.674852, KL Loss 0.164908
# Epoch 45/150, Batch 101/625, Total Loss 10.255861, Likelihood Loss 9.421309, KL Loss 0.166911
# Epoch 45/150, Batch 201/625, Total Loss 12.063784, Likelihood Loss 11.317713, KL Loss 0.149214
# Epoch 45/150, Batch 301/625, Total Loss 12.868394, Likelihood Loss 12.387813, KL Loss 0.096116
# Epoch 45/150, Batch 401/625, Total Loss 12.786961, Likelihood Loss 12.022405, KL Loss 0.152911
# Epoch 45/150, Batch 501/625, Total Loss 14.325446, Likelihood Loss 13.722948, KL Loss 0.120500
# Epoch 45/150, Batch 601/625, Total Loss 12.878620, Likelihood Loss 12.171551, KL Loss 0.141414
# ====================================================
#
#
# Epoch 45/150, Train Total Loss 14.065289, Eval Total Loss 17.058037
#
#
# ====================================================
# Epoch 46/150, Batch 1/625, Total Loss 12.696733, Likelihood Loss 11.841953, KL Loss 0.170956
# Epoch 46/150, Batch 101/625, Total Loss 11.377146, Likelihood Loss 10.568720, KL Loss 0.161685
# Epoch 46/150, Batch 201/625, Total Loss 8.971299, Likelihood Loss 8.177921, KL Loss 0.158675
# Epoch 46/150, Batch 301/625, Total Loss 11.630101, Likelihood Loss 11.060665, KL Loss 0.113887
# Epoch 46/150, Batch 401/625, Total Loss 14.868783, Likelihood Loss 14.118498, KL Loss 0.150057
# Epoch 46/150, Batch 501/625, Total Loss 10.121063, Likelihood Loss 9.525969, KL Loss 0.119019
# Epoch 46/150, Batch 601/625, Total Loss 10.886702, Likelihood Loss 10.136520, KL Loss 0.150036
# ====================================================
#
#
# Epoch 46/150, Train Total Loss 14.700805, Eval Total Loss 17.286934
#
#
# ====================================================
# Epoch 47/150, Batch 1/625, Total Loss 11.940525, Likelihood Loss 11.104905, KL Loss 0.167124
# Epoch 47/150, Batch 101/625, Total Loss 11.107515, Likelihood Loss 10.330231, KL Loss 0.155457
# Epoch 47/150, Batch 201/625, Total Loss 10.736110, Likelihood Loss 10.019484, KL Loss 0.143325
# Epoch 47/150, Batch 301/625, Total Loss 11.641697, Likelihood Loss 11.109951, KL Loss 0.106349
# Epoch 47/150, Batch 401/625, Total Loss 12.995288, Likelihood Loss 12.285254, KL Loss 0.142007
# Epoch 47/150, Batch 501/625, Total Loss 9.491468, Likelihood Loss 8.958761, KL Loss 0.106541
# Epoch 47/150, Batch 601/625, Total Loss 11.404783, Likelihood Loss 10.723075, KL Loss 0.136342
# ====================================================
#
#
# Epoch 47/150, Train Total Loss 11.906775, Eval Total Loss 15.132835
#
#
# ====================================================
# Epoch 48/150, Batch 1/625, Total Loss 10.506109, Likelihood Loss 9.711956, KL Loss 0.158831
# Epoch 48/150, Batch 101/625, Total Loss 9.605566, Likelihood Loss 8.876026, KL Loss 0.145908
# Epoch 48/150, Batch 201/625, Total Loss 10.733236, Likelihood Loss 10.032844, KL Loss 0.140079
# Epoch 48/150, Batch 301/625, Total Loss 9.594139, Likelihood Loss 9.136091, KL Loss 0.091610
# Epoch 48/150, Batch 401/625, Total Loss 11.976793, Likelihood Loss 11.316265, KL Loss 0.132106
# Epoch 48/150, Batch 501/625, Total Loss 9.000390, Likelihood Loss 8.479551, KL Loss 0.104168
# Epoch 48/150, Batch 601/625, Total Loss 9.347928, Likelihood Loss 8.700283, KL Loss 0.129529
# ====================================================
#
#
# Epoch 48/150, Train Total Loss 15.115803, Eval Total Loss 16.637766
#
#
# ====================================================
# Epoch 49/150, Batch 1/625, Total Loss 11.759726, Likelihood Loss 11.076233, KL Loss 0.136699
# Epoch 49/150, Batch 101/625, Total Loss 8.927590, Likelihood Loss 8.228430, KL Loss 0.139832
# Epoch 49/150, Batch 201/625, Total Loss 8.336890, Likelihood Loss 7.681894, KL Loss 0.130999
# Epoch 49/150, Batch 301/625, Total Loss 7.946843, Likelihood Loss 7.510335, KL Loss 0.087302
# Epoch 49/150, Batch 401/625, Total Loss 12.485186, Likelihood Loss 11.817804, KL Loss 0.133476
# Epoch 49/150, Batch 501/625, Total Loss 9.662318, Likelihood Loss 9.165074, KL Loss 0.099449
# Epoch 49/150, Batch 601/625, Total Loss 10.407708, Likelihood Loss 9.780067, KL Loss 0.125528
# ====================================================
#
#
# Epoch 49/150, Train Total Loss 11.417783, Eval Total Loss 14.475191
#
#
# ====================================================
# Epoch 50/150, Batch 1/625, Total Loss 11.284866, Likelihood Loss 10.578321, KL Loss 0.141309
# Epoch 50/150, Batch 101/625, Total Loss 10.310275, Likelihood Loss 9.637810, KL Loss 0.134493
# Epoch 50/150, Batch 201/625, Total Loss 8.295574, Likelihood Loss 7.686301, KL Loss 0.121855
# Epoch 50/150, Batch 301/625, Total Loss 9.706621, Likelihood Loss 9.337553, KL Loss 0.073814
# Epoch 50/150, Batch 401/625, Total Loss 12.379562, Likelihood Loss 11.707833, KL Loss 0.134346
# Epoch 50/150, Batch 501/625, Total Loss 9.488727, Likelihood Loss 9.000368, KL Loss 0.097672
# Epoch 50/150, Batch 601/625, Total Loss 11.052116, Likelihood Loss 10.467550, KL Loss 0.116913
# ====================================================
#
#
# Epoch 50/150, Train Total Loss 13.721338, Eval Total Loss 16.453983
#
#
# ====================================================
# Epoch 51/150, Batch 1/625, Total Loss 10.720057, Likelihood Loss 10.013214, KL Loss 0.141369
# Epoch 51/150, Batch 101/625, Total Loss 13.129699, Likelihood Loss 12.323299, KL Loss 0.161280
# Epoch 51/150, Batch 201/625, Total Loss 8.782230, Likelihood Loss 8.166866, KL Loss 0.123073
# Epoch 51/150, Batch 301/625, Total Loss 9.102365, Likelihood Loss 8.681735, KL Loss 0.084126
# Epoch 51/150, Batch 401/625, Total Loss 12.807190, Likelihood Loss 12.187225, KL Loss 0.123993
# Epoch 51/150, Batch 501/625, Total Loss 10.129390, Likelihood Loss 9.639185, KL Loss 0.098041
# Epoch 51/150, Batch 601/625, Total Loss 10.353143, Likelihood Loss 9.758753, KL Loss 0.118878
# ====================================================
#
#
# Epoch 51/150, Train Total Loss 12.270246, Eval Total Loss 16.913326
#
#
# ====================================================
# Epoch 52/150, Batch 1/625, Total Loss 13.595456, Likelihood Loss 12.872336, KL Loss 0.144624
# Epoch 52/150, Batch 101/625, Total Loss 8.910452, Likelihood Loss 8.243067, KL Loss 0.133477
# Epoch 52/150, Batch 201/625, Total Loss 11.191721, Likelihood Loss 10.562396, KL Loss 0.125865
# Epoch 52/150, Batch 301/625, Total Loss 9.257760, Likelihood Loss 8.832391, KL Loss 0.085074
# Epoch 52/150, Batch 401/625, Total Loss 12.035976, Likelihood Loss 11.407478, KL Loss 0.125700
# Epoch 52/150, Batch 501/625, Total Loss 9.379873, Likelihood Loss 8.924285, KL Loss 0.091118
# Epoch 52/150, Batch 601/625, Total Loss 21.264996, Likelihood Loss 20.609501, KL Loss 0.131099
# ====================================================
#
#
# Epoch 52/150, Train Total Loss 13.129722, Eval Total Loss 18.251066
#
#
# ====================================================
# Epoch 53/150, Batch 1/625, Total Loss 14.845632, Likelihood Loss 14.006003, KL Loss 0.167926
# Epoch 53/150, Batch 101/625, Total Loss 9.593328, Likelihood Loss 8.907758, KL Loss 0.137114
# Epoch 53/150, Batch 201/625, Total Loss 10.877093, Likelihood Loss 10.228422, KL Loss 0.129734
# Epoch 53/150, Batch 301/625, Total Loss 10.671540, Likelihood Loss 10.247341, KL Loss 0.084840
# Epoch 53/150, Batch 401/625, Total Loss 10.810032, Likelihood Loss 10.182096, KL Loss 0.125587
# Epoch 53/150, Batch 501/625, Total Loss 9.009247, Likelihood Loss 8.538599, KL Loss 0.094130
# Epoch 53/150, Batch 601/625, Total Loss 10.080871, Likelihood Loss 9.437247, KL Loss 0.128725
# ====================================================
#
#
# Epoch 53/150, Train Total Loss 13.434529, Eval Total Loss 16.203573
#
#
# ====================================================
# Epoch 54/150, Batch 1/625, Total Loss 9.842194, Likelihood Loss 9.100985, KL Loss 0.148242
# Epoch 54/150, Batch 101/625, Total Loss 9.818083, Likelihood Loss 9.154419, KL Loss 0.132733
# Epoch 54/150, Batch 201/625, Total Loss 7.689320, Likelihood Loss 7.076668, KL Loss 0.122530
# Epoch 54/150, Batch 301/625, Total Loss 7.799084, Likelihood Loss 7.425235, KL Loss 0.074770
# Epoch 54/150, Batch 401/625, Total Loss 13.068263, Likelihood Loss 12.498356, KL Loss 0.113981
# Epoch 54/150, Batch 501/625, Total Loss 8.972259, Likelihood Loss 8.480639, KL Loss 0.098324
# Epoch 54/150, Batch 601/625, Total Loss 11.120498, Likelihood Loss 10.545479, KL Loss 0.115004
# ====================================================
#
#
# Epoch 54/150, Train Total Loss 12.284022, Eval Total Loss 15.404846
#
#
# ====================================================
# Epoch 55/150, Batch 1/625, Total Loss 9.292969, Likelihood Loss 8.632092, KL Loss 0.132175
# Epoch 55/150, Batch 101/625, Total Loss 10.196991, Likelihood Loss 9.603931, KL Loss 0.118612
# Epoch 55/150, Batch 201/625, Total Loss 9.268491, Likelihood Loss 8.695843, KL Loss 0.114530
# Epoch 55/150, Batch 301/625, Total Loss 7.504298, Likelihood Loss 7.115377, KL Loss 0.077784
# Epoch 55/150, Batch 401/625, Total Loss 14.387339, Likelihood Loss 13.824862, KL Loss 0.112495
# Epoch 55/150, Batch 501/625, Total Loss 14.478292, Likelihood Loss 14.022301, KL Loss 0.091198
# Epoch 55/150, Batch 601/625, Total Loss 10.359823, Likelihood Loss 9.743983, KL Loss 0.123168
# ====================================================
#
#
# Epoch 55/150, Train Total Loss 12.225531, Eval Total Loss 15.362432
#
#
# ====================================================
# Epoch 56/150, Batch 1/625, Total Loss 11.295349, Likelihood Loss 10.602684, KL Loss 0.138533
# Epoch 56/150, Batch 101/625, Total Loss 9.093279, Likelihood Loss 8.469224, KL Loss 0.124811
# Epoch 56/150, Batch 201/625, Total Loss 9.114975, Likelihood Loss 8.480638, KL Loss 0.126868
# Epoch 56/150, Batch 301/625, Total Loss 8.251771, Likelihood Loss 7.838159, KL Loss 0.082722
# Epoch 56/150, Batch 401/625, Total Loss 14.494366, Likelihood Loss 13.903025, KL Loss 0.118268
# Epoch 56/150, Batch 501/625, Total Loss 10.219408, Likelihood Loss 9.715852, KL Loss 0.100711
# Epoch 56/150, Batch 601/625, Total Loss 12.318893, Likelihood Loss 11.587242, KL Loss 0.146330
# ====================================================
#
#
# Epoch 56/150, Train Total Loss 10.281158, Eval Total Loss 14.926917
#
#
# ====================================================
# Epoch 57/150, Batch 1/625, Total Loss 9.371715, Likelihood Loss 8.652296, KL Loss 0.143884
# Epoch 57/150, Batch 101/625, Total Loss 10.573160, Likelihood Loss 9.963472, KL Loss 0.121937
# Epoch 57/150, Batch 201/625, Total Loss 9.149340, Likelihood Loss 8.579557, KL Loss 0.113956
# Epoch 57/150, Batch 301/625, Total Loss 9.311707, Likelihood Loss 8.939083, KL Loss 0.074525
# Epoch 57/150, Batch 401/625, Total Loss 11.728214, Likelihood Loss 11.132690, KL Loss 0.119105
# Epoch 57/150, Batch 501/625, Total Loss 10.997931, Likelihood Loss 10.515507, KL Loss 0.096485
# Epoch 57/150, Batch 601/625, Total Loss 19.024479, Likelihood Loss 18.382843, KL Loss 0.128327
# ====================================================
#
#
# Epoch 57/150, Train Total Loss 11.237876, Eval Total Loss 21.156996
#
#
# ====================================================
# Epoch 58/150, Batch 1/625, Total Loss 12.534161, Likelihood Loss 11.829507, KL Loss 0.140931
# Epoch 58/150, Batch 101/625, Total Loss 9.424830, Likelihood Loss 8.800147, KL Loss 0.124937
# ...
#
#
# Epoch 131/150, Train Total Loss 8.120465, Eval Total Loss 17.540649
#
#
# ====================================================
# Epoch 132/150, Batch 1/625, Total Loss 7.416672, Likelihood Loss 7.074925, KL Loss 0.068349
# Epoch 132/150, Batch 101/625, Total Loss 5.108762, Likelihood Loss 4.795563, KL Loss 0.062640
# Epoch 132/150, Batch 201/625, Total Loss 5.703285, Likelihood Loss 5.405931, KL Loss 0.059471
# Epoch 132/150, Batch 301/625, Total Loss 5.931781, Likelihood Loss 5.730302, KL Loss 0.040296
# Epoch 132/150, Batch 401/625, Total Loss 6.085652, Likelihood Loss 5.789136, KL Loss 0.059303
# Epoch 132/150, Batch 501/625, Total Loss 5.277950, Likelihood Loss 5.026407, KL Loss 0.050309
# Epoch 132/150, Batch 601/625, Total Loss 5.388834, Likelihood Loss 5.099370, KL Loss 0.057893
# ====================================================
#
#
# Epoch 132/150, Train Total Loss 8.134844, Eval Total Loss 14.695804
#
#
# ====================================================
# Epoch 133/150, Batch 1/625, Total Loss 7.886528, Likelihood Loss 7.558731, KL Loss 0.065559
# Epoch 133/150, Batch 101/625, Total Loss 8.138902, Likelihood Loss 7.824889, KL Loss 0.062803
# Epoch 133/150, Batch 201/625, Total Loss 8.109837, Likelihood Loss 7.797598, KL Loss 0.062448
# Epoch 133/150, Batch 301/625, Total Loss 5.279783, Likelihood Loss 5.073703, KL Loss 0.041216
# Epoch 133/150, Batch 401/625, Total Loss 5.882369, Likelihood Loss 5.615785, KL Loss 0.053317
# Epoch 133/150, Batch 501/625, Total Loss 5.203415, Likelihood Loss 4.958405, KL Loss 0.049002
# Epoch 133/150, Batch 601/625, Total Loss 5.332117, Likelihood Loss 5.053114, KL Loss 0.055800
# ====================================================
#
#
# Epoch 133/150, Train Total Loss 9.939307, Eval Total Loss 13.592564
#
#
# ====================================================
# Epoch 134/150, Batch 1/625, Total Loss 7.919649, Likelihood Loss 7.605556, KL Loss 0.062819
# Epoch 134/150, Batch 101/625, Total Loss 6.167192, Likelihood Loss 5.882020, KL Loss 0.057034
# Epoch 134/150, Batch 201/625, Total Loss 7.654369, Likelihood Loss 7.369586, KL Loss 0.056956
# Epoch 134/150, Batch 301/625, Total Loss 4.838232, Likelihood Loss 4.643014, KL Loss 0.039044
# Epoch 134/150, Batch 401/625, Total Loss 5.931277, Likelihood Loss 5.668230, KL Loss 0.052609
# Epoch 134/150, Batch 501/625, Total Loss 4.687485, Likelihood Loss 4.459683, KL Loss 0.045560
# Epoch 134/150, Batch 601/625, Total Loss 7.419895, Likelihood Loss 7.149983, KL Loss 0.053982
# ====================================================
#
#
# Epoch 134/150, Train Total Loss 8.958529, Eval Total Loss 15.393376
#
#
# ====================================================
# Epoch 135/150, Batch 1/625, Total Loss 7.160786, Likelihood Loss 6.860028, KL Loss 0.060152
# Epoch 135/150, Batch 101/625, Total Loss 6.518724, Likelihood Loss 6.235272, KL Loss 0.056690
# Epoch 135/150, Batch 201/625, Total Loss 7.019457, Likelihood Loss 6.746782, KL Loss 0.054535
# Epoch 135/150, Batch 301/625, Total Loss 4.753979, Likelihood Loss 4.569520, KL Loss 0.036892
# Epoch 135/150, Batch 401/625, Total Loss 5.115106, Likelihood Loss 4.857336, KL Loss 0.051554
# Epoch 135/150, Batch 501/625, Total Loss 4.596635, Likelihood Loss 4.362185, KL Loss 0.046890
# Epoch 135/150, Batch 601/625, Total Loss 6.521943, Likelihood Loss 6.244159, KL Loss 0.055557
# ====================================================
#
#
# Epoch 135/150, Train Total Loss 6.248339, Eval Total Loss 13.608562
#
#
# ====================================================
# Epoch 136/150, Batch 1/625, Total Loss 5.887674, Likelihood Loss 5.596868, KL Loss 0.058161
# Epoch 136/150, Batch 101/625, Total Loss 6.250452, Likelihood Loss 5.971502, KL Loss 0.055790
# Epoch 136/150, Batch 201/625, Total Loss 6.969811, Likelihood Loss 6.710154, KL Loss 0.051931
# Epoch 136/150, Batch 301/625, Total Loss 4.411467, Likelihood Loss 4.234564, KL Loss 0.035381
# Epoch 136/150, Batch 401/625, Total Loss 5.418832, Likelihood Loss 5.160816, KL Loss 0.051603
# Epoch 136/150, Batch 501/625, Total Loss 4.949272, Likelihood Loss 4.734325, KL Loss 0.042989
# Epoch 136/150, Batch 601/625, Total Loss 6.021493, Likelihood Loss 5.751677, KL Loss 0.053963
# ====================================================
#
#
# Epoch 136/150, Train Total Loss 8.045816, Eval Total Loss 17.144886
#
#
# ====================================================
# Epoch 137/150, Batch 1/625, Total Loss 7.327029, Likelihood Loss 7.031928, KL Loss 0.059020
# Epoch 137/150, Batch 101/625, Total Loss 6.123650, Likelihood Loss 5.786611, KL Loss 0.067408
# Epoch 137/150, Batch 201/625, Total Loss 5.844088, Likelihood Loss 5.583021, KL Loss 0.052214
# Epoch 137/150, Batch 301/625, Total Loss 4.347281, Likelihood Loss 4.166121, KL Loss 0.036232
# Epoch 137/150, Batch 401/625, Total Loss 5.926157, Likelihood Loss 5.668694, KL Loss 0.051493
# Epoch 137/150, Batch 501/625, Total Loss 4.824423, Likelihood Loss 4.605131, KL Loss 0.043858
# Epoch 137/150, Batch 601/625, Total Loss 5.784832, Likelihood Loss 5.500731, KL Loss 0.056820
# ====================================================
#
#
# Epoch 137/150, Train Total Loss 7.174436, Eval Total Loss 18.138868
#
#
# ====================================================
# Epoch 138/150, Batch 1/625, Total Loss 7.241487, Likelihood Loss 6.928835, KL Loss 0.062530
# Epoch 138/150, Batch 101/625, Total Loss 5.236243, Likelihood Loss 4.877760, KL Loss 0.071697
# Epoch 138/150, Batch 201/625, Total Loss 5.411575, Likelihood Loss 5.150258, KL Loss 0.052264
# Epoch 138/150, Batch 301/625, Total Loss 3.664497, Likelihood Loss 3.486445, KL Loss 0.035610
# Epoch 138/150, Batch 401/625, Total Loss 6.051579, Likelihood Loss 5.801962, KL Loss 0.049923
# Epoch 138/150, Batch 501/625, Total Loss 5.026625, Likelihood Loss 4.811003, KL Loss 0.043124
# Epoch 138/150, Batch 601/625, Total Loss 7.010500, Likelihood Loss 6.744492, KL Loss 0.053202
# ====================================================
#
#
# Epoch 138/150, Train Total Loss 6.324953, Eval Total Loss 18.014452
#
#
# ====================================================
# Epoch 139/150, Batch 1/625, Total Loss 6.696949, Likelihood Loss 6.373081, KL Loss 0.064774
# Epoch 139/150, Batch 101/625, Total Loss 4.977579, Likelihood Loss 4.653081, KL Loss 0.064899
# Epoch 139/150, Batch 201/625, Total Loss 5.439513, Likelihood Loss 5.159330, KL Loss 0.056037
# Epoch 139/150, Batch 301/625, Total Loss 4.324602, Likelihood Loss 4.135788, KL Loss 0.037763
# Epoch 139/150, Batch 401/625, Total Loss 5.509257, Likelihood Loss 5.238153, KL Loss 0.054221
# Epoch 139/150, Batch 501/625, Total Loss 5.484616, Likelihood Loss 5.239885, KL Loss 0.048946
# Epoch 139/150, Batch 601/625, Total Loss 5.811781, Likelihood Loss 5.543561, KL Loss 0.053644
# ====================================================
#
#
# Epoch 139/150, Train Total Loss 7.089749, Eval Total Loss 11.865078
#
#
# ====================================================
# Epoch 140/150, Batch 1/625, Total Loss 5.790939, Likelihood Loss 5.492517, KL Loss 0.059684
# Epoch 140/150, Batch 101/625, Total Loss 5.261111, Likelihood Loss 4.975106, KL Loss 0.057201
# Epoch 140/150, Batch 201/625, Total Loss 4.030052, Likelihood Loss 3.762456, KL Loss 0.053519
# Epoch 140/150, Batch 301/625, Total Loss 4.988396, Likelihood Loss 4.800141, KL Loss 0.037651
# Epoch 140/150, Batch 401/625, Total Loss 6.882276, Likelihood Loss 6.628169, KL Loss 0.050821
# Epoch 140/150, Batch 501/625, Total Loss 6.072912, Likelihood Loss 5.839314, KL Loss 0.046720
# Epoch 140/150, Batch 601/625, Total Loss 7.139596, Likelihood Loss 6.847332, KL Loss 0.058453
# ====================================================
#
#
# Epoch 140/150, Train Total Loss 5.713026, Eval Total Loss 11.248227
#
#
# ====================================================
# Epoch 141/150, Batch 1/625, Total Loss 5.308340, Likelihood Loss 4.971858, KL Loss 0.067297
# Epoch 141/150, Batch 101/625, Total Loss 4.946618, Likelihood Loss 4.677711, KL Loss 0.053782
# Epoch 141/150, Batch 201/625, Total Loss 4.780325, Likelihood Loss 4.511683, KL Loss 0.053729
# Epoch 141/150, Batch 301/625, Total Loss 5.739858, Likelihood Loss 5.537724, KL Loss 0.040427
# Epoch 141/150, Batch 401/625, Total Loss 5.533346, Likelihood Loss 5.263679, KL Loss 0.053934
# Epoch 141/150, Batch 501/625, Total Loss 6.140543, Likelihood Loss 5.892221, KL Loss 0.049664
# Epoch 141/150, Batch 601/625, Total Loss 8.133225, Likelihood Loss 7.835295, KL Loss 0.059586
# ====================================================
#
#
# Epoch 141/150, Train Total Loss 4.962464, Eval Total Loss 12.275375
#
#
# ====================================================
# Epoch 142/150, Batch 1/625, Total Loss 5.943270, Likelihood Loss 5.633817, KL Loss 0.061890
# Epoch 142/150, Batch 101/625, Total Loss 5.336153, Likelihood Loss 5.051824, KL Loss 0.056866
# Epoch 142/150, Batch 201/625, Total Loss 4.448485, Likelihood Loss 4.185074, KL Loss 0.052682
# Epoch 142/150, Batch 301/625, Total Loss 5.753167, Likelihood Loss 5.552305, KL Loss 0.040172
# Epoch 142/150, Batch 401/625, Total Loss 6.426051, Likelihood Loss 6.146799, KL Loss 0.055850
# Epoch 142/150, Batch 501/625, Total Loss 5.115321, Likelihood Loss 4.874260, KL Loss 0.048212
# Epoch 142/150, Batch 601/625, Total Loss 6.378671, Likelihood Loss 6.093349, KL Loss 0.057064
# ====================================================
#
#
# Epoch 142/150, Train Total Loss 5.739666, Eval Total Loss 12.981726
#
#
# ====================================================
# Epoch 143/150, Batch 1/625, Total Loss 5.311893, Likelihood Loss 5.006615, KL Loss 0.061056
# Epoch 143/150, Batch 101/625, Total Loss 6.723462, Likelihood Loss 6.408086, KL Loss 0.063075
# Epoch 143/150, Batch 201/625, Total Loss 5.913612, Likelihood Loss 5.637423, KL Loss 0.055238
# Epoch 143/150, Batch 301/625, Total Loss 6.169856, Likelihood Loss 5.948949, KL Loss 0.044181
# Epoch 143/150, Batch 401/625, Total Loss 5.648520, Likelihood Loss 5.368437, KL Loss 0.056017
# Epoch 143/150, Batch 501/625, Total Loss 5.792690, Likelihood Loss 5.546461, KL Loss 0.049246
# Epoch 143/150, Batch 601/625, Total Loss 7.167592, Likelihood Loss 6.889633, KL Loss 0.055592
# ====================================================
#
#
# Epoch 143/150, Train Total Loss 8.005312, Eval Total Loss 13.103224
#
#
# ====================================================
# Epoch 144/150, Batch 1/625, Total Loss 6.894010, Likelihood Loss 6.561062, KL Loss 0.066590
# Epoch 144/150, Batch 101/625, Total Loss 6.422789, Likelihood Loss 6.149171, KL Loss 0.054723
# Epoch 144/150, Batch 201/625, Total Loss 5.532049, Likelihood Loss 5.269392, KL Loss 0.052531
# Epoch 144/150, Batch 301/625, Total Loss 6.080681, Likelihood Loss 5.875741, KL Loss 0.040988
# Epoch 144/150, Batch 401/625, Total Loss 6.223178, Likelihood Loss 5.949480, KL Loss 0.054740
# Epoch 144/150, Batch 501/625, Total Loss 8.763108, Likelihood Loss 8.505590, KL Loss 0.051504
# Epoch 144/150, Batch 601/625, Total Loss 9.194665, Likelihood Loss 8.894926, KL Loss 0.059948
# ====================================================
#
#
# Epoch 144/150, Train Total Loss 7.801303, Eval Total Loss 16.460649
#
#
# ====================================================
# Epoch 145/150, Batch 1/625, Total Loss 7.864109, Likelihood Loss 7.533309, KL Loss 0.066160
# Epoch 145/150, Batch 101/625, Total Loss 7.222924, Likelihood Loss 6.918245, KL Loss 0.060936
# Epoch 145/150, Batch 201/625, Total Loss 6.676146, Likelihood Loss 6.400521, KL Loss 0.055125
# Epoch 145/150, Batch 301/625, Total Loss 5.971991, Likelihood Loss 5.770457, KL Loss 0.040307
# Epoch 145/150, Batch 401/625, Total Loss 6.282799, Likelihood Loss 6.004916, KL Loss 0.055577
# Epoch 145/150, Batch 501/625, Total Loss 5.367824, Likelihood Loss 5.111588, KL Loss 0.051247
# Epoch 145/150, Batch 601/625, Total Loss 6.653367, Likelihood Loss 6.376307, KL Loss 0.055412
# ====================================================
#
#
# Epoch 145/150, Train Total Loss 10.867263, Eval Total Loss 19.463703
#
#
# ====================================================
# Epoch 146/150, Batch 1/625, Total Loss 12.527106, Likelihood Loss 12.174712, KL Loss 0.070479
# Epoch 146/150, Batch 101/625, Total Loss 5.283172, Likelihood Loss 4.976686, KL Loss 0.061297
# Epoch 146/150, Batch 201/625, Total Loss 7.084551, Likelihood Loss 6.791585, KL Loss 0.058593
# Epoch 146/150, Batch 301/625, Total Loss 5.775810, Likelihood Loss 5.541298, KL Loss 0.046902
# Epoch 146/150, Batch 401/625, Total Loss 7.120586, Likelihood Loss 6.824072, KL Loss 0.059303
# Epoch 146/150, Batch 501/625, Total Loss 4.756354, Likelihood Loss 4.497704, KL Loss 0.051730
# Epoch 146/150, Batch 601/625, Total Loss 5.235009, Likelihood Loss 4.957591, KL Loss 0.055484
# ====================================================
#
#
# Epoch 146/150, Train Total Loss 11.571356, Eval Total Loss 18.008518
#
#
# ====================================================
# Epoch 147/150, Batch 1/625, Total Loss 11.039433, Likelihood Loss 10.689821, KL Loss 0.069922
# Epoch 147/150, Batch 101/625, Total Loss 6.289815, Likelihood Loss 5.991638, KL Loss 0.059636
# Epoch 147/150, Batch 201/625, Total Loss 5.693059, Likelihood Loss 5.396332, KL Loss 0.059345
# Epoch 147/150, Batch 301/625, Total Loss 8.034389, Likelihood Loss 7.820650, KL Loss 0.042748
# Epoch 147/150, Batch 401/625, Total Loss 6.192978, Likelihood Loss 5.909771, KL Loss 0.056642
# Epoch 147/150, Batch 501/625, Total Loss 5.713687, Likelihood Loss 5.467378, KL Loss 0.049262
# Epoch 147/150, Batch 601/625, Total Loss 5.807779, Likelihood Loss 5.525626, KL Loss 0.056431
# ====================================================
#
#
# Epoch 147/150, Train Total Loss 9.247871, Eval Total Loss 16.882528
#
#
# ====================================================
# Epoch 148/150, Batch 1/625, Total Loss 9.196951, Likelihood Loss 8.872261, KL Loss 0.064938
# Epoch 148/150, Batch 101/625, Total Loss 5.776273, Likelihood Loss 5.483479, KL Loss 0.058559
# Epoch 148/150, Batch 201/625, Total Loss 4.887423, Likelihood Loss 4.592409, KL Loss 0.059003
# Epoch 148/150, Batch 301/625, Total Loss 6.481189, Likelihood Loss 6.276266, KL Loss 0.040985
# Epoch 148/150, Batch 401/625, Total Loss 5.418724, Likelihood Loss 5.157009, KL Loss 0.052343
# Epoch 148/150, Batch 501/625, Total Loss 5.257190, Likelihood Loss 5.020828, KL Loss 0.047272
# Epoch 148/150, Batch 601/625, Total Loss 4.892770, Likelihood Loss 4.619817, KL Loss 0.054591
# ====================================================
#
#
# Epoch 148/150, Train Total Loss 7.244197, Eval Total Loss 15.178728
#
#
# ====================================================
# Epoch 149/150, Batch 1/625, Total Loss 7.217009, Likelihood Loss 6.894596, KL Loss 0.064482
# Epoch 149/150, Batch 101/625, Total Loss 5.533457, Likelihood Loss 5.211369, KL Loss 0.064418
# Epoch 149/150, Batch 201/625, Total Loss 4.193712, Likelihood Loss 3.904214, KL Loss 0.057899
# Epoch 149/150, Batch 301/625, Total Loss 5.475329, Likelihood Loss 5.274698, KL Loss 0.040126
# Epoch 149/150, Batch 401/625, Total Loss 5.081373, Likelihood Loss 4.827365, KL Loss 0.050802
# Epoch 149/150, Batch 501/625, Total Loss 4.341300, Likelihood Loss 4.110128, KL Loss 0.046234
# Epoch 149/150, Batch 601/625, Total Loss 4.492109, Likelihood Loss 4.233709, KL Loss 0.051680
# ====================================================
#
#
# Epoch 149/150, Train Total Loss 5.199976, Eval Total Loss 13.136212
#
#
# ====================================================
# Epoch 150/150, Batch 1/625, Total Loss 5.222587, Likelihood Loss 4.921277, KL Loss 0.060262
# Epoch 150/150, Batch 101/625, Total Loss 5.761172, Likelihood Loss 5.475985, KL Loss 0.057037
# Epoch 150/150, Batch 201/625, Total Loss 4.096811, Likelihood Loss 3.838423, KL Loss 0.051677
# Epoch 150/150, Batch 301/625, Total Loss 4.763264, Likelihood Loss 4.570126, KL Loss 0.038628
# Epoch 150/150, Batch 401/625, Total Loss 5.012777, Likelihood Loss 4.771389, KL Loss 0.048278
# Epoch 150/150, Batch 501/625, Total Loss 4.090886, Likelihood Loss 3.876084, KL Loss 0.042960
# Epoch 150/150, Batch 601/625, Total Loss 4.073836, Likelihood Loss 3.831796, KL Loss 0.048408
# ====================================================
#
#
# Epoch 150/150, Train Total Loss 5.206973, Eval Total Loss 11.631281
#
#
# ====================================================

# %%
# Data for plotting
fig, ax = plt.subplots()
ax.plot(range(epoch), train_loss_record,  'k--', label='train')
ax.plot(range(epoch), test_loss_record,  'k:', label='test')


legend = ax.legend(loc='upper right', fontsize='large')

ax.set(xlabel='epoch', ylabel='Mean Absolute Error',
        title='Loss with %d training samples' % (train_x.shape[0]))
ax.grid()

fig.savefig("figs/vunet_loss_%dtrain.pdf"%(train_x.shape[0]), format='pdf')
plt.show()

# %% [markdown]
# # Test starts here
#
# ### Do not need to run training section

# %%
epoch = 150
learning_rate = 5e-4
train_nr = train_x.shape[0]
test_nr = test_x.shape[0]

input_shape = (128,128,2)
output_shape = (128,128,1)


# enc_up, hidden_shapes = vunet.create_enc_up(input_shape, n_scales = 8)
# enc_down = vunet.create_enc_down(latent_shape)
# dec_up = vunet.create_dec_up(output_shape, n_scales = 8) # only c input
# dec_down = vunet.create_dec_down(hidden_shapes, latent_shape, n_scales = 8)

enc_up, hidden_shapes = vunet.create_enc_up(output_shape, n_scales = 5)
enc_down = vunet.create_enc_down(hidden_shapes[-1])
dec_up = vunet.create_dec_up(input_shape, n_scales = 5) # only c input
dec_down = vunet.create_dec_down(hidden_shapes, hidden_shapes[-1], n_scales = 5)

enc_up.load_weights(output_dir + 'enc_up_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
enc_down.load_weights(output_dir + 'enc_down_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
dec_up.load_weights(output_dir + 'dec_up_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
dec_down.load_weights(output_dir + 'dec_down_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))

# %% [markdown]
# #### Transfer forward pass (the only test task we care about)

# %%
# xc = Input(shape=input_shape) # perm + well location
# c = Input(shape=(128,128,1)) # well location

# hs = enc_up(xc)
# z_posterior_sample, z_posterior_mean = enc_down(hs[-1])
# gs = dec_up(c)
# x_hat, z_piror_sample, z_piror_mean = dec_down([z_posterior_mean, *gs])

# v_unet_model = Model([xc, c], [x_hat])

# %%
xc = Input(shape=input_shape) # perm + well location
c = Input(shape=(128,128,1)) # well location

hs = enc_up(c)
z_posterior_sample, z_posterior_mean = enc_down(hs[-1])
gs = dec_up(xc)
x_hat, z_piror_sample, z_piror_mean = dec_down([z_posterior_mean, *gs])

v_unet_model = Model([xc, c], [x_hat])

# %%
sat_pred_eval = v_unet_model.predict([test_x, test_x[:,:,:,[1]]])
sat_pred_eval.shape
# Out:
# (100, 128, 128, 1)

# %%
sat_pred_train = v_unet_model.predict([train_x[:10,...], train_x[:10,:,:,[1]]])
sat_pred_train.shape
# Out:
# (10, 128, 128, 1)

# %%
num_test = 7
k_fig = plt.figure()
plt.imshow(test_x[num_test,:,:,0]*1000)
plt.colorbar(fraction=0.046)

# %%
# num_test = 7

# for i in range(16):
#     fig = plt.figure(figsize=(15,3))
#     plt.set_cmap('gray')
    
#     plt.subplot(1,3,1)
#     plt.imshow(vae_weights[0][:,:,0,i])
#     plt.colorbar(fraction=0.046)
# #     plt.clim([-0.1, 0.1])

#     plt.subplot(1,3,2)
#     plt.imshow(vae_weights[0][:,:,1,i])
#     plt.colorbar(fraction=0.046)
# #     plt.clim([-0.1, 0.1])

#     plt.subplot(1,3,3)
# #     plt.set_cmap('jet')
#     plt.imshow(sat_pred_eval[0][num_test,:,:,i])
#     plt.colorbar(fraction=0.046)
# #     fig.savefig('layer1'+'channel'+str(i)+'.png')

# %%
# plt.set_cmap('jet')
# # k_fig = plt.figure()
# # plt.imshow(test_x[0,:,:,0])
# # plt.colorbar(fraction=0.046)
# # k_fig.savefig('k.png')
# layer = 11
# for i in range(32):
#     fig = plt.figure()
#     plt.imshow(sat_pred_eval[layer-1][0,:,:,i])
#     plt.colorbar(fraction=0.046)
#     fig.savefig('figs/layer'+str(layer)+'channel'+str(i)+'.png')
# Out:
# /data3/Astro/global/miniconda3/envs/tf-1.10.0/lib/python3.6/site-packages/matplotlib/pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %%
# epoch_plot = np.asarray(epoch_plot_list)+1
# rec_loss = np.asarray(rec_loss_list)/16384/16
# eval_loss = np.asarray(eval_loss_list)/16384/16
# rec_loss = np.sqrt(rec_loss)
# eval_loss = np.sqrt(eval_loss)
# print(epoch_plot)
# print(rec_loss)
# print(eval_loss)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-e669792aac3d> in <module>
# ----> 1 epoch_plot = np.asarray(epoch_plot_list)+1
#       2 rec_loss = np.asarray(rec_loss_list)/16384/16
#       3 eval_loss = np.asarray(eval_loss_list)/16384/16
#       4 rec_loss = np.sqrt(rec_loss)
#       5 eval_loss = np.sqrt(eval_loss)
#
# NameError: name 'epoch_plot_list' is not defined

# %%
# # Data for plotting
# fig, ax = plt.subplots()
# ax.plot(epoch_plot, rec_loss,  'k--', label='train')
# ax.plot(epoch_plot, eval_loss,  'k:', label='test')


# legend = ax.legend(loc='upper right', fontsize='large')

# ax.set(xlabel='epoch', ylabel='Mean Absolute Error',
#         title='20,000 Training Samples')
# ax.grid()

# fig.savefig("test.png")
# plt.show()

# %%
train_inj_plot = train_x * 200
train_inj_plot[:, :, 1 ,1] = train_inj_plot[:, :, 0, 1]
train_inj_plot[:, :, 2 ,1] = train_inj_plot[:, :, 0, 1]
test_inj_plot = test_x * 200
test_inj_plot[:, :, 1 ,1] = test_inj_plot[:, :, 0, 1]
test_inj_plot[:, :, 2 ,1] = test_inj_plot[:, :, 0, 1]

# %% [markdown]
# ## Train simulation results

# %%
for k in range(0,5):
    plt.figure(k,figsize=(15,3))
    
    plt.subplot(1,5,1)
    plt.title('k (mD)')
    plt.imshow(train_x[k, :, :, 0] * 1000)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,2)
    plt.title('Injection (day)')
    plt.imshow(train_inj_plot[k, :, :, 1])
    plt.clim(0, 200)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,3)
    inj = test_x[k, 1, 1, 0]*50
    plt.title('SG (true)')
    plt.imshow(train_y[k, :, :, 0].reshape(128, 128))
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,4)
    plt.imshow(sat_pred_train[k, :, :, 0].reshape(128, 128))
    plt.title('SG (pred)')
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,5)
    rel_err = np.abs((sat_pred_train[k, :, :, 0] - train_y[k, :, :, 0]))
    plt.imshow(rel_err) 
    plt.title('Abs Error')
    plt.colorbar(fraction=0.046)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Test simulation results

# %%
for k in range(0,5):
    plt.figure(k,figsize=(15,3))
    
    plt.subplot(1,5,1)
    plt.title('x (permeability)')
    plt.imshow(test_x[k, :, :, 0] * 1000)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,2)
    plt.title('Injection (day)')
    plt.imshow(test_inj_plot[k, :, :, 1])
    plt.clim(0, 200)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,3)
    inj = test_x[k, 1, 1, 0]*50
    plt.title('y (CO2 saturation)')
    plt.imshow(test_y[k, :, :, 0].reshape(128, 128))
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,4)
    plt.imshow(sat_pred_eval[k, :, :, 0].reshape(128, 128))
    plt.title('$\hat{y}$ (CO2 saturation)')
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,5)
    abs_err = np.abs((sat_pred_eval[k, :, :, 0] - test_y[k, :, :, 0]))
    plt.imshow(abs_err) 
    plt.title('Absolute Error')
    plt.colorbar(fraction=0.046)
    plt.clim([0, 0.2])
    plt.tight_layout()
    plt.show()
