# %%
import numpy as np
# import unet
import unet_gege
import os
os.environ["CUDA_VISIBLE_DEVICES"]="1"
from keras import backend as K
from keras.layers import Input
from keras.models import Model
from keras.optimizers import Adam
import h5py
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.set_cmap('jet')

# %%
import tensorflow as tf
from keras import backend as K

# tf.session specification
# TensorFlow wizardry
config = tf.ConfigProto()

# Don't pre-allocate memory; allocate as-needed
config.gpu_options.allow_growth = True

# Only allow a total of half the GPU memory to be allocated
config.gpu_options.per_process_gpu_memory_fraction = 0.5

# Create a session with the above options specified.
K.tensorflow_backend.set_session(tf.Session(config=config))

# %% [markdown]
# # Load data

# %%
output_dir = 'saved_models/'
case_string = 'well_control_128x128'

# %%
data_dir = '/data/cees/gegewen/well_control_data/'

hf_r = h5py.File(data_dir + 'train_' + case_string + '_40000.hdf5', 'r')
# hf_r = h5py.File(data_dir + 'train_' + case_string + '_400.hdf5', 'r')
train_x = np.array(hf_r.get('k'))
train_y = np.array(hf_r.get('S'))
hf_r.close()

# %%
hf_w = h5py.File(data_dir + 'test_' + case_string + '_8000.hdf5', 'r')
# hf_w = h5py.File(data_dir + 'test_' + case_string + '_80.hdf5', 'r')
test_x = np.array(hf_w.get('k'))
test_y = np.array(hf_w.get('S'))
hf_w.close()

# %%
print('train_x shape is ', train_x.shape)
print('train_y shape is ', train_y.shape)
print('test_x shape is ', test_x.shape)
print('test_y shape is ', test_y.shape)
# Out:
# train_x shape is  (40000, 128, 128, 2)
# train_y shape is  (40000, 128, 128, 1)
# test_x shape is  (8000, 128, 128, 2)
# test_y shape is  (8000, 128, 128, 1)

# %%
train_x = train_x[:20000, ...]
train_y = train_y[:20000, ...]
test_x = test_x[:100, ...]
test_y = test_y[:100, ...]
print('train_x shape is ', train_x.shape)
print('train_y shape is ', train_y.shape)
print('test_x shape ', test_x.shape)
print('test_y shape ', test_y.shape)
# Out:
# train_x shape is  (20000, 128, 128, 2)
# train_y shape is  (20000, 128, 128, 1)
# test_x shape  (100, 128, 128, 2)
# test_y shape  (100, 128, 128, 1)

# %% [markdown]
# ### Plot training dataset, train (Optional)

# %%
for k in range(5):
    plt.figure(k,figsize=(15,3))
    
    plt.subplot(1,5,1)
    plt.title('k (mD)')
    plt.imshow(train_x[k, :, :, 0] * 1000)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,2)
    plt.title('Injection (day)')
    plot_k = train_x[k, :, :, 1]
    plt.imshow(plot_k)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,3)
    plt.title('SG (true)')
    plt.imshow(train_y[k, :, :, 0].reshape(128, 128))
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### Plot test dataset, test (Optional)

# %%
for k in range(5):
    plt.figure(k,figsize=(15,3))
    
    plt.subplot(1,5,1)
    plt.title('k (mD)')
    plt.imshow(test_x[k, :, :, 0] * 1000)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,2)
    plt.title('Injection (day)')
    plot_k = test_x[k, :, :, 1]
    plt.imshow(plot_k)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,3)
    plt.title('SG (true)')
    plt.imshow(test_y[k, :, :, 0].reshape(128, 128))
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    

    plt.tight_layout()
    plt.show()

# %% [markdown]
# # Training starts here
# ### Bypass this part if you only want test

# %%
# reload module, in case needed
# from importlib import reload
# reload(unet)
# Out:
# <module 'unet_2' from '/data/cees/zjin/cs231n/project/var-unet/unet_2.py'>

# %%
input_shape = (128, 128, 2)
output_shape = (128, 128, 1)

# %% [markdown]
# ### Load the model of choice u-net

# %%
unet_model = unet_gege.create_vae(input_shape)
# unet_model.summary()

# %% [markdown]
# #### Train forward pass

# %%
# unet_up, hidden_shapes = unet.create_unet_up(input_shape)
# unet_down = unet.create_unet_down(hidden_shapes)
# #     unet_up.summary()
# #     unet_down.summary()

xc = Input(shape=input_shape) # perm + well location|
c = Input(shape=output_shape) # well location

# hidden_layers = unet_up(xc)
# x_hat = unet_down(hidden_layers)    
x_hat = unet_model(xc)

# %% [markdown]
# #### Define loss functions

# %%
def likelihood_loss(x, x_hat):
    '''
    Reconstruction loss, L2 norm
    '''
    v = 0.1
    return K.mean(K.sum((K.batch_flatten(x) - K.batch_flatten(x_hat)) ** 2 / (2*v), axis=-1))

def latent_kl_loss(q, p):
    mean1 = q
    mean2 = p
    
    kl = 0.5 * (mean2 - mean1)**2
    kl = K.sum(kl, axis = [1,2,3])
    kl = K.mean(kl)
    return kl

# %% [markdown]
# #### Compute loss

# %%
x = Input(shape=output_shape) # target saturation

likelihood_loss_value = likelihood_loss(x, x_hat)
# kl_loss = latent_kl_loss(z_posterior_mean, z_piror_mean)
# kl_weight = 5.0
# total_loss = likelihood_loss_value + kl_weight * kl_loss
total_loss = likelihood_loss_value

# %% [markdown]
# #### Build computation graph

# %%
epoch = 150
learning_rate = 5e-4
train_nr = train_x.shape[0]
test_nr = test_x.shape[0]
batch_size = 16
num_batch = int(train_nr/batch_size)

# %%
opt = Adam(lr=learning_rate)

# trainable_weights = unet_up.trainable_weights + unet_down.trainable_weights
trainable_weights = unet_model.trainable_weights

updates = opt.get_updates(total_loss, trainable_weights)

iterate = K.function([xc, c, x], [total_loss], updates=updates)

eval_loss = K.function([xc, c, x], [total_loss])

# %% [markdown]
# #### Start training

# %%
train_loss_record = []
test_loss_record =[]

for e in range(epoch):
    for ib in range(num_batch):
        ind0 = ib * batch_size
        x_batch = train_x[ind0:ind0+batch_size, ...]
        y_batch = train_y[ind0:ind0+batch_size, ...]
        
        train_losses = iterate([x_batch, x_batch[:,:,:,[1]], y_batch])
        if ib % 50 == 0:
            print('Epoch %d/%d, Batch %d/%d, Total Loss %f' %(e+1, epoch, ib+1, num_batch, train_losses[0]))
        
        eval_losses = eval_loss([test_x, test_x[:,:,:,[1]], test_y])
    train_loss_record.append(train_losses[0])
    test_loss_record.append(eval_losses[0])

    print('====================================================')
    print('\n')
    print('Epoch %d/%d, Train Total Loss %f, Eval Total Loss %f' % (e + 1, epoch, train_losses[0], eval_losses[0]))
    print('\n')
    print('====================================================')
# unet_up.save_weights(output_dir + 'unet_up_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
# unet_down.save_weights(output_dir + 'unet_down_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
unet_model.save_weights(output_dir + 'unet_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
# Out:
# Epoch 1/150, Batch 1/1250, Total Loss 1087.951660
# Epoch 1/150, Batch 51/1250, Total Loss 587.038696
# Epoch 1/150, Batch 101/1250, Total Loss 469.838745
# Epoch 1/150, Batch 151/1250, Total Loss 343.186676
# Epoch 1/150, Batch 201/1250, Total Loss 212.986176
# Epoch 1/150, Batch 251/1250, Total Loss 144.132965
# Epoch 1/150, Batch 301/1250, Total Loss 128.866776
# Epoch 1/150, Batch 351/1250, Total Loss 128.038208
# Epoch 1/150, Batch 401/1250, Total Loss 117.616463
# Epoch 1/150, Batch 451/1250, Total Loss 152.767990
# Epoch 1/150, Batch 501/1250, Total Loss 100.506256
# Epoch 1/150, Batch 551/1250, Total Loss 138.573746
# Epoch 1/150, Batch 601/1250, Total Loss 89.421188
# Epoch 1/150, Batch 651/1250, Total Loss 93.407928
# Epoch 1/150, Batch 701/1250, Total Loss 80.213043
# Epoch 1/150, Batch 751/1250, Total Loss 100.854301
# Epoch 1/150, Batch 801/1250, Total Loss 62.628567
# Epoch 1/150, Batch 851/1250, Total Loss 83.723465
# Epoch 1/150, Batch 901/1250, Total Loss 59.714470
# Epoch 1/150, Batch 951/1250, Total Loss 89.866203
# Epoch 1/150, Batch 1001/1250, Total Loss 47.790260
# Epoch 1/150, Batch 1051/1250, Total Loss 71.629936
# Epoch 1/150, Batch 1101/1250, Total Loss 57.626846
# Epoch 1/150, Batch 1151/1250, Total Loss 50.858303
# Epoch 1/150, Batch 1201/1250, Total Loss 44.954239
# ====================================================
#
#
# Epoch 1/150, Train Total Loss 76.047699, Eval Total Loss 73.295921
#
#
# ====================================================
# Epoch 2/150, Batch 1/1250, Total Loss 75.999344
# Epoch 2/150, Batch 51/1250, Total Loss 57.632401
# Epoch 2/150, Batch 101/1250, Total Loss 61.741287
# Epoch 2/150, Batch 151/1250, Total Loss 69.243637
# Epoch 2/150, Batch 201/1250, Total Loss 44.135040
# Epoch 2/150, Batch 251/1250, Total Loss 44.115601
# Epoch 2/150, Batch 301/1250, Total Loss 34.813332
# Epoch 2/150, Batch 351/1250, Total Loss 53.300709
# Epoch 2/150, Batch 401/1250, Total Loss 44.300697
# Epoch 2/150, Batch 451/1250, Total Loss 81.652390
# Epoch 2/150, Batch 501/1250, Total Loss 49.311073
# Epoch 2/150, Batch 551/1250, Total Loss 82.966057
# Epoch 2/150, Batch 601/1250, Total Loss 49.726784
# Epoch 2/150, Batch 651/1250, Total Loss 35.079971
# Epoch 2/150, Batch 701/1250, Total Loss 35.171432
# Epoch 2/150, Batch 751/1250, Total Loss 56.754608
# Epoch 2/150, Batch 801/1250, Total Loss 34.414043
# Epoch 2/150, Batch 851/1250, Total Loss 48.042473
# Epoch 2/150, Batch 901/1250, Total Loss 35.752487
# Epoch 2/150, Batch 951/1250, Total Loss 51.064651
# Epoch 2/150, Batch 1001/1250, Total Loss 45.081520
# Epoch 2/150, Batch 1051/1250, Total Loss 52.216206
# Epoch 2/150, Batch 1101/1250, Total Loss 37.012749
# Epoch 2/150, Batch 1151/1250, Total Loss 24.676195
# Epoch 2/150, Batch 1201/1250, Total Loss 30.638519
# ====================================================
#
#
# Epoch 2/150, Train Total Loss 64.224518, Eval Total Loss 47.021351
#
#
# ====================================================
# Epoch 3/150, Batch 1/1250, Total Loss 45.452698
# Epoch 3/150, Batch 51/1250, Total Loss 38.127266
# Epoch 3/150, Batch 101/1250, Total Loss 52.732975
# Epoch 3/150, Batch 151/1250, Total Loss 37.293922
# Epoch 3/150, Batch 201/1250, Total Loss 32.631424
# Epoch 3/150, Batch 251/1250, Total Loss 32.384033
# Epoch 3/150, Batch 301/1250, Total Loss 28.757414
# Epoch 3/150, Batch 351/1250, Total Loss 34.096458
# Epoch 3/150, Batch 401/1250, Total Loss 33.810211
# Epoch 3/150, Batch 451/1250, Total Loss 43.080624
# Epoch 3/150, Batch 501/1250, Total Loss 41.738525
# Epoch 3/150, Batch 551/1250, Total Loss 48.649620
# Epoch 3/150, Batch 601/1250, Total Loss 51.163559
# Epoch 3/150, Batch 651/1250, Total Loss 24.978710
# Epoch 3/150, Batch 701/1250, Total Loss 23.861633
# Epoch 3/150, Batch 751/1250, Total Loss 39.004822
# Epoch 3/150, Batch 801/1250, Total Loss 22.992493
# Epoch 3/150, Batch 851/1250, Total Loss 34.032524
# Epoch 3/150, Batch 901/1250, Total Loss 29.126141
# Epoch 3/150, Batch 951/1250, Total Loss 45.325157
# Epoch 3/150, Batch 1001/1250, Total Loss 46.505386
# Epoch 3/150, Batch 1051/1250, Total Loss 28.985130
# Epoch 3/150, Batch 1101/1250, Total Loss 29.292093
# Epoch 3/150, Batch 1151/1250, Total Loss 19.549351
# Epoch 3/150, Batch 1201/1250, Total Loss 23.542656
# ====================================================
#
#
# Epoch 3/150, Train Total Loss 39.544243, Eval Total Loss 30.128784
#
#
# ====================================================
# Epoch 4/150, Batch 1/1250, Total Loss 33.541836
# Epoch 4/150, Batch 51/1250, Total Loss 30.346594
# Epoch 4/150, Batch 101/1250, Total Loss 39.714836
# Epoch 4/150, Batch 151/1250, Total Loss 29.393059
# Epoch 4/150, Batch 201/1250, Total Loss 19.245110
# Epoch 4/150, Batch 251/1250, Total Loss 24.336185
# Epoch 4/150, Batch 301/1250, Total Loss 27.141895
# Epoch 4/150, Batch 351/1250, Total Loss 24.190187
# Epoch 4/150, Batch 401/1250, Total Loss 46.175648
# Epoch 4/150, Batch 451/1250, Total Loss 36.948685
# Epoch 4/150, Batch 501/1250, Total Loss 29.190718
# Epoch 4/150, Batch 551/1250, Total Loss 50.437656
# Epoch 4/150, Batch 601/1250, Total Loss 35.739441
# Epoch 4/150, Batch 651/1250, Total Loss 22.840302
# Epoch 4/150, Batch 701/1250, Total Loss 25.116976
# Epoch 4/150, Batch 751/1250, Total Loss 31.499113
# Epoch 4/150, Batch 801/1250, Total Loss 22.660921
# Epoch 4/150, Batch 851/1250, Total Loss 29.132933
# Epoch 4/150, Batch 901/1250, Total Loss 23.384848
# Epoch 4/150, Batch 951/1250, Total Loss 32.022003
# Epoch 4/150, Batch 1001/1250, Total Loss 28.548662
# Epoch 4/150, Batch 1051/1250, Total Loss 25.048313
# Epoch 4/150, Batch 1101/1250, Total Loss 23.591259
# Epoch 4/150, Batch 1151/1250, Total Loss 19.012159
# Epoch 4/150, Batch 1201/1250, Total Loss 19.302273
# ====================================================
#
#
# Epoch 4/150, Train Total Loss 31.407593, Eval Total Loss 31.997303
#
#
# ====================================================
# Epoch 5/150, Batch 1/1250, Total Loss 37.090813
# Epoch 5/150, Batch 51/1250, Total Loss 27.336103
# Epoch 5/150, Batch 101/1250, Total Loss 31.346245
# Epoch 5/150, Batch 151/1250, Total Loss 22.460928
# Epoch 5/150, Batch 201/1250, Total Loss 18.735004
# Epoch 5/150, Batch 251/1250, Total Loss 20.800940
# Epoch 5/150, Batch 301/1250, Total Loss 22.486713
# Epoch 5/150, Batch 351/1250, Total Loss 22.799404
# Epoch 5/150, Batch 401/1250, Total Loss 29.226278
# Epoch 5/150, Batch 451/1250, Total Loss 28.312057
# Epoch 5/150, Batch 501/1250, Total Loss 22.699684
# Epoch 5/150, Batch 551/1250, Total Loss 33.807091
# Epoch 5/150, Batch 601/1250, Total Loss 28.242374
# Epoch 5/150, Batch 651/1250, Total Loss 24.867241
# Epoch 5/150, Batch 701/1250, Total Loss 18.911797
# Epoch 5/150, Batch 751/1250, Total Loss 21.040920
# Epoch 5/150, Batch 801/1250, Total Loss 21.648781
# Epoch 5/150, Batch 851/1250, Total Loss 25.121010
# Epoch 5/150, Batch 901/1250, Total Loss 24.121689
# Epoch 5/150, Batch 951/1250, Total Loss 34.235847
# Epoch 5/150, Batch 1001/1250, Total Loss 26.092318
# Epoch 5/150, Batch 1051/1250, Total Loss 19.061932
# Epoch 5/150, Batch 1101/1250, Total Loss 26.083582
# Epoch 5/150, Batch 1151/1250, Total Loss 24.144535
# Epoch 5/150, Batch 1201/1250, Total Loss 18.684589
# ====================================================
#
#
# Epoch 5/150, Train Total Loss 28.960159, Eval Total Loss 33.224613
#
#
# ====================================================
# Epoch 6/150, Batch 1/1250, Total Loss 34.184490
# Epoch 6/150, Batch 51/1250, Total Loss 23.044321
# Epoch 6/150, Batch 101/1250, Total Loss 22.868826
# Epoch 6/150, Batch 151/1250, Total Loss 23.653616
# Epoch 6/150, Batch 201/1250, Total Loss 23.280548
# Epoch 6/150, Batch 251/1250, Total Loss 24.133266
# Epoch 6/150, Batch 301/1250, Total Loss 18.518810
# Epoch 6/150, Batch 351/1250, Total Loss 23.156082
# Epoch 6/150, Batch 401/1250, Total Loss 25.995668
# Epoch 6/150, Batch 451/1250, Total Loss 37.439117
# Epoch 6/150, Batch 501/1250, Total Loss 21.105148
# Epoch 6/150, Batch 551/1250, Total Loss 34.289059
# Epoch 6/150, Batch 601/1250, Total Loss 43.988449
# Epoch 6/150, Batch 651/1250, Total Loss 17.078520
# Epoch 6/150, Batch 701/1250, Total Loss 16.047421
# Epoch 6/150, Batch 751/1250, Total Loss 21.091404
# Epoch 6/150, Batch 801/1250, Total Loss 19.703827
# Epoch 6/150, Batch 851/1250, Total Loss 24.244865
# Epoch 6/150, Batch 901/1250, Total Loss 20.842388
# Epoch 6/150, Batch 951/1250, Total Loss 30.382679
# Epoch 6/150, Batch 1001/1250, Total Loss 25.269310
# Epoch 6/150, Batch 1051/1250, Total Loss 24.336983
# Epoch 6/150, Batch 1101/1250, Total Loss 16.821291
# Epoch 6/150, Batch 1151/1250, Total Loss 26.298489
# Epoch 6/150, Batch 1201/1250, Total Loss 19.523367
# ====================================================
#
#
# Epoch 6/150, Train Total Loss 30.529179, Eval Total Loss 31.522263
#
#
# ====================================================
# Epoch 7/150, Batch 1/1250, Total Loss 29.368038
# Epoch 7/150, Batch 51/1250, Total Loss 21.393230
# Epoch 7/150, Batch 101/1250, Total Loss 20.411728
# Epoch 7/150, Batch 151/1250, Total Loss 19.460945
# Epoch 7/150, Batch 201/1250, Total Loss 17.165977
# Epoch 7/150, Batch 251/1250, Total Loss 24.209267
# Epoch 7/150, Batch 301/1250, Total Loss 15.045370
# Epoch 7/150, Batch 351/1250, Total Loss 29.709213
# Epoch 7/150, Batch 401/1250, Total Loss 20.256565
# Epoch 7/150, Batch 451/1250, Total Loss 22.576099
# Epoch 7/150, Batch 501/1250, Total Loss 17.033907
# Epoch 7/150, Batch 551/1250, Total Loss 29.454063
# Epoch 7/150, Batch 601/1250, Total Loss 32.375935
# Epoch 7/150, Batch 651/1250, Total Loss 14.945524
# Epoch 7/150, Batch 701/1250, Total Loss 15.199348
# Epoch 7/150, Batch 751/1250, Total Loss 20.247538
# Epoch 7/150, Batch 801/1250, Total Loss 16.141022
# Epoch 7/150, Batch 851/1250, Total Loss 24.986671
# Epoch 7/150, Batch 901/1250, Total Loss 25.237719
# Epoch 7/150, Batch 951/1250, Total Loss 20.705467
# Epoch 7/150, Batch 1001/1250, Total Loss 18.237265
# Epoch 7/150, Batch 1051/1250, Total Loss 21.866920
# Epoch 7/150, Batch 1101/1250, Total Loss 21.127913
# Epoch 7/150, Batch 1151/1250, Total Loss 12.464374
# Epoch 7/150, Batch 1201/1250, Total Loss 16.670635
# ====================================================
#
#
# Epoch 7/150, Train Total Loss 19.631763, Eval Total Loss 25.365652
#
#
# ====================================================
# Epoch 8/150, Batch 1/1250, Total Loss 23.465229
# Epoch 8/150, Batch 51/1250, Total Loss 20.906395
# Epoch 8/150, Batch 101/1250, Total Loss 20.983074
# Epoch 8/150, Batch 151/1250, Total Loss 17.699762
# Epoch 8/150, Batch 201/1250, Total Loss 15.439880
# Epoch 8/150, Batch 251/1250, Total Loss 25.018425
# Epoch 8/150, Batch 301/1250, Total Loss 16.306736
# Epoch 8/150, Batch 351/1250, Total Loss 21.336922
# Epoch 8/150, Batch 401/1250, Total Loss 30.041128
# Epoch 8/150, Batch 451/1250, Total Loss 27.099701
# Epoch 8/150, Batch 501/1250, Total Loss 17.104952
# Epoch 8/150, Batch 551/1250, Total Loss 29.992973
# Epoch 8/150, Batch 601/1250, Total Loss 18.887629
# Epoch 8/150, Batch 651/1250, Total Loss 15.632409
# Epoch 8/150, Batch 701/1250, Total Loss 16.582096
# Epoch 8/150, Batch 751/1250, Total Loss 17.658083
# Epoch 8/150, Batch 801/1250, Total Loss 16.451031
# Epoch 8/150, Batch 851/1250, Total Loss 18.507023
# Epoch 8/150, Batch 901/1250, Total Loss 19.100586
# Epoch 8/150, Batch 951/1250, Total Loss 23.228165
# Epoch 8/150, Batch 1001/1250, Total Loss 18.997911
# Epoch 8/150, Batch 1051/1250, Total Loss 19.481861
# Epoch 8/150, Batch 1101/1250, Total Loss 17.210478
# Epoch 8/150, Batch 1151/1250, Total Loss 13.225790
# Epoch 8/150, Batch 1201/1250, Total Loss 12.935440
# ====================================================
#
#
# Epoch 8/150, Train Total Loss 23.333162, Eval Total Loss 22.144934
#
#
# ====================================================
# Epoch 9/150, Batch 1/1250, Total Loss 21.662189
# Epoch 9/150, Batch 51/1250, Total Loss 19.958838
# Epoch 9/150, Batch 101/1250, Total Loss 16.965397
# Epoch 9/150, Batch 151/1250, Total Loss 17.736656
# Epoch 9/150, Batch 201/1250, Total Loss 16.683266
# Epoch 9/150, Batch 251/1250, Total Loss 16.675400
# Epoch 9/150, Batch 301/1250, Total Loss 12.557007
# Epoch 9/150, Batch 351/1250, Total Loss 18.553827
# Epoch 9/150, Batch 401/1250, Total Loss 21.639812
# Epoch 9/150, Batch 451/1250, Total Loss 17.472275
# Epoch 9/150, Batch 501/1250, Total Loss 16.119678
# Epoch 9/150, Batch 551/1250, Total Loss 33.526985
# Epoch 9/150, Batch 601/1250, Total Loss 33.124847
# Epoch 9/150, Batch 651/1250, Total Loss 15.043678
# Epoch 9/150, Batch 701/1250, Total Loss 14.143956
# Epoch 9/150, Batch 751/1250, Total Loss 15.446770
# Epoch 9/150, Batch 801/1250, Total Loss 16.709984
# Epoch 9/150, Batch 851/1250, Total Loss 17.168365
# Epoch 9/150, Batch 901/1250, Total Loss 20.316317
# Epoch 9/150, Batch 951/1250, Total Loss 23.958185
# Epoch 9/150, Batch 1001/1250, Total Loss 24.169769
# Epoch 9/150, Batch 1051/1250, Total Loss 19.509893
# Epoch 9/150, Batch 1101/1250, Total Loss 15.931931
# Epoch 9/150, Batch 1151/1250, Total Loss 14.751755
# Epoch 9/150, Batch 1201/1250, Total Loss 11.782786
# ====================================================
#
#
# Epoch 9/150, Train Total Loss 17.946781, Eval Total Loss 18.159920
#
#
# ====================================================
# Epoch 10/150, Batch 1/1250, Total Loss 17.531929
# Epoch 10/150, Batch 51/1250, Total Loss 17.392632
# Epoch 10/150, Batch 101/1250, Total Loss 16.483334
# Epoch 10/150, Batch 151/1250, Total Loss 15.113643
# Epoch 10/150, Batch 201/1250, Total Loss 12.605083
# Epoch 10/150, Batch 251/1250, Total Loss 23.728439
# Epoch 10/150, Batch 301/1250, Total Loss 14.260550
# Epoch 10/150, Batch 351/1250, Total Loss 16.532532
# Epoch 10/150, Batch 401/1250, Total Loss 17.604076
# Epoch 10/150, Batch 451/1250, Total Loss 19.380276
# Epoch 10/150, Batch 501/1250, Total Loss 12.236206
# Epoch 10/150, Batch 551/1250, Total Loss 21.782524
# Epoch 10/150, Batch 601/1250, Total Loss 14.943821
# Epoch 10/150, Batch 651/1250, Total Loss 13.861203
# Epoch 10/150, Batch 701/1250, Total Loss 13.965920
# Epoch 10/150, Batch 751/1250, Total Loss 16.698929
# Epoch 10/150, Batch 801/1250, Total Loss 16.643816
# Epoch 10/150, Batch 851/1250, Total Loss 19.074898
# Epoch 10/150, Batch 901/1250, Total Loss 17.869753
# Epoch 10/150, Batch 951/1250, Total Loss 23.475918
# Epoch 10/150, Batch 1001/1250, Total Loss 25.076019
# Epoch 10/150, Batch 1051/1250, Total Loss 20.106741
# Epoch 10/150, Batch 1101/1250, Total Loss 19.056465
# Epoch 10/150, Batch 1151/1250, Total Loss 12.651663
# Epoch 10/150, Batch 1201/1250, Total Loss 11.116718
# ====================================================
#
#
# Epoch 10/150, Train Total Loss 15.978666, Eval Total Loss 18.241734
#
#
# ====================================================
# Epoch 11/150, Batch 1/1250, Total Loss 15.721873
# Epoch 11/150, Batch 51/1250, Total Loss 17.126436
# Epoch 11/150, Batch 101/1250, Total Loss 22.779127
# Epoch 11/150, Batch 151/1250, Total Loss 14.296142
# Epoch 11/150, Batch 201/1250, Total Loss 14.096958
# Epoch 11/150, Batch 251/1250, Total Loss 16.956163
# Epoch 11/150, Batch 301/1250, Total Loss 13.067320
# Epoch 11/150, Batch 351/1250, Total Loss 14.476725
# Epoch 11/150, Batch 401/1250, Total Loss 19.735119
# Epoch 11/150, Batch 451/1250, Total Loss 21.188576
# Epoch 11/150, Batch 501/1250, Total Loss 15.829000
# Epoch 11/150, Batch 551/1250, Total Loss 26.766382
# Epoch 11/150, Batch 601/1250, Total Loss 29.237013
# Epoch 11/150, Batch 651/1250, Total Loss 15.196550
# Epoch 11/150, Batch 701/1250, Total Loss 21.260418
# Epoch 11/150, Batch 751/1250, Total Loss 13.106428
# Epoch 11/150, Batch 801/1250, Total Loss 13.061556
# Epoch 11/150, Batch 851/1250, Total Loss 21.687403
# Epoch 11/150, Batch 901/1250, Total Loss 17.871277
# Epoch 11/150, Batch 951/1250, Total Loss 18.617374
# Epoch 11/150, Batch 1001/1250, Total Loss 18.350159
# Epoch 11/150, Batch 1051/1250, Total Loss 15.339334
# Epoch 11/150, Batch 1101/1250, Total Loss 16.751495
# Epoch 11/150, Batch 1151/1250, Total Loss 12.919311
# Epoch 11/150, Batch 1201/1250, Total Loss 11.990598
# ====================================================
#
#
# Epoch 11/150, Train Total Loss 12.955291, Eval Total Loss 13.869768
#
#
# ====================================================
# Epoch 12/150, Batch 1/1250, Total Loss 14.106845
# Epoch 12/150, Batch 51/1250, Total Loss 15.353181
# Epoch 12/150, Batch 101/1250, Total Loss 17.041832
# Epoch 12/150, Batch 151/1250, Total Loss 12.321012
# Epoch 12/150, Batch 201/1250, Total Loss 11.848222
# Epoch 12/150, Batch 251/1250, Total Loss 17.764439
# Epoch 12/150, Batch 301/1250, Total Loss 10.673201
# Epoch 12/150, Batch 351/1250, Total Loss 25.622221
# Epoch 12/150, Batch 401/1250, Total Loss 23.309715
# Epoch 12/150, Batch 451/1250, Total Loss 15.386871
# Epoch 12/150, Batch 501/1250, Total Loss 13.694733
# Epoch 12/150, Batch 551/1250, Total Loss 22.856613
# Epoch 12/150, Batch 601/1250, Total Loss 18.396120
# Epoch 12/150, Batch 651/1250, Total Loss 16.143013
# Epoch 12/150, Batch 701/1250, Total Loss 13.372080
# Epoch 12/150, Batch 751/1250, Total Loss 13.034294
# Epoch 12/150, Batch 801/1250, Total Loss 11.429811
# Epoch 12/150, Batch 851/1250, Total Loss 17.828350
# Epoch 12/150, Batch 901/1250, Total Loss 15.559227
# Epoch 12/150, Batch 951/1250, Total Loss 16.095856
# Epoch 12/150, Batch 1001/1250, Total Loss 16.863422
# Epoch 12/150, Batch 1051/1250, Total Loss 16.166458
# Epoch 12/150, Batch 1101/1250, Total Loss 24.056870
# Epoch 12/150, Batch 1151/1250, Total Loss 10.152302
# Epoch 12/150, Batch 1201/1250, Total Loss 18.506145
# ====================================================
#
#
# Epoch 12/150, Train Total Loss 16.448233, Eval Total Loss 16.948359
#
#
# ====================================================
# Epoch 13/150, Batch 1/1250, Total Loss 15.126569
# Epoch 13/150, Batch 51/1250, Total Loss 15.826654
# Epoch 13/150, Batch 101/1250, Total Loss 16.118374
# Epoch 13/150, Batch 151/1250, Total Loss 13.874891
# Epoch 13/150, Batch 201/1250, Total Loss 11.078051
# Epoch 13/150, Batch 251/1250, Total Loss 13.965222
# Epoch 13/150, Batch 301/1250, Total Loss 9.647446
# Epoch 13/150, Batch 351/1250, Total Loss 17.565098
# Epoch 13/150, Batch 401/1250, Total Loss 20.739832
# Epoch 13/150, Batch 451/1250, Total Loss 14.617684
# Epoch 13/150, Batch 501/1250, Total Loss 9.615044
# Epoch 13/150, Batch 551/1250, Total Loss 18.535728
# Epoch 13/150, Batch 601/1250, Total Loss 13.597777
# Epoch 13/150, Batch 651/1250, Total Loss 13.764258
# Epoch 13/150, Batch 701/1250, Total Loss 16.455265
# Epoch 13/150, Batch 751/1250, Total Loss 15.089594
# Epoch 13/150, Batch 801/1250, Total Loss 11.127005
# Epoch 13/150, Batch 851/1250, Total Loss 16.997828
# Epoch 13/150, Batch 901/1250, Total Loss 16.040161
# Epoch 13/150, Batch 951/1250, Total Loss 19.382816
# Epoch 13/150, Batch 1001/1250, Total Loss 11.562654
# Epoch 13/150, Batch 1051/1250, Total Loss 17.367203
# Epoch 13/150, Batch 1101/1250, Total Loss 17.160542
# Epoch 13/150, Batch 1151/1250, Total Loss 7.755083
# Epoch 13/150, Batch 1201/1250, Total Loss 13.449016
# ====================================================
#
#
# Epoch 13/150, Train Total Loss 17.284168, Eval Total Loss 13.593732
#
#
# ====================================================
# Epoch 14/150, Batch 1/1250, Total Loss 11.937878
# Epoch 14/150, Batch 51/1250, Total Loss 12.462980
# Epoch 14/150, Batch 101/1250, Total Loss 22.909933
# Epoch 14/150, Batch 151/1250, Total Loss 13.078178
# Epoch 14/150, Batch 201/1250, Total Loss 11.482655
# Epoch 14/150, Batch 251/1250, Total Loss 13.987223
# Epoch 14/150, Batch 301/1250, Total Loss 7.685410
# Epoch 14/150, Batch 351/1250, Total Loss 13.132334
# Epoch 14/150, Batch 401/1250, Total Loss 16.938538
# Epoch 14/150, Batch 451/1250, Total Loss 12.176868
# Epoch 14/150, Batch 501/1250, Total Loss 14.005448
# Epoch 14/150, Batch 551/1250, Total Loss 23.089861
# Epoch 14/150, Batch 601/1250, Total Loss 14.303360
# Epoch 14/150, Batch 651/1250, Total Loss 9.991621
# Epoch 14/150, Batch 701/1250, Total Loss 11.400988
# Epoch 14/150, Batch 751/1250, Total Loss 12.733418
# Epoch 14/150, Batch 801/1250, Total Loss 12.952137
# Epoch 14/150, Batch 851/1250, Total Loss 14.001463
# Epoch 14/150, Batch 901/1250, Total Loss 13.492805
# Epoch 14/150, Batch 951/1250, Total Loss 17.628178
# Epoch 14/150, Batch 1001/1250, Total Loss 13.514518
# Epoch 14/150, Batch 1051/1250, Total Loss 17.668354
# Epoch 14/150, Batch 1101/1250, Total Loss 20.548130
# Epoch 14/150, Batch 1151/1250, Total Loss 11.287926
# Epoch 14/150, Batch 1201/1250, Total Loss 12.788593
# ====================================================
#
#
# Epoch 14/150, Train Total Loss 12.694221, Eval Total Loss 14.589272
#
#
# ====================================================
# Epoch 15/150, Batch 1/1250, Total Loss 12.141535
# Epoch 15/150, Batch 51/1250, Total Loss 12.125376
# Epoch 15/150, Batch 101/1250, Total Loss 12.874806
# Epoch 15/150, Batch 151/1250, Total Loss 11.618984
# Epoch 15/150, Batch 201/1250, Total Loss 10.301126
# Epoch 15/150, Batch 251/1250, Total Loss 13.229540
# Epoch 15/150, Batch 301/1250, Total Loss 10.308121
# Epoch 15/150, Batch 351/1250, Total Loss 12.385201
# Epoch 15/150, Batch 401/1250, Total Loss 16.408352
# Epoch 15/150, Batch 451/1250, Total Loss 11.410296
# Epoch 15/150, Batch 501/1250, Total Loss 10.316825
# Epoch 15/150, Batch 551/1250, Total Loss 18.006783
# Epoch 15/150, Batch 601/1250, Total Loss 18.875635
# Epoch 15/150, Batch 651/1250, Total Loss 22.549332
# Epoch 15/150, Batch 701/1250, Total Loss 10.349043
# Epoch 15/150, Batch 751/1250, Total Loss 13.531218
# Epoch 15/150, Batch 801/1250, Total Loss 9.084426
# Epoch 15/150, Batch 851/1250, Total Loss 19.832220
# Epoch 15/150, Batch 901/1250, Total Loss 14.421075
# Epoch 15/150, Batch 951/1250, Total Loss 19.043159
# Epoch 15/150, Batch 1001/1250, Total Loss 14.999689
# Epoch 15/150, Batch 1051/1250, Total Loss 17.819483
# Epoch 15/150, Batch 1101/1250, Total Loss 13.391261
# Epoch 15/150, Batch 1151/1250, Total Loss 9.559458
# Epoch 15/150, Batch 1201/1250, Total Loss 13.987968
# ====================================================
#
#
# Epoch 15/150, Train Total Loss 16.409853, Eval Total Loss 12.940934
#
#
# ====================================================
# Epoch 16/150, Batch 1/1250, Total Loss 12.205554
# Epoch 16/150, Batch 51/1250, Total Loss 11.442570
# Epoch 16/150, Batch 101/1250, Total Loss 12.833266
# Epoch 16/150, Batch 151/1250, Total Loss 11.043560
# Epoch 16/150, Batch 201/1250, Total Loss 15.300187
# Epoch 16/150, Batch 251/1250, Total Loss 13.048599
# Epoch 16/150, Batch 301/1250, Total Loss 8.927013
# Epoch 16/150, Batch 351/1250, Total Loss 9.237358
# Epoch 16/150, Batch 401/1250, Total Loss 14.528624
# Epoch 16/150, Batch 451/1250, Total Loss 9.803864
# Epoch 16/150, Batch 501/1250, Total Loss 8.812201
# Epoch 16/150, Batch 551/1250, Total Loss 16.790928
# Epoch 16/150, Batch 601/1250, Total Loss 8.324390
# Epoch 16/150, Batch 651/1250, Total Loss 9.110785
# Epoch 16/150, Batch 701/1250, Total Loss 8.644808
# Epoch 16/150, Batch 751/1250, Total Loss 12.346321
# Epoch 16/150, Batch 801/1250, Total Loss 8.824587
# Epoch 16/150, Batch 851/1250, Total Loss 11.029747
# Epoch 16/150, Batch 901/1250, Total Loss 15.940825
# Epoch 16/150, Batch 951/1250, Total Loss 14.986550
# Epoch 16/150, Batch 1001/1250, Total Loss 15.238098
# Epoch 16/150, Batch 1051/1250, Total Loss 12.964733
# Epoch 16/150, Batch 1101/1250, Total Loss 9.779718
# Epoch 16/150, Batch 1151/1250, Total Loss 8.819801
# Epoch 16/150, Batch 1201/1250, Total Loss 7.119573
# ====================================================
#
#
# Epoch 16/150, Train Total Loss 10.942500, Eval Total Loss 13.607024
#
#
# ====================================================
# Epoch 17/150, Batch 1/1250, Total Loss 8.957590
# Epoch 17/150, Batch 51/1250, Total Loss 11.163355
# Epoch 17/150, Batch 101/1250, Total Loss 10.478099
# Epoch 17/150, Batch 151/1250, Total Loss 11.081877
# Epoch 17/150, Batch 201/1250, Total Loss 8.216860
# Epoch 17/150, Batch 251/1250, Total Loss 14.193920
# Epoch 17/150, Batch 301/1250, Total Loss 8.057133
# Epoch 17/150, Batch 351/1250, Total Loss 9.629339
# Epoch 17/150, Batch 401/1250, Total Loss 15.649685
# Epoch 17/150, Batch 451/1250, Total Loss 9.046513
# Epoch 17/150, Batch 501/1250, Total Loss 9.971097
# Epoch 17/150, Batch 551/1250, Total Loss 17.078527
# Epoch 17/150, Batch 601/1250, Total Loss 14.001090
# Epoch 17/150, Batch 651/1250, Total Loss 12.080538
# Epoch 17/150, Batch 701/1250, Total Loss 7.736855
# Epoch 17/150, Batch 751/1250, Total Loss 12.523384
# Epoch 17/150, Batch 801/1250, Total Loss 7.978396
# Epoch 17/150, Batch 851/1250, Total Loss 16.383991
# Epoch 17/150, Batch 901/1250, Total Loss 14.266071
# Epoch 17/150, Batch 951/1250, Total Loss 18.552464
# Epoch 17/150, Batch 1001/1250, Total Loss 17.019457
# Epoch 17/150, Batch 1051/1250, Total Loss 15.824472
# Epoch 17/150, Batch 1101/1250, Total Loss 10.088228
# Epoch 17/150, Batch 1151/1250, Total Loss 8.278047
# Epoch 17/150, Batch 1201/1250, Total Loss 16.190483
# ====================================================
#
#
# Epoch 17/150, Train Total Loss 10.970051, Eval Total Loss 11.920145
#
#
# ====================================================
# Epoch 18/150, Batch 1/1250, Total Loss 10.485224
# Epoch 18/150, Batch 51/1250, Total Loss 11.395760
# Epoch 18/150, Batch 101/1250, Total Loss 16.022264
# Epoch 18/150, Batch 151/1250, Total Loss 11.473669
# Epoch 18/150, Batch 201/1250, Total Loss 9.953897
# Epoch 18/150, Batch 251/1250, Total Loss 10.012882
# Epoch 18/150, Batch 301/1250, Total Loss 8.186861
# Epoch 18/150, Batch 351/1250, Total Loss 9.317741
# Epoch 18/150, Batch 401/1250, Total Loss 13.480665
# Epoch 18/150, Batch 451/1250, Total Loss 12.117498
# Epoch 18/150, Batch 501/1250, Total Loss 8.652778
# Epoch 18/150, Batch 551/1250, Total Loss 20.019760
# Epoch 18/150, Batch 601/1250, Total Loss 8.638882
# Epoch 18/150, Batch 651/1250, Total Loss 9.487658
# Epoch 18/150, Batch 701/1250, Total Loss 9.760326
# Epoch 18/150, Batch 751/1250, Total Loss 14.432477
# Epoch 18/150, Batch 801/1250, Total Loss 10.809858
# Epoch 18/150, Batch 851/1250, Total Loss 10.690134
# Epoch 18/150, Batch 901/1250, Total Loss 19.136665
# Epoch 18/150, Batch 951/1250, Total Loss 21.058805
# Epoch 18/150, Batch 1001/1250, Total Loss 15.626450
# Epoch 18/150, Batch 1051/1250, Total Loss 13.651433
# Epoch 18/150, Batch 1101/1250, Total Loss 16.677631
# Epoch 18/150, Batch 1151/1250, Total Loss 6.657647
# Epoch 18/150, Batch 1201/1250, Total Loss 9.761735
# ====================================================
#
#
# Epoch 18/150, Train Total Loss 11.142069, Eval Total Loss 12.113425
#
#
# ====================================================
# Epoch 19/150, Batch 1/1250, Total Loss 9.336444
# Epoch 19/150, Batch 51/1250, Total Loss 10.440182
# Epoch 19/150, Batch 101/1250, Total Loss 10.250019
# Epoch 19/150, Batch 151/1250, Total Loss 9.035622
# Epoch 19/150, Batch 201/1250, Total Loss 9.752562
# Epoch 19/150, Batch 251/1250, Total Loss 14.612566
# Epoch 19/150, Batch 301/1250, Total Loss 9.188166
# Epoch 19/150, Batch 351/1250, Total Loss 9.135549
# Epoch 19/150, Batch 401/1250, Total Loss 13.077025
# Epoch 19/150, Batch 451/1250, Total Loss 9.945084
# Epoch 19/150, Batch 501/1250, Total Loss 8.440790
# Epoch 19/150, Batch 551/1250, Total Loss 16.643997
# Epoch 19/150, Batch 601/1250, Total Loss 11.806000
# Epoch 19/150, Batch 651/1250, Total Loss 8.320695
# Epoch 19/150, Batch 701/1250, Total Loss 14.569446
# Epoch 19/150, Batch 751/1250, Total Loss 12.296921
# Epoch 19/150, Batch 801/1250, Total Loss 10.166494
# Epoch 19/150, Batch 851/1250, Total Loss 12.033166
# Epoch 19/150, Batch 901/1250, Total Loss 14.355897
# Epoch 19/150, Batch 951/1250, Total Loss 17.260593
# Epoch 19/150, Batch 1001/1250, Total Loss 7.303262
# Epoch 19/150, Batch 1051/1250, Total Loss 11.738422
# Epoch 19/150, Batch 1101/1250, Total Loss 11.301090
# Epoch 19/150, Batch 1151/1250, Total Loss 5.781713
# Epoch 19/150, Batch 1201/1250, Total Loss 10.728990
# ====================================================
#
#
# Epoch 19/150, Train Total Loss 14.970085, Eval Total Loss 12.346789
#
#
# ====================================================
# Epoch 20/150, Batch 1/1250, Total Loss 10.643816
# Epoch 20/150, Batch 51/1250, Total Loss 10.143835
# Epoch 20/150, Batch 101/1250, Total Loss 8.912655
# Epoch 20/150, Batch 151/1250, Total Loss 8.763667
# Epoch 20/150, Batch 201/1250, Total Loss 9.930848
# Epoch 20/150, Batch 251/1250, Total Loss 12.983482
# Epoch 20/150, Batch 301/1250, Total Loss 11.379675
# Epoch 20/150, Batch 351/1250, Total Loss 9.666480
# Epoch 20/150, Batch 401/1250, Total Loss 11.629979
# Epoch 20/150, Batch 451/1250, Total Loss 9.525995
# Epoch 20/150, Batch 501/1250, Total Loss 8.196226
# Epoch 20/150, Batch 551/1250, Total Loss 13.338488
# Epoch 20/150, Batch 601/1250, Total Loss 11.230118
# Epoch 20/150, Batch 651/1250, Total Loss 8.157534
# Epoch 20/150, Batch 701/1250, Total Loss 8.084163
# Epoch 20/150, Batch 751/1250, Total Loss 13.002753
# Epoch 20/150, Batch 801/1250, Total Loss 7.728932
# Epoch 20/150, Batch 851/1250, Total Loss 10.042465
# Epoch 20/150, Batch 901/1250, Total Loss 12.353825
# Epoch 20/150, Batch 951/1250, Total Loss 17.094433
# Epoch 20/150, Batch 1001/1250, Total Loss 8.148232
# Epoch 20/150, Batch 1051/1250, Total Loss 11.040692
# Epoch 20/150, Batch 1101/1250, Total Loss 9.027813
# Epoch 20/150, Batch 1151/1250, Total Loss 6.110365
# Epoch 20/150, Batch 1201/1250, Total Loss 12.049964
# ====================================================
#
#
# Epoch 20/150, Train Total Loss 17.730276, Eval Total Loss 13.915274
#
#
# ====================================================
# Epoch 21/150, Batch 1/1250, Total Loss 10.617205
# Epoch 21/150, Batch 51/1250, Total Loss 11.352217
# Epoch 21/150, Batch 101/1250, Total Loss 9.225782
# Epoch 21/150, Batch 151/1250, Total Loss 8.543951
# Epoch 21/150, Batch 201/1250, Total Loss 7.927489
# Epoch 21/150, Batch 251/1250, Total Loss 9.627076
# Epoch 21/150, Batch 301/1250, Total Loss 8.278952
# Epoch 21/150, Batch 351/1250, Total Loss 7.820332
# Epoch 21/150, Batch 401/1250, Total Loss 8.753790
# Epoch 21/150, Batch 451/1250, Total Loss 11.426054
# Epoch 21/150, Batch 501/1250, Total Loss 8.479004
# Epoch 21/150, Batch 551/1250, Total Loss 16.839174
# Epoch 21/150, Batch 601/1250, Total Loss 11.555558
# Epoch 21/150, Batch 651/1250, Total Loss 8.617207
# Epoch 21/150, Batch 701/1250, Total Loss 7.872381
# Epoch 21/150, Batch 751/1250, Total Loss 11.591551
# Epoch 21/150, Batch 801/1250, Total Loss 8.391239
# Epoch 21/150, Batch 851/1250, Total Loss 13.918634
# Epoch 21/150, Batch 901/1250, Total Loss 9.761248
# Epoch 21/150, Batch 951/1250, Total Loss 13.757133
# Epoch 21/150, Batch 1001/1250, Total Loss 12.873454
# Epoch 21/150, Batch 1051/1250, Total Loss 9.481380
# Epoch 21/150, Batch 1101/1250, Total Loss 11.494785
# Epoch 21/150, Batch 1151/1250, Total Loss 6.572035
# Epoch 21/150, Batch 1201/1250, Total Loss 9.526012
# ====================================================
#
#
# Epoch 21/150, Train Total Loss 11.299231, Eval Total Loss 11.505876
#
#
# ====================================================
# Epoch 22/150, Batch 1/1250, Total Loss 9.574596
# Epoch 22/150, Batch 51/1250, Total Loss 12.264807
# Epoch 22/150, Batch 101/1250, Total Loss 10.741141
# Epoch 22/150, Batch 151/1250, Total Loss 8.796955
# Epoch 22/150, Batch 201/1250, Total Loss 11.499192
# Epoch 22/150, Batch 251/1250, Total Loss 9.745701
# Epoch 22/150, Batch 301/1250, Total Loss 9.291318
# Epoch 22/150, Batch 351/1250, Total Loss 7.652623
# Epoch 22/150, Batch 401/1250, Total Loss 10.373833
# Epoch 22/150, Batch 451/1250, Total Loss 10.169390
# Epoch 22/150, Batch 501/1250, Total Loss 9.215615
# Epoch 22/150, Batch 551/1250, Total Loss 13.419196
# Epoch 22/150, Batch 601/1250, Total Loss 7.130143
# Epoch 22/150, Batch 651/1250, Total Loss 8.196445
# Epoch 22/150, Batch 701/1250, Total Loss 9.817114
# Epoch 22/150, Batch 751/1250, Total Loss 10.554209
# Epoch 22/150, Batch 801/1250, Total Loss 9.573046
# Epoch 22/150, Batch 851/1250, Total Loss 11.657844
# Epoch 22/150, Batch 901/1250, Total Loss 8.704007
# Epoch 22/150, Batch 951/1250, Total Loss 11.004636
# Epoch 22/150, Batch 1001/1250, Total Loss 8.347593
# Epoch 22/150, Batch 1051/1250, Total Loss 10.385664
# Epoch 22/150, Batch 1101/1250, Total Loss 8.718970
# Epoch 22/150, Batch 1151/1250, Total Loss 6.613601
# Epoch 22/150, Batch 1201/1250, Total Loss 10.470984
# ====================================================
#
#
# Epoch 22/150, Train Total Loss 11.286189, Eval Total Loss 13.180343
#
#
# ====================================================
# Epoch 23/150, Batch 1/1250, Total Loss 9.720243
# Epoch 23/150, Batch 51/1250, Total Loss 12.783269
# Epoch 23/150, Batch 101/1250, Total Loss 9.755969
# Epoch 23/150, Batch 151/1250, Total Loss 7.343690
# Epoch 23/150, Batch 201/1250, Total Loss 7.509257
# Epoch 23/150, Batch 251/1250, Total Loss 9.691468
# Epoch 23/150, Batch 301/1250, Total Loss 7.258951
# Epoch 23/150, Batch 351/1250, Total Loss 8.533628
# Epoch 23/150, Batch 401/1250, Total Loss 12.617376
# Epoch 23/150, Batch 451/1250, Total Loss 9.898858
# Epoch 23/150, Batch 501/1250, Total Loss 7.411895
# Epoch 23/150, Batch 551/1250, Total Loss 16.130737
# Epoch 23/150, Batch 601/1250, Total Loss 9.683956
# Epoch 23/150, Batch 651/1250, Total Loss 7.883775
# Epoch 23/150, Batch 701/1250, Total Loss 9.147197
# Epoch 23/150, Batch 751/1250, Total Loss 12.025789
# Epoch 23/150, Batch 801/1250, Total Loss 12.564472
# Epoch 23/150, Batch 851/1250, Total Loss 9.722245
# Epoch 23/150, Batch 901/1250, Total Loss 10.410786
# Epoch 23/150, Batch 951/1250, Total Loss 11.381722
# Epoch 23/150, Batch 1001/1250, Total Loss 9.164173
# Epoch 23/150, Batch 1051/1250, Total Loss 15.863567
# Epoch 23/150, Batch 1101/1250, Total Loss 8.464669
# Epoch 23/150, Batch 1151/1250, Total Loss 7.361808
# Epoch 23/150, Batch 1201/1250, Total Loss 6.977328
# ====================================================
#
#
# Epoch 23/150, Train Total Loss 12.635828, Eval Total Loss 9.630678
#
#
# ====================================================
# Epoch 24/150, Batch 1/1250, Total Loss 7.305388
# Epoch 24/150, Batch 51/1250, Total Loss 9.124329
# Epoch 24/150, Batch 101/1250, Total Loss 6.934216
# Epoch 24/150, Batch 151/1250, Total Loss 7.989895
# Epoch 24/150, Batch 201/1250, Total Loss 7.156258
# Epoch 24/150, Batch 251/1250, Total Loss 11.418707
# Epoch 24/150, Batch 301/1250, Total Loss 11.173479
# Epoch 24/150, Batch 351/1250, Total Loss 8.199394
# Epoch 24/150, Batch 401/1250, Total Loss 12.215576
# Epoch 24/150, Batch 451/1250, Total Loss 8.589554
# Epoch 24/150, Batch 501/1250, Total Loss 12.358688
# Epoch 24/150, Batch 551/1250, Total Loss 13.836643
# Epoch 24/150, Batch 601/1250, Total Loss 11.891870
# Epoch 24/150, Batch 651/1250, Total Loss 7.310124
# Epoch 24/150, Batch 701/1250, Total Loss 7.576226
# Epoch 24/150, Batch 751/1250, Total Loss 8.283493
# Epoch 24/150, Batch 801/1250, Total Loss 6.634153
# Epoch 24/150, Batch 851/1250, Total Loss 10.781545
# Epoch 24/150, Batch 901/1250, Total Loss 9.352546
# Epoch 24/150, Batch 951/1250, Total Loss 13.857784
# Epoch 24/150, Batch 1001/1250, Total Loss 7.450445
# Epoch 24/150, Batch 1051/1250, Total Loss 8.088919
# Epoch 24/150, Batch 1101/1250, Total Loss 6.587427
# Epoch 24/150, Batch 1151/1250, Total Loss 5.473468
# Epoch 24/150, Batch 1201/1250, Total Loss 11.297174
# ====================================================
#
#
# Epoch 24/150, Train Total Loss 19.273689, Eval Total Loss 14.475066
#
#
# ====================================================
# Epoch 25/150, Batch 1/1250, Total Loss 12.048914
# Epoch 25/150, Batch 51/1250, Total Loss 10.858128
# Epoch 25/150, Batch 101/1250, Total Loss 7.807045
# Epoch 25/150, Batch 151/1250, Total Loss 6.939510
# Epoch 25/150, Batch 201/1250, Total Loss 5.828352
# Epoch 25/150, Batch 251/1250, Total Loss 9.678160
# Epoch 25/150, Batch 301/1250, Total Loss 8.823084
# Epoch 25/150, Batch 351/1250, Total Loss 6.103244
# Epoch 25/150, Batch 401/1250, Total Loss 10.221459
# Epoch 25/150, Batch 451/1250, Total Loss 8.597472
# Epoch 25/150, Batch 501/1250, Total Loss 7.211881
# Epoch 25/150, Batch 551/1250, Total Loss 13.529016
# Epoch 25/150, Batch 601/1250, Total Loss 9.122837
# Epoch 25/150, Batch 651/1250, Total Loss 7.611365
# Epoch 25/150, Batch 701/1250, Total Loss 6.305608
# Epoch 25/150, Batch 751/1250, Total Loss 6.937490
# Epoch 25/150, Batch 801/1250, Total Loss 6.045245
# Epoch 25/150, Batch 851/1250, Total Loss 7.590733
# Epoch 25/150, Batch 901/1250, Total Loss 8.320164
# Epoch 25/150, Batch 951/1250, Total Loss 11.760986
# Epoch 25/150, Batch 1001/1250, Total Loss 5.366455
# Epoch 25/150, Batch 1051/1250, Total Loss 7.454896
# Epoch 25/150, Batch 1101/1250, Total Loss 5.835384
# Epoch 25/150, Batch 1151/1250, Total Loss 5.604943
# Epoch 25/150, Batch 1201/1250, Total Loss 5.377997
# ====================================================
#
#
# Epoch 25/150, Train Total Loss 10.819332, Eval Total Loss 9.985194
#
#
# ====================================================
# Epoch 26/150, Batch 1/1250, Total Loss 8.010567
# Epoch 26/150, Batch 51/1250, Total Loss 8.549799
# Epoch 26/150, Batch 101/1250, Total Loss 8.128035
# Epoch 26/150, Batch 151/1250, Total Loss 7.341735
# Epoch 26/150, Batch 201/1250, Total Loss 7.518711
# Epoch 26/150, Batch 251/1250, Total Loss 7.978662
# Epoch 26/150, Batch 301/1250, Total Loss 6.578251
# Epoch 26/150, Batch 351/1250, Total Loss 8.803335
# Epoch 26/150, Batch 401/1250, Total Loss 10.205152
# Epoch 26/150, Batch 451/1250, Total Loss 11.167203
# Epoch 26/150, Batch 501/1250, Total Loss 8.354127
# Epoch 26/150, Batch 551/1250, Total Loss 17.575186
# Epoch 26/150, Batch 601/1250, Total Loss 9.637503
# Epoch 26/150, Batch 651/1250, Total Loss 7.931540
# Epoch 26/150, Batch 701/1250, Total Loss 6.349548
# Epoch 26/150, Batch 751/1250, Total Loss 9.200720
# Epoch 26/150, Batch 801/1250, Total Loss 6.572921
# Epoch 26/150, Batch 851/1250, Total Loss 8.492355
# Epoch 26/150, Batch 901/1250, Total Loss 8.522890
# Epoch 26/150, Batch 951/1250, Total Loss 10.954575
# Epoch 26/150, Batch 1001/1250, Total Loss 8.056013
# Epoch 26/150, Batch 1051/1250, Total Loss 8.692826
# Epoch 26/150, Batch 1101/1250, Total Loss 6.374125
# Epoch 26/150, Batch 1151/1250, Total Loss 6.134661
# Epoch 26/150, Batch 1201/1250, Total Loss 7.018869
# ====================================================
#
#
# Epoch 26/150, Train Total Loss 6.556715, Eval Total Loss 8.905693
#
#
# ====================================================
# Epoch 27/150, Batch 1/1250, Total Loss 8.726979
# Epoch 27/150, Batch 51/1250, Total Loss 8.466507
# Epoch 27/150, Batch 101/1250, Total Loss 7.125858
# Epoch 27/150, Batch 151/1250, Total Loss 7.578485
# Epoch 27/150, Batch 201/1250, Total Loss 7.387309
# Epoch 27/150, Batch 251/1250, Total Loss 7.194643
# Epoch 27/150, Batch 301/1250, Total Loss 6.479937
# Epoch 27/150, Batch 351/1250, Total Loss 8.114822
# Epoch 27/150, Batch 401/1250, Total Loss 9.819802
# Epoch 27/150, Batch 451/1250, Total Loss 7.370965
# Epoch 27/150, Batch 501/1250, Total Loss 7.008898
# Epoch 27/150, Batch 551/1250, Total Loss 12.241875
# Epoch 27/150, Batch 601/1250, Total Loss 7.860977
# Epoch 27/150, Batch 651/1250, Total Loss 6.499752
# Epoch 27/150, Batch 701/1250, Total Loss 6.239051
# Epoch 27/150, Batch 751/1250, Total Loss 9.060179
# Epoch 27/150, Batch 801/1250, Total Loss 7.118882
# Epoch 27/150, Batch 851/1250, Total Loss 6.754900
# Epoch 27/150, Batch 901/1250, Total Loss 7.709955
# Epoch 27/150, Batch 951/1250, Total Loss 10.574878
# Epoch 27/150, Batch 1001/1250, Total Loss 5.718913
# Epoch 27/150, Batch 1051/1250, Total Loss 8.389505
# Epoch 27/150, Batch 1101/1250, Total Loss 8.150208
# Epoch 27/150, Batch 1151/1250, Total Loss 5.715053
# Epoch 27/150, Batch 1201/1250, Total Loss 7.754066
# ====================================================
#
#
# Epoch 27/150, Train Total Loss 7.046585, Eval Total Loss 8.945416
#
#
# ====================================================
# Epoch 28/150, Batch 1/1250, Total Loss 7.650619
# Epoch 28/150, Batch 51/1250, Total Loss 8.561942
# Epoch 28/150, Batch 101/1250, Total Loss 9.627490
# Epoch 28/150, Batch 151/1250, Total Loss 6.719950
# Epoch 28/150, Batch 201/1250, Total Loss 8.362559
# Epoch 28/150, Batch 251/1250, Total Loss 8.208233
# Epoch 28/150, Batch 301/1250, Total Loss 7.268087
# Epoch 28/150, Batch 351/1250, Total Loss 10.450590
# Epoch 28/150, Batch 401/1250, Total Loss 9.676867
# Epoch 28/150, Batch 451/1250, Total Loss 7.955443
# Epoch 28/150, Batch 501/1250, Total Loss 6.054652
# Epoch 28/150, Batch 551/1250, Total Loss 15.504475
# Epoch 28/150, Batch 601/1250, Total Loss 7.978399
# Epoch 28/150, Batch 651/1250, Total Loss 8.602124
# Epoch 28/150, Batch 701/1250, Total Loss 6.404130
# Epoch 28/150, Batch 751/1250, Total Loss 8.199313
# Epoch 28/150, Batch 801/1250, Total Loss 6.583880
# Epoch 28/150, Batch 851/1250, Total Loss 6.964895
# Epoch 28/150, Batch 901/1250, Total Loss 9.703688
# Epoch 28/150, Batch 951/1250, Total Loss 8.041710
# Epoch 28/150, Batch 1001/1250, Total Loss 6.579306
# Epoch 28/150, Batch 1051/1250, Total Loss 7.597114
# Epoch 28/150, Batch 1101/1250, Total Loss 11.175288
# Epoch 28/150, Batch 1151/1250, Total Loss 6.769617
# Epoch 28/150, Batch 1201/1250, Total Loss 9.417473
# ====================================================
#
#
# Epoch 28/150, Train Total Loss 6.407916, Eval Total Loss 7.594251
#
#
# ====================================================
# Epoch 29/150, Batch 1/1250, Total Loss 5.466606
# Epoch 29/150, Batch 51/1250, Total Loss 8.532057
# Epoch 29/150, Batch 101/1250, Total Loss 7.275403
# Epoch 29/150, Batch 151/1250, Total Loss 6.769085
# Epoch 29/150, Batch 201/1250, Total Loss 7.037030
# Epoch 29/150, Batch 251/1250, Total Loss 9.833703
# Epoch 29/150, Batch 301/1250, Total Loss 6.117929
# Epoch 29/150, Batch 351/1250, Total Loss 7.855325
# Epoch 29/150, Batch 401/1250, Total Loss 8.566122
# Epoch 29/150, Batch 451/1250, Total Loss 9.845372
# Epoch 29/150, Batch 501/1250, Total Loss 7.239892
# Epoch 29/150, Batch 551/1250, Total Loss 14.234514
# Epoch 29/150, Batch 601/1250, Total Loss 6.930568
# Epoch 29/150, Batch 651/1250, Total Loss 8.162512
# Epoch 29/150, Batch 701/1250, Total Loss 9.066412
# Epoch 29/150, Batch 751/1250, Total Loss 7.924266
# Epoch 29/150, Batch 801/1250, Total Loss 6.724490
# Epoch 29/150, Batch 851/1250, Total Loss 7.530182
# Epoch 29/150, Batch 901/1250, Total Loss 12.451626
# Epoch 29/150, Batch 951/1250, Total Loss 9.676056
# Epoch 29/150, Batch 1001/1250, Total Loss 8.528666
# Epoch 29/150, Batch 1051/1250, Total Loss 10.007580
# Epoch 29/150, Batch 1101/1250, Total Loss 7.500990
# Epoch 29/150, Batch 1151/1250, Total Loss 6.866974
# Epoch 29/150, Batch 1201/1250, Total Loss 8.652539
# ====================================================
#
#
# Epoch 29/150, Train Total Loss 7.255088, Eval Total Loss 9.236627
#
#
# ====================================================
# Epoch 30/150, Batch 1/1250, Total Loss 7.613383
# Epoch 30/150, Batch 51/1250, Total Loss 8.245499
# Epoch 30/150, Batch 101/1250, Total Loss 7.043787
# Epoch 30/150, Batch 151/1250, Total Loss 6.930881
# Epoch 30/150, Batch 201/1250, Total Loss 7.515429
# Epoch 30/150, Batch 251/1250, Total Loss 9.343834
# Epoch 30/150, Batch 301/1250, Total Loss 6.319495
# Epoch 30/150, Batch 351/1250, Total Loss 7.944781
# Epoch 30/150, Batch 401/1250, Total Loss 9.389032
# Epoch 30/150, Batch 451/1250, Total Loss 7.834730
# Epoch 30/150, Batch 501/1250, Total Loss 5.625132
# Epoch 30/150, Batch 551/1250, Total Loss 10.908613
# Epoch 30/150, Batch 601/1250, Total Loss 6.242277
# Epoch 30/150, Batch 651/1250, Total Loss 10.621605
# Epoch 30/150, Batch 701/1250, Total Loss 6.339746
# Epoch 30/150, Batch 751/1250, Total Loss 7.312634
# Epoch 30/150, Batch 801/1250, Total Loss 8.256460
# Epoch 30/150, Batch 851/1250, Total Loss 8.218344
# Epoch 30/150, Batch 901/1250, Total Loss 7.726224
# Epoch 30/150, Batch 951/1250, Total Loss 8.332437
# Epoch 30/150, Batch 1001/1250, Total Loss 7.244982
# Epoch 30/150, Batch 1051/1250, Total Loss 6.690374
# Epoch 30/150, Batch 1101/1250, Total Loss 13.823993
# Epoch 30/150, Batch 1151/1250, Total Loss 7.347510
# Epoch 30/150, Batch 1201/1250, Total Loss 6.788697
# ====================================================
#
#
# Epoch 30/150, Train Total Loss 8.526975, Eval Total Loss 8.932137
#
#
# ====================================================
# Epoch 31/150, Batch 1/1250, Total Loss 8.028723
# Epoch 31/150, Batch 51/1250, Total Loss 9.199156
# Epoch 31/150, Batch 101/1250, Total Loss 9.075205
# Epoch 31/150, Batch 151/1250, Total Loss 6.245404
# Epoch 31/150, Batch 201/1250, Total Loss 6.887698
# Epoch 31/150, Batch 251/1250, Total Loss 7.212736
# Epoch 31/150, Batch 301/1250, Total Loss 5.117657
# Epoch 31/150, Batch 351/1250, Total Loss 6.345311
# Epoch 31/150, Batch 401/1250, Total Loss 8.470127
# Epoch 31/150, Batch 451/1250, Total Loss 7.985007
# Epoch 31/150, Batch 501/1250, Total Loss 5.338193
# Epoch 31/150, Batch 551/1250, Total Loss 8.996511
# Epoch 31/150, Batch 601/1250, Total Loss 9.376769
# Epoch 31/150, Batch 651/1250, Total Loss 8.222107
# Epoch 31/150, Batch 701/1250, Total Loss 5.653605
# Epoch 31/150, Batch 751/1250, Total Loss 6.172149
# Epoch 31/150, Batch 801/1250, Total Loss 5.854602
# Epoch 31/150, Batch 851/1250, Total Loss 5.312776
# Epoch 31/150, Batch 901/1250, Total Loss 6.874382
# Epoch 31/150, Batch 951/1250, Total Loss 7.274993
# Epoch 31/150, Batch 1001/1250, Total Loss 5.085564
# Epoch 31/150, Batch 1051/1250, Total Loss 7.034331
# Epoch 31/150, Batch 1101/1250, Total Loss 7.208138
# Epoch 31/150, Batch 1151/1250, Total Loss 5.713391
# Epoch 31/150, Batch 1201/1250, Total Loss 7.015411
# ====================================================
#
#
# Epoch 31/150, Train Total Loss 6.518776, Eval Total Loss 7.694052
#
#
# ====================================================
# Epoch 32/150, Batch 1/1250, Total Loss 5.876595
# Epoch 32/150, Batch 51/1250, Total Loss 8.261047
# Epoch 32/150, Batch 101/1250, Total Loss 5.406931
# Epoch 32/150, Batch 151/1250, Total Loss 5.470948
# Epoch 32/150, Batch 201/1250, Total Loss 5.163874
# Epoch 32/150, Batch 251/1250, Total Loss 5.879283
# Epoch 32/150, Batch 301/1250, Total Loss 5.110228
# Epoch 32/150, Batch 351/1250, Total Loss 7.376876
# Epoch 32/150, Batch 401/1250, Total Loss 6.972703
# Epoch 32/150, Batch 451/1250, Total Loss 6.537939
# Epoch 32/150, Batch 501/1250, Total Loss 5.274830
# Epoch 32/150, Batch 551/1250, Total Loss 9.203450
# Epoch 32/150, Batch 601/1250, Total Loss 8.231407
# Epoch 32/150, Batch 651/1250, Total Loss 7.371392
# Epoch 32/150, Batch 701/1250, Total Loss 6.171072
# Epoch 32/150, Batch 751/1250, Total Loss 7.592169
# Epoch 32/150, Batch 801/1250, Total Loss 5.477748
# Epoch 32/150, Batch 851/1250, Total Loss 6.542256
# Epoch 32/150, Batch 901/1250, Total Loss 7.889733
# Epoch 32/150, Batch 951/1250, Total Loss 7.275954
# Epoch 32/150, Batch 1001/1250, Total Loss 5.355698
# Epoch 32/150, Batch 1051/1250, Total Loss 7.738643
# Epoch 32/150, Batch 1101/1250, Total Loss 6.301072
# Epoch 32/150, Batch 1151/1250, Total Loss 6.016289
# Epoch 32/150, Batch 1201/1250, Total Loss 5.675374
# ====================================================
#
#
# Epoch 32/150, Train Total Loss 7.560405, Eval Total Loss 7.232810
#
#
# ====================================================
# Epoch 33/150, Batch 1/1250, Total Loss 5.421209
# Epoch 33/150, Batch 51/1250, Total Loss 6.668541
# Epoch 33/150, Batch 101/1250, Total Loss 5.840040
# Epoch 33/150, Batch 151/1250, Total Loss 4.859449
# Epoch 33/150, Batch 201/1250, Total Loss 5.560887
# Epoch 33/150, Batch 251/1250, Total Loss 7.112652
# Epoch 33/150, Batch 301/1250, Total Loss 4.546093
# Epoch 33/150, Batch 351/1250, Total Loss 8.765917
# Epoch 33/150, Batch 401/1250, Total Loss 9.489977
# Epoch 33/150, Batch 451/1250, Total Loss 7.371055
# Epoch 33/150, Batch 501/1250, Total Loss 7.153813
# Epoch 33/150, Batch 551/1250, Total Loss 16.015873
# Epoch 33/150, Batch 601/1250, Total Loss 9.811897
# Epoch 33/150, Batch 651/1250, Total Loss 7.914753
# Epoch 33/150, Batch 701/1250, Total Loss 5.800614
# Epoch 33/150, Batch 751/1250, Total Loss 5.718956
# Epoch 33/150, Batch 801/1250, Total Loss 7.766638
# Epoch 33/150, Batch 851/1250, Total Loss 6.752556
# Epoch 33/150, Batch 901/1250, Total Loss 8.859986
# Epoch 33/150, Batch 951/1250, Total Loss 6.963337
# Epoch 33/150, Batch 1001/1250, Total Loss 5.109964
# Epoch 33/150, Batch 1051/1250, Total Loss 5.662414
# Epoch 33/150, Batch 1101/1250, Total Loss 5.562930
# Epoch 33/150, Batch 1151/1250, Total Loss 3.869633
# Epoch 33/150, Batch 1201/1250, Total Loss 4.446872
# ====================================================
#
#
# Epoch 33/150, Train Total Loss 6.299370, Eval Total Loss 8.608859
#
#
# ====================================================
# Epoch 34/150, Batch 1/1250, Total Loss 5.667678
# Epoch 34/150, Batch 51/1250, Total Loss 7.823358
# Epoch 34/150, Batch 101/1250, Total Loss 6.748660
# Epoch 34/150, Batch 151/1250, Total Loss 8.183577
# Epoch 34/150, Batch 201/1250, Total Loss 5.829406
# Epoch 34/150, Batch 251/1250, Total Loss 6.297412
# Epoch 34/150, Batch 301/1250, Total Loss 4.723537
# Epoch 34/150, Batch 351/1250, Total Loss 7.179186
# Epoch 34/150, Batch 401/1250, Total Loss 7.704110
# Epoch 34/150, Batch 451/1250, Total Loss 6.317342
# Epoch 34/150, Batch 501/1250, Total Loss 7.259669
# ...
# Epoch 69/150, Batch 401/1250, Total Loss 4.083534
# Epoch 69/150, Batch 451/1250, Total Loss 3.750118
# Epoch 69/150, Batch 501/1250, Total Loss 3.971764
# Epoch 69/150, Batch 551/1250, Total Loss 5.609367
# Epoch 69/150, Batch 601/1250, Total Loss 11.919024
# Epoch 69/150, Batch 651/1250, Total Loss 4.870597
# Epoch 69/150, Batch 701/1250, Total Loss 4.852853
# Epoch 69/150, Batch 751/1250, Total Loss 3.971006
# Epoch 69/150, Batch 801/1250, Total Loss 3.437829
# Epoch 69/150, Batch 851/1250, Total Loss 5.197857
# Epoch 69/150, Batch 901/1250, Total Loss 5.904644
# Epoch 69/150, Batch 951/1250, Total Loss 5.429072
# Epoch 69/150, Batch 1001/1250, Total Loss 3.455879
# Epoch 69/150, Batch 1051/1250, Total Loss 3.732554
# Epoch 69/150, Batch 1101/1250, Total Loss 3.328983
# Epoch 69/150, Batch 1151/1250, Total Loss 3.679604
# Epoch 69/150, Batch 1201/1250, Total Loss 5.579304
# ====================================================
#
#
# Epoch 69/150, Train Total Loss 3.646810, Eval Total Loss 5.524205
#
#
# ====================================================
# Epoch 70/150, Batch 1/1250, Total Loss 3.719994
# Epoch 70/150, Batch 51/1250, Total Loss 4.268773
# Epoch 70/150, Batch 101/1250, Total Loss 3.900487
# Epoch 70/150, Batch 151/1250, Total Loss 2.829715
# Epoch 70/150, Batch 201/1250, Total Loss 3.463471
# Epoch 70/150, Batch 251/1250, Total Loss 3.752616
# Epoch 70/150, Batch 301/1250, Total Loss 2.828559
# Epoch 70/150, Batch 351/1250, Total Loss 3.858010
# Epoch 70/150, Batch 401/1250, Total Loss 5.788060
# Epoch 70/150, Batch 451/1250, Total Loss 6.280436
# Epoch 70/150, Batch 501/1250, Total Loss 3.047198
# Epoch 70/150, Batch 551/1250, Total Loss 6.595269
# Epoch 70/150, Batch 601/1250, Total Loss 4.609085
# Epoch 70/150, Batch 651/1250, Total Loss 4.228621
# Epoch 70/150, Batch 701/1250, Total Loss 5.189772
# Epoch 70/150, Batch 751/1250, Total Loss 4.083488
# Epoch 70/150, Batch 801/1250, Total Loss 3.827361
# Epoch 70/150, Batch 851/1250, Total Loss 5.251185
# Epoch 70/150, Batch 901/1250, Total Loss 4.232977
# Epoch 70/150, Batch 951/1250, Total Loss 5.276621
# Epoch 70/150, Batch 1001/1250, Total Loss 4.666096
# Epoch 70/150, Batch 1051/1250, Total Loss 6.447229
# Epoch 70/150, Batch 1101/1250, Total Loss 3.775329
# Epoch 70/150, Batch 1151/1250, Total Loss 3.602141
# Epoch 70/150, Batch 1201/1250, Total Loss 3.222979
# ====================================================
#
#
# Epoch 70/150, Train Total Loss 3.332694, Eval Total Loss 4.607075
#
#
# ====================================================
# Epoch 71/150, Batch 1/1250, Total Loss 2.740937
# Epoch 71/150, Batch 51/1250, Total Loss 3.854536
# Epoch 71/150, Batch 101/1250, Total Loss 3.606293
# Epoch 71/150, Batch 151/1250, Total Loss 3.227532
# Epoch 71/150, Batch 201/1250, Total Loss 3.590758
# Epoch 71/150, Batch 251/1250, Total Loss 3.734677
# Epoch 71/150, Batch 301/1250, Total Loss 2.942884
# Epoch 71/150, Batch 351/1250, Total Loss 3.730742
# Epoch 71/150, Batch 401/1250, Total Loss 4.677552
# Epoch 71/150, Batch 451/1250, Total Loss 4.240917
# Epoch 71/150, Batch 501/1250, Total Loss 3.386733
# Epoch 71/150, Batch 551/1250, Total Loss 6.223814
# Epoch 71/150, Batch 601/1250, Total Loss 3.185390
# Epoch 71/150, Batch 651/1250, Total Loss 3.979258
# Epoch 71/150, Batch 701/1250, Total Loss 3.167868
# Epoch 71/150, Batch 751/1250, Total Loss 3.309335
# Epoch 71/150, Batch 801/1250, Total Loss 2.988705
# Epoch 71/150, Batch 851/1250, Total Loss 3.885608
# Epoch 71/150, Batch 901/1250, Total Loss 4.381527
# Epoch 71/150, Batch 951/1250, Total Loss 5.067017
# Epoch 71/150, Batch 1001/1250, Total Loss 3.215595
# Epoch 71/150, Batch 1051/1250, Total Loss 6.251663
# Epoch 71/150, Batch 1101/1250, Total Loss 3.321908
# Epoch 71/150, Batch 1151/1250, Total Loss 2.783887
# Epoch 71/150, Batch 1201/1250, Total Loss 2.646918
# ====================================================
#
#
# Epoch 71/150, Train Total Loss 3.562526, Eval Total Loss 5.056109
#
#
# ====================================================
# Epoch 72/150, Batch 1/1250, Total Loss 2.812838
# Epoch 72/150, Batch 51/1250, Total Loss 3.525017
# Epoch 72/150, Batch 101/1250, Total Loss 3.155556
# Epoch 72/150, Batch 151/1250, Total Loss 2.823579
# Epoch 72/150, Batch 201/1250, Total Loss 3.058402
# Epoch 72/150, Batch 251/1250, Total Loss 3.920383
# Epoch 72/150, Batch 301/1250, Total Loss 2.972397
# Epoch 72/150, Batch 351/1250, Total Loss 3.559107
# Epoch 72/150, Batch 401/1250, Total Loss 4.278601
# Epoch 72/150, Batch 451/1250, Total Loss 3.436094
# Epoch 72/150, Batch 501/1250, Total Loss 3.174099
# Epoch 72/150, Batch 551/1250, Total Loss 4.954609
# Epoch 72/150, Batch 601/1250, Total Loss 3.129738
# Epoch 72/150, Batch 651/1250, Total Loss 3.512080
# Epoch 72/150, Batch 701/1250, Total Loss 2.235365
# Epoch 72/150, Batch 751/1250, Total Loss 3.264779
# Epoch 72/150, Batch 801/1250, Total Loss 2.725775
# Epoch 72/150, Batch 851/1250, Total Loss 3.150554
# Epoch 72/150, Batch 901/1250, Total Loss 4.483534
# Epoch 72/150, Batch 951/1250, Total Loss 4.441768
# Epoch 72/150, Batch 1001/1250, Total Loss 2.883155
# Epoch 72/150, Batch 1051/1250, Total Loss 5.097583
# Epoch 72/150, Batch 1101/1250, Total Loss 3.235583
# Epoch 72/150, Batch 1151/1250, Total Loss 2.494590
# Epoch 72/150, Batch 1201/1250, Total Loss 3.344245
# ====================================================
#
#
# Epoch 72/150, Train Total Loss 3.053871, Eval Total Loss 5.091496
#
#
# ====================================================
# Epoch 73/150, Batch 1/1250, Total Loss 3.114904
# Epoch 73/150, Batch 51/1250, Total Loss 3.943279
# Epoch 73/150, Batch 101/1250, Total Loss 3.776774
# Epoch 73/150, Batch 151/1250, Total Loss 3.126353
# Epoch 73/150, Batch 201/1250, Total Loss 2.819652
# Epoch 73/150, Batch 251/1250, Total Loss 4.059082
# Epoch 73/150, Batch 301/1250, Total Loss 2.998010
# Epoch 73/150, Batch 351/1250, Total Loss 3.448720
# Epoch 73/150, Batch 401/1250, Total Loss 3.347304
# Epoch 73/150, Batch 451/1250, Total Loss 3.362915
# Epoch 73/150, Batch 501/1250, Total Loss 3.776185
# Epoch 73/150, Batch 551/1250, Total Loss 5.785632
# Epoch 73/150, Batch 601/1250, Total Loss 2.888241
# Epoch 73/150, Batch 651/1250, Total Loss 3.684420
# Epoch 73/150, Batch 701/1250, Total Loss 2.950807
# Epoch 73/150, Batch 751/1250, Total Loss 3.167516
# Epoch 73/150, Batch 801/1250, Total Loss 2.985847
# Epoch 73/150, Batch 851/1250, Total Loss 3.152487
# Epoch 73/150, Batch 901/1250, Total Loss 3.521365
# Epoch 73/150, Batch 951/1250, Total Loss 3.886369
# Epoch 73/150, Batch 1001/1250, Total Loss 2.370511
# Epoch 73/150, Batch 1051/1250, Total Loss 4.414120
# Epoch 73/150, Batch 1101/1250, Total Loss 3.163854
# Epoch 73/150, Batch 1151/1250, Total Loss 2.577092
# Epoch 73/150, Batch 1201/1250, Total Loss 2.925086
# ====================================================
#
#
# Epoch 73/150, Train Total Loss 3.324005, Eval Total Loss 5.135085
#
#
# ====================================================
# Epoch 74/150, Batch 1/1250, Total Loss 3.452636
# Epoch 74/150, Batch 51/1250, Total Loss 4.753896
# Epoch 74/150, Batch 101/1250, Total Loss 4.713561
# Epoch 74/150, Batch 151/1250, Total Loss 3.582522
# Epoch 74/150, Batch 201/1250, Total Loss 3.506708
# Epoch 74/150, Batch 251/1250, Total Loss 4.237417
# Epoch 74/150, Batch 301/1250, Total Loss 3.202930
# Epoch 74/150, Batch 351/1250, Total Loss 3.328674
# Epoch 74/150, Batch 401/1250, Total Loss 4.752267
# Epoch 74/150, Batch 451/1250, Total Loss 4.084291
# Epoch 74/150, Batch 501/1250, Total Loss 4.792990
# Epoch 74/150, Batch 551/1250, Total Loss 4.621859
# Epoch 74/150, Batch 601/1250, Total Loss 3.598089
# Epoch 74/150, Batch 651/1250, Total Loss 4.638950
# Epoch 74/150, Batch 701/1250, Total Loss 4.935606
# Epoch 74/150, Batch 751/1250, Total Loss 4.505838
# Epoch 74/150, Batch 801/1250, Total Loss 5.074614
# Epoch 74/150, Batch 851/1250, Total Loss 5.630005
# Epoch 74/150, Batch 901/1250, Total Loss 5.244886
# Epoch 74/150, Batch 951/1250, Total Loss 4.789645
# Epoch 74/150, Batch 1001/1250, Total Loss 4.259507
# Epoch 74/150, Batch 1051/1250, Total Loss 4.311964
# Epoch 74/150, Batch 1101/1250, Total Loss 4.350742
# Epoch 74/150, Batch 1151/1250, Total Loss 2.984549
# Epoch 74/150, Batch 1201/1250, Total Loss 5.723615
# ====================================================
#
#
# Epoch 74/150, Train Total Loss 3.369561, Eval Total Loss 5.378024
#
#
# ====================================================
# Epoch 75/150, Batch 1/1250, Total Loss 3.696474
# Epoch 75/150, Batch 51/1250, Total Loss 4.133240
# Epoch 75/150, Batch 101/1250, Total Loss 5.687754
# Epoch 75/150, Batch 151/1250, Total Loss 3.131363
# Epoch 75/150, Batch 201/1250, Total Loss 2.725049
# Epoch 75/150, Batch 251/1250, Total Loss 6.522306
# Epoch 75/150, Batch 301/1250, Total Loss 3.367312
# Epoch 75/150, Batch 351/1250, Total Loss 4.904907
# Epoch 75/150, Batch 401/1250, Total Loss 5.086961
# Epoch 75/150, Batch 451/1250, Total Loss 5.055837
# Epoch 75/150, Batch 501/1250, Total Loss 3.812575
# Epoch 75/150, Batch 551/1250, Total Loss 5.720223
# Epoch 75/150, Batch 601/1250, Total Loss 4.890341
# Epoch 75/150, Batch 651/1250, Total Loss 3.266735
# Epoch 75/150, Batch 701/1250, Total Loss 4.659604
# Epoch 75/150, Batch 751/1250, Total Loss 4.260000
# Epoch 75/150, Batch 801/1250, Total Loss 3.602897
# Epoch 75/150, Batch 851/1250, Total Loss 5.842038
# Epoch 75/150, Batch 901/1250, Total Loss 5.950854
# Epoch 75/150, Batch 951/1250, Total Loss 4.991915
# Epoch 75/150, Batch 1001/1250, Total Loss 3.525806
# Epoch 75/150, Batch 1051/1250, Total Loss 3.961120
# Epoch 75/150, Batch 1101/1250, Total Loss 2.990951
# Epoch 75/150, Batch 1151/1250, Total Loss 2.970659
# Epoch 75/150, Batch 1201/1250, Total Loss 4.006555
# ====================================================
#
#
# Epoch 75/150, Train Total Loss 4.982035, Eval Total Loss 8.226507
#
#
# ====================================================
# Epoch 76/150, Batch 1/1250, Total Loss 4.796749
# Epoch 76/150, Batch 51/1250, Total Loss 4.260745
# Epoch 76/150, Batch 101/1250, Total Loss 3.794948
# Epoch 76/150, Batch 151/1250, Total Loss 3.916067
# Epoch 76/150, Batch 201/1250, Total Loss 2.885340
# Epoch 76/150, Batch 251/1250, Total Loss 7.574884
# Epoch 76/150, Batch 301/1250, Total Loss 4.317028
# Epoch 76/150, Batch 351/1250, Total Loss 3.289481
# Epoch 76/150, Batch 401/1250, Total Loss 4.751269
# Epoch 76/150, Batch 451/1250, Total Loss 3.444817
# Epoch 76/150, Batch 501/1250, Total Loss 4.863961
# Epoch 76/150, Batch 551/1250, Total Loss 4.957756
# Epoch 76/150, Batch 601/1250, Total Loss 3.258327
# Epoch 76/150, Batch 651/1250, Total Loss 6.091004
# Epoch 76/150, Batch 701/1250, Total Loss 5.086735
# Epoch 76/150, Batch 751/1250, Total Loss 4.649376
# Epoch 76/150, Batch 801/1250, Total Loss 2.903304
# Epoch 76/150, Batch 851/1250, Total Loss 4.727486
# Epoch 76/150, Batch 901/1250, Total Loss 4.151552
# Epoch 76/150, Batch 951/1250, Total Loss 4.652156
# Epoch 76/150, Batch 1001/1250, Total Loss 2.896132
# Epoch 76/150, Batch 1051/1250, Total Loss 3.059535
# Epoch 76/150, Batch 1101/1250, Total Loss 2.528620
# Epoch 76/150, Batch 1151/1250, Total Loss 2.463645
# Epoch 76/150, Batch 1201/1250, Total Loss 3.669072
# ====================================================
#
#
# Epoch 76/150, Train Total Loss 3.193251, Eval Total Loss 6.570613
#
#
# ====================================================
# Epoch 77/150, Batch 1/1250, Total Loss 3.574522
# Epoch 77/150, Batch 51/1250, Total Loss 4.159553
# Epoch 77/150, Batch 101/1250, Total Loss 3.291094
# Epoch 77/150, Batch 151/1250, Total Loss 4.098051
# Epoch 77/150, Batch 201/1250, Total Loss 3.003119
# Epoch 77/150, Batch 251/1250, Total Loss 6.731832
# Epoch 77/150, Batch 301/1250, Total Loss 2.735752
# Epoch 77/150, Batch 351/1250, Total Loss 3.043546
# Epoch 77/150, Batch 401/1250, Total Loss 3.801494
# Epoch 77/150, Batch 451/1250, Total Loss 3.025800
# Epoch 77/150, Batch 501/1250, Total Loss 4.243785
# Epoch 77/150, Batch 551/1250, Total Loss 5.549510
# Epoch 77/150, Batch 601/1250, Total Loss 3.002356
# Epoch 77/150, Batch 651/1250, Total Loss 3.244814
# Epoch 77/150, Batch 701/1250, Total Loss 3.760372
# Epoch 77/150, Batch 751/1250, Total Loss 3.614293
# Epoch 77/150, Batch 801/1250, Total Loss 2.731515
# Epoch 77/150, Batch 851/1250, Total Loss 3.389823
# Epoch 77/150, Batch 901/1250, Total Loss 3.242830
# Epoch 77/150, Batch 951/1250, Total Loss 3.851088
# Epoch 77/150, Batch 1001/1250, Total Loss 2.103488
# Epoch 77/150, Batch 1051/1250, Total Loss 2.810401
# Epoch 77/150, Batch 1101/1250, Total Loss 2.570679
# Epoch 77/150, Batch 1151/1250, Total Loss 1.971568
# Epoch 77/150, Batch 1201/1250, Total Loss 2.401573
# ====================================================
#
#
# Epoch 77/150, Train Total Loss 3.142451, Eval Total Loss 5.780344
#
#
# ====================================================
# Epoch 78/150, Batch 1/1250, Total Loss 3.100636
# Epoch 78/150, Batch 51/1250, Total Loss 3.271644
# Epoch 78/150, Batch 101/1250, Total Loss 2.778282
# Epoch 78/150, Batch 151/1250, Total Loss 2.844195
# Epoch 78/150, Batch 201/1250, Total Loss 2.629299
# Epoch 78/150, Batch 251/1250, Total Loss 5.177802
# Epoch 78/150, Batch 301/1250, Total Loss 2.474808
# Epoch 78/150, Batch 351/1250, Total Loss 2.754737
# Epoch 78/150, Batch 401/1250, Total Loss 3.352182
# Epoch 78/150, Batch 451/1250, Total Loss 3.188020
# Epoch 78/150, Batch 501/1250, Total Loss 2.527683
# Epoch 78/150, Batch 551/1250, Total Loss 5.178534
# Epoch 78/150, Batch 601/1250, Total Loss 2.950487
# Epoch 78/150, Batch 651/1250, Total Loss 2.816030
# Epoch 78/150, Batch 701/1250, Total Loss 2.222781
# Epoch 78/150, Batch 751/1250, Total Loss 3.402612
# Epoch 78/150, Batch 801/1250, Total Loss 2.898961
# Epoch 78/150, Batch 851/1250, Total Loss 3.048000
# Epoch 78/150, Batch 901/1250, Total Loss 3.162678
# Epoch 78/150, Batch 951/1250, Total Loss 3.218084
# Epoch 78/150, Batch 1001/1250, Total Loss 1.914091
# Epoch 78/150, Batch 1051/1250, Total Loss 3.040318
# Epoch 78/150, Batch 1101/1250, Total Loss 2.570092
# Epoch 78/150, Batch 1151/1250, Total Loss 2.411187
# Epoch 78/150, Batch 1201/1250, Total Loss 2.730747
# ====================================================
#
#
# Epoch 78/150, Train Total Loss 3.231791, Eval Total Loss 5.220324
#
#
# ====================================================
# Epoch 79/150, Batch 1/1250, Total Loss 3.031908
# Epoch 79/150, Batch 51/1250, Total Loss 3.610737
# Epoch 79/150, Batch 101/1250, Total Loss 2.785901
# Epoch 79/150, Batch 151/1250, Total Loss 2.927763
# Epoch 79/150, Batch 201/1250, Total Loss 3.399896
# Epoch 79/150, Batch 251/1250, Total Loss 3.759798
# Epoch 79/150, Batch 301/1250, Total Loss 2.323461
# Epoch 79/150, Batch 351/1250, Total Loss 3.101167
# Epoch 79/150, Batch 401/1250, Total Loss 3.753968
# Epoch 79/150, Batch 451/1250, Total Loss 4.601541
# Epoch 79/150, Batch 501/1250, Total Loss 2.710095
# Epoch 79/150, Batch 551/1250, Total Loss 5.253255
# Epoch 79/150, Batch 601/1250, Total Loss 2.926526
# Epoch 79/150, Batch 651/1250, Total Loss 3.123054
# Epoch 79/150, Batch 701/1250, Total Loss 2.210441
# Epoch 79/150, Batch 751/1250, Total Loss 3.088044
# Epoch 79/150, Batch 801/1250, Total Loss 3.081011
# Epoch 79/150, Batch 851/1250, Total Loss 3.722598
# Epoch 79/150, Batch 901/1250, Total Loss 3.487801
# Epoch 79/150, Batch 951/1250, Total Loss 3.505543
# Epoch 79/150, Batch 1001/1250, Total Loss 2.370758
# Epoch 79/150, Batch 1051/1250, Total Loss 2.754539
# Epoch 79/150, Batch 1101/1250, Total Loss 2.733020
# Epoch 79/150, Batch 1151/1250, Total Loss 2.382297
# Epoch 79/150, Batch 1201/1250, Total Loss 2.805014
# ====================================================
#
#
# Epoch 79/150, Train Total Loss 2.771872, Eval Total Loss 4.846676
#
#
# ====================================================
# Epoch 80/150, Batch 1/1250, Total Loss 2.487662
# Epoch 80/150, Batch 51/1250, Total Loss 3.534549
# Epoch 80/150, Batch 101/1250, Total Loss 2.793588
# Epoch 80/150, Batch 151/1250, Total Loss 2.839176
# Epoch 80/150, Batch 201/1250, Total Loss 2.951133
# Epoch 80/150, Batch 251/1250, Total Loss 3.312703
# Epoch 80/150, Batch 301/1250, Total Loss 2.501147
# Epoch 80/150, Batch 351/1250, Total Loss 3.086938
# Epoch 80/150, Batch 401/1250, Total Loss 3.482020
# Epoch 80/150, Batch 451/1250, Total Loss 4.399252
# Epoch 80/150, Batch 501/1250, Total Loss 2.918597
# Epoch 80/150, Batch 551/1250, Total Loss 5.962400
# Epoch 80/150, Batch 601/1250, Total Loss 3.204878

# %%
# Data for plotting
fig, ax = plt.subplots()
ax.plot(range(epoch), train_loss_record,  'k--', label='train')
ax.plot(range(epoch), test_loss_record,  'k:', label='test')


legend = ax.legend(loc='upper right', fontsize='large')

ax.set(xlabel='epoch', ylabel='Mean Absolute Error',
        title='Loss with %d training samples' % (train_x.shape[0]))
ax.grid()

fig.savefig("figs/loss_%dtrain.png"%(train_x.shape[0]))
plt.show()

# %% [markdown]
# # Test starts here
#
#
# #### If you have pre-trained model saved,
# #### no need to run training section.
# #### Just load the data and start from here

# %%
epoch = 150
learning_rate = 5e-4
train_nr = train_x.shape[0]
test_nr = test_x.shape[0]

input_shape = (128,128,2)
output_shape = (128,128,1)

# unet_up, hidden_shapes = unet.create_unet_up(input_shape)
# unet_down = unet.create_unet_down(hidden_shapes)
a_unet = unet_gege.create_vae(input_shape)

# unet_up.load_weights(output_dir + 'unet_up_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
# unet_down.load_weights(output_dir + 'unet_down_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
a_unet.load_weights(output_dir + 'unet_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))

# %% [markdown]
# #### Transfer forward pass (the only test task we care about)

# %%
xc = Input(shape=input_shape) # perm + well location
c = Input(shape=(128,128,1)) # well location

# hidden_layers = unet_up(xc)
# x_hat = unet_down(hidden_layers)
x_hat = a_unet(xc)

unet_model = Model([xc, c], [x_hat])

# %%
# predict test set
sat_pred_eval = unet_model.predict([test_x, test_x[:,:,:,[1]]])
sat_pred_eval.shape
# Out:
# (100, 128, 128, 1)

# %%
# predict training set
sat_pred_train = unet_model.predict([train_x[:10,...], train_x[:10,:,:,[1]]])
sat_pred_train.shape
# Out:
# (10, 128, 128, 1)

# %%
num_test = 7
k_fig = plt.figure()
plt.imshow(test_x[num_test,:,:,0]*1000)
plt.colorbar(fraction=0.046)

# %%
# num_test = 7

# for i in range(16):
#     fig = plt.figure(figsize=(15,3))
#     plt.set_cmap('gray')
    
#     plt.subplot(1,3,1)
#     plt.imshow(vae_weights[0][:,:,0,i])
#     plt.colorbar(fraction=0.046)
# #     plt.clim([-0.1, 0.1])

#     plt.subplot(1,3,2)
#     plt.imshow(vae_weights[0][:,:,1,i])
#     plt.colorbar(fraction=0.046)
# #     plt.clim([-0.1, 0.1])

#     plt.subplot(1,3,3)
# #     plt.set_cmap('jet')
#     plt.imshow(sat_pred_eval[0][num_test,:,:,i])
#     plt.colorbar(fraction=0.046)
# #     fig.savefig('layer1'+'channel'+str(i)+'.png')

# %%
# plt.set_cmap('jet')
# # k_fig = plt.figure()
# # plt.imshow(test_x[0,:,:,0])
# # plt.colorbar(fraction=0.046)
# # k_fig.savefig('k.png')
# layer = 11
# for i in range(32):
#     fig = plt.figure()
#     plt.imshow(sat_pred_eval[layer-1][0,:,:,i])
#     plt.colorbar(fraction=0.046)
#     fig.savefig('figs/layer'+str(layer)+'channel'+str(i)+'.png')

# %%
# epoch_plot = np.asarray(epoch_plot_list)+1
# rec_loss = np.asarray(rec_loss_list)/16384/16
# eval_loss = np.asarray(eval_loss_list)/16384/16
# rec_loss = np.sqrt(rec_loss)
# eval_loss = np.sqrt(eval_loss)
# print(epoch_plot)
# print(rec_loss)
# print(eval_loss)

# %%
# # Data for plotting
# fig, ax = plt.subplots()
# ax.plot(epoch_plot, rec_loss,  'k--', label='train')
# ax.plot(epoch_plot, eval_loss,  'k:', label='test')


# legend = ax.legend(loc='upper right', fontsize='large')

# ax.set(xlabel='epoch', ylabel='Mean Absolute Error',
#         title='20,000 Training Samples')
# ax.grid()

# fig.savefig("test.png")
# plt.show()

# %%
train_inj_plot = train_x * 200
train_inj_plot[:, :, 1 ,1] = train_inj_plot[:, :, 0, 1]
train_inj_plot[:, :, 2 ,1] = train_inj_plot[:, :, 0, 1]
test_inj_plot = test_x * 200
test_inj_plot[:, :, 1 ,1] = test_inj_plot[:, :, 0, 1]
test_inj_plot[:, :, 2 ,1] = test_inj_plot[:, :, 0, 1]

# %% [markdown]
# ## Training set simulation results

# %%
for k in range(0,5):
    plt.figure(k,figsize=(15,3))
    
    plt.subplot(1,5,1)
    plt.title('k (mD)')
    plt.imshow(train_x[k, :, :, 0] * 1000)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,2)
    plt.title('Injection (day)')
    plt.imshow(train_inj_plot[k, :, :, 1])
    plt.clim(0, 200)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,3)
    inj = test_x[k, 1, 1, 0]*50
    plt.title('SG (true)')
    plt.imshow(train_y[k, :, :, 0].reshape(128, 128))
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,4)
    plt.imshow(sat_pred_train[k, :, :, 0].reshape(128, 128))
    plt.title('SG (pred)')
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,5)
    rel_err = np.abs((sat_pred_train[k, :, :, 0] - train_y[k, :, :, 0]))
    plt.imshow(rel_err) 
    plt.title('Abs. error')
    plt.colorbar(fraction=0.046)
    plt.tight_layout()
    plt.show()

# %% [markdown]
# ## Test simulation results

# %%
for k in range(0,5):
    plt.figure(k,figsize=(15,3))
    
    plt.subplot(1,5,1)
    plt.title('k (mD)')
    plt.imshow(test_x[k, :, :, 0] * 1000)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,2)
    plt.title('Injection (day)')
    plt.imshow(test_inj_plot[k, :, :, 1])
    plt.clim(0, 200)
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,3)
    inj = test_x[k, 1, 1, 0]*50
    plt.title('SG (true)')
    plt.imshow(test_y[k, :, :, 0].reshape(128, 128))
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,4)
    plt.imshow(sat_pred_eval[k, :, :, 0].reshape(128, 128))
    plt.title('SG (pred)')
    plt.clim([0, 0.6])
    plt.colorbar(fraction=0.046)
    
    plt.subplot(1,5,5)
    abs_err = np.abs((sat_pred_eval[k, :, :, 0] - test_y[k, :, :, 0]))
    plt.imshow(abs_err) 
    plt.title('Abs. error')
    plt.colorbar(fraction=0.046)
    plt.clim([0, 0.2])
    plt.tight_layout()
    plt.show()
