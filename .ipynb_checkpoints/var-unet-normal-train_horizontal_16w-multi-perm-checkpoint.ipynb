# %%
import numpy as np

# import vunet
# import vunet_simple as vunet
import vunet_1 as vunet

import os
os.environ["CUDA_VISIBLE_DEVICES"]="3"
from keras import backend as K
from keras.layers import Input
from keras.models import Model
from keras.optimizers import Adam
from keras import losses

import h5py
import datetime
# Out:
# Using TensorFlow backend.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.set_cmap('jet')

# %%
import tensorflow as tf
from keras import backend as K

# tf.session specification
# TensorFlow wizardry
config = tf.ConfigProto()

# Don't pre-allocate memory; allocate as-needed
config.gpu_options.allow_growth = True

# Only allow a total of half the GPU memory to be allocated
config.gpu_options.per_process_gpu_memory_fraction = 0.85

# Create a session with the above options specified.
K.tensorflow_backend.set_session(tf.Session(config=config))

# %% [markdown]
# #### Load/select data

# %%
model_string = 'vunet'
output_dir = 'saved_models/'
# case_string = 'horizontal_16w'
case_string = 'horizontal_16w_fix_perm'
data_dir = '/data/cees/zjin/cs231n/project/var-unet/data/'

# %%
hf_r = h5py.File(data_dir + case_string + '.hdf5', 'r')
# hf_r = h5py.File(data_dir + case_string + '_aug.hdf5', 'r') # augmented data
data_train = np.array(hf_r.get('data_train'))
data_eval = np.array(hf_r.get('data_eval'))
hf_r.close()

print(data_train.shape)
print(data_eval.shape)
# Out:
# (7600, 128, 128, 3, 2)
# (784, 128, 128, 3, 2)

# %%
n_trial_data = 7600
data_train_trial = data_train[:n_trial_data,...]
print(data_train_trial.shape)


n_eval_data = 200
data_eval_trial = data_eval[:n_eval_data,...]
print(data_eval_trial.shape)
# Out:
# (7600, 128, 128, 3, 2)
# (200, 128, 128, 3, 2)

# %% [markdown]
# #### Visualize input data

# %%
sat_threshold = 0.1
for k in range (0,4):
    plt.figure(figsize=(16, 6))
    #
    plt.subplot(2,4,1)
    plt.imshow(data_train_trial[k,...,0, 0])
    plt.title('w')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,4,2)
    plt.imshow(data_train_trial[k,...,1, 0])
    plt.title('S')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,4,3)
    plt.imshow(data_train_trial[k,...,2, 0])
    plt.title('p')
    plt.colorbar(fraction=0.046)
    #
    sat_bin = np.greater_equal(data_train_trial[k,...,1, 0], sat_threshold).astype(float)
    plt.subplot(2,4,4)
    plt.imshow(sat_bin)
    plt.title('$S_{bin}$')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,4,5)
    plt.imshow(data_train_trial[k,...,0, 1])
    plt.title('$w^{\prime}$')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,4,6)
    plt.imshow(data_train_trial[k,...,1, 1])
    plt.title('$S^{\prime}$')
    plt.colorbar(fraction=0.046)
    #
    plt.subplot(2,4,7)
    plt.imshow(data_train_trial[k,...,2, 1])
    plt.title('$p^{\prime}$')
    plt.colorbar(fraction=0.046)
    #
    sat_bin_prime = np.greater_equal(data_train_trial[k,...,1, 1], sat_threshold).astype(float)
    plt.subplot(2,4,8)
    plt.imshow(sat_bin_prime)
    plt.title('$S^{\prime}_{bin}$')
    plt.colorbar(fraction=0.046)
    
    plt.tight_layout()
    plt.show()

# %% [markdown]
# #### Re-organize data

# %%
# data_train_trial shape (?, 128, 128, 3, 2)
train_x_y_hat0 = data_train_trial[..., 0]# xc
train_y_hat0 = data_train_trial[..., [0], 1] #c
train_x_hat0 = data_train_trial[..., 1:, 1] # x

print(train_x_y_hat0.shape)
print(train_y_hat0.shape)
print(train_x_hat0.shape)

eval_x_y_hat0 = data_eval_trial[..., 0]# xc
eval_y_hat0 = data_eval_trial[..., [0], 1] #c
eval_x_hat0 = data_eval_trial[..., 1:, 1] # x

print(eval_x_y_hat0.shape)
print(eval_y_hat0.shape)
print(eval_x_hat0.shape)

# eval_x_y_hat0, eval_y_hat0, eval_x_hat0
# Out:
# (7600, 128, 128, 3)
# (7600, 128, 128, 1)
# (7600, 128, 128, 2)
# (200, 128, 128, 3)
# (200, 128, 128, 1)
# (200, 128, 128, 2)

# %% [markdown]
# #### Train forward pass v-unet

# %%
input_shape = (128, 128, 3) # [S,p,w], the old saturation, pressure and well location
w_shape = (128, 128, 1) # [w'], the new well location and injection/production time
output_shape = (128, 128, 2) # [S', p'], the new saturation and pressure

# %% [markdown]
# reload if necessary

# %%
# from importlib import reload
# reload(vunet)
# Out:
# <module 'vunet_1' from '/data/cees/zjin/cs231n/project/var-unet/vunet_1.py'>

# %%
# change the role of enc_up and dec_up
# model specifications
n_res_block = 1
n_low_res = 6
n_scales = 5

enc_up, hidden_shapes = vunet.create_enc_up(input_shape, n_scales = n_scales)
enc_down = vunet.create_enc_down(hidden_shapes[-1])
dec_up = vunet.create_dec_up(w_shape, n_scales = n_scales) # only c input
dec_down = vunet.create_dec_down(hidden_shapes, hidden_shapes[-1], output_shape, n_scales = n_scales,  n_low_res = n_low_res)

# %%
# save inital weights
enc_up.save_weights(output_dir + 'enc_up_norm_init_' + case_string + '.h5' )
enc_down.save_weights(output_dir + 'enc_down_norm_init_' + case_string + '.h5' )
dec_up.save_weights(output_dir + 'dec_up_norm_init_' + case_string + '.h5' )
dec_down.save_weights(output_dir + 'dec_down_norm_init_' + case_string + '.h5' )

# %%
xc = Input(shape=input_shape) # perm + well location
c = Input(shape=w_shape) # well location

hs = enc_up(xc)
z_posterior_sample, z_posterior_mean = enc_down(hs[-1])
gs = dec_up(c)
x_hat, z_piror_sample, z_piror_mean = dec_down([z_posterior_mean, *gs])

# %%
def likelihood_loss(x, x_hat):
    '''
    Reconstruction loss, L2 norm
    '''
    
    v = 0.1
    return K.mean(K.sum((K.batch_flatten(x) - K.batch_flatten(x_hat)) ** 2 / (2*v), axis=-1))

def bce_loss(x, x_hat, s_cut=0.1):
    '''
    binary cross entropy loss, for saturation
    
    x shape: (?, 128, 128, 2)
    s_cut: saturation threshold: 0.1
    '''
    
    _, nx, ny, _ = x.shape

    sat = K.reshape(x[..., 0], (-1, nx*ny)) # shape (?, 128x128)
    sat_hat = K.reshape(x_hat[..., 0], (-1, nx*ny))
    
#     print(sat.shape)
    
    sat_bin = K.cast(K.greater_equal(sat, s_cut), dtype=K.floatx()) # greater_equal() returns boolean values, 
    sat_hat_bin = K.cast(K.greater_equal(sat_hat, s_cut), dtype=K.floatx()) # K.cast converts boolean to (0, 1)
    binary_loss = losses.binary_crossentropy(sat_bin, sat_hat_bin)
    
#     print(binary_loss.shape)
    
    return K.mean(binary_loss)

def flux_loss():
    pass

def latent_kl_loss(q, p):
    mean1 = q
    mean2 = p
    
    kl = 0.5 * (mean2 - mean1)**2
    kl = K.sum(kl, axis = [1,2,3])
    kl = K.mean(kl)
    return kl

# %%
x = Input(shape=output_shape) # target saturation, pressure

likelihood_ls = likelihood_loss(x, x_hat)

bce_ls = bce_loss(x, x_hat, sat_threshold)
kl_ls = latent_kl_loss(z_posterior_mean, z_piror_mean)

kl_weight = 5.0
bce_weight = 20.0

total_loss = likelihood_ls+ kl_weight * kl_ls + bce_weight* bce_ls

# %% [markdown]
# ## Re-train start here

# %%
epoch = 12
learning_rate = 2e-4 # default 1e-3
decay = 5e-5 # default 1e-5
train_nr = data_train_trial.shape[0]
eval_nr = data_eval_trial.shape[0]

print('train_nr: ', train_nr)
print('eval_nr: ', eval_nr)

batch_size = 16
num_batch = int(train_nr/batch_size) 

print('num_batch: ', num_batch)
# Out:
# train_nr:  7600
# eval_nr:  200
# num_batch:  475

# %%
# in case of re-training, load initial weights
enc_up.load_weights(output_dir + 'enc_up_norm_init_' + case_string + '.h5')
enc_down.load_weights(output_dir + 'enc_down_norm_init_' + case_string + '.h5')
dec_up.load_weights(output_dir + 'dec_up_norm_init_' + case_string + '.h5')
dec_down.load_weights(output_dir + 'dec_down_norm_init_' + case_string + '.h5')

# %%
opt = Adam(lr=learning_rate, decay=decay)

trainable_weights = enc_up.trainable_weights + enc_down.trainable_weights + dec_up.trainable_weights + dec_down.trainable_weights

updates = opt.get_updates(total_loss, trainable_weights)

iterate = K.function([xc, c, x], [total_loss, likelihood_ls, kl_weight*kl_ls, bce_weight*bce_ls], updates=updates)

eval_loss = K.function([xc, c, x], [total_loss])

# %%
## used to generate log directory
currentDT = datetime.datetime.now()
current_time = str(currentDT).replace(" ", "-")[:-10]
print(current_time)
# Out:
# 2019-06-03-10:32

# %%
## log for tensorboard
case_suffix = 'fix_perm'

def write_summary(value, tag, summary_writer, global_step):
    """
    Write a single summary value to tensorboard
    """
    summary = tf.Summary()
    summary.value.add(tag=tag, simple_value=value)
    summary_writer.add_summary(summary, global_step)

    
summary_writer = tf.summary.FileWriter('logs/' + model_string + '_norm_lr%.0e_ep%d_'%(learning_rate, epoch)  + current_time + '_' + case_suffix)

# %%
for e in range(epoch):
    for ib in range(num_batch):
        ind0 = ib * batch_size
        n_itr = e * train_nr + ind0 + batch_size # for tensorboard output
        
        x_y_hat0_batch = train_x_y_hat0[ind0:ind0+batch_size, ...] #xc
        y_hat0_batch = train_y_hat0[ind0:ind0+batch_size, ...] # c: shape
        x_hat0_batch = train_x_hat0[ind0:ind0+batch_size, ...] # x
        
        train_losses = iterate([x_y_hat0_batch, y_hat0_batch, x_hat0_batch])
        ## -- K.function()
        ## -- Equivalent to:
        # train_losses = tf.session.run(feed_dict={xc: x_y_hat0_batch, c: y_hat0_batch, x: x_hat0_batch}, ...
        #                               fetches= [total_loss, likelihood_loss_value, kl_loss])
        # But output tensor for the updates operation is not returned.
        # For session.run(), the fetches should include a 'update' tensor, 
        # which is a tf operator that updates weights for each iteration.
        # Specifically, the 'update' tensor is defined as:
        # ---------------------------------
        # params = tf.trainable_variables()
        # gradients = tf.gradients(loss, params)
        # opt = tf.train.AdamOptimizer(learning_rate=FLAGS.learning_rate)
        # update = opt.apply_gradients(zip(gradients, params), global_step=global_step)
        # ---------------------------------
        # session.run() is with tf, and does not require Keras
        # K.function is a Keras API, which is more convient

        if ib % 100 == 0:
            print('Epoch %d/%d, Batch %d/%d, Total Loss %f, Likelihood Loss %f, KL Loss %f BCE Loss %f' % (e+1, epoch, ib+1, num_batch, train_losses[0], train_losses[1], train_losses[2], train_losses[3]))
            write_summary(train_losses[0], 'train_loss', summary_writer, n_itr) # log for tensorboard
    
    eval_losses = eval_loss([eval_x_y_hat0, eval_y_hat0, eval_x_hat0])    
    write_summary(eval_losses[0], 'eval_loss', summary_writer, n_itr) # log for tensorboard
        

    print('====================================================')
    print('\n')
    print('Epoch %d/%d, Train Total Loss %f, Eval Total Loss %f' % (e + 1, epoch, train_losses[0], eval_losses[0]))
    print('\n')
    print('====================================================')

    
enc_up.save_weights(output_dir + 'enc_up_norm_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
enc_down.save_weights(output_dir + 'enc_down_norm_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
dec_up.save_weights(output_dir + 'dec_up_norm_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
dec_down.save_weights(output_dir + 'dec_down_norm_' + case_string + '_%dtrain_lr%.0e_ep%d.h5' % (train_nr, learning_rate, epoch))
# Out:
# Epoch 1/10, Batch 1/475, Total Loss 13991.000000, Likelihood Loss 13840.532227, KL Loss 13.186447 BCE Loss 137.281235
# Epoch 1/10, Batch 101/475, Total Loss 2382.890381, Likelihood Loss 2189.310547, KL Loss 3.358620 BCE Loss 190.221100
# Epoch 1/10, Batch 201/475, Total Loss 1808.978882, Likelihood Loss 1722.230591, KL Loss 1.650614 BCE Loss 85.097672
# Epoch 1/10, Batch 301/475, Total Loss 1087.118408, Likelihood Loss 1022.381653, KL Loss 3.713098 BCE Loss 61.023651
# Epoch 1/10, Batch 401/475, Total Loss 1190.932129, Likelihood Loss 1122.181152, KL Loss 4.427030 BCE Loss 64.323944
# ====================================================
#
#
# Epoch 1/10, Train Total Loss 1064.855713, Eval Total Loss 1082.748169
#
#
# ====================================================
# Epoch 2/10, Batch 1/475, Total Loss 1056.807861, Likelihood Loss 992.727539, KL Loss 4.594399 BCE Loss 59.485886
# Epoch 2/10, Batch 101/475, Total Loss 617.969238, Likelihood Loss 577.494995, KL Loss 2.804009 BCE Loss 37.670208
# Epoch 2/10, Batch 201/475, Total Loss 833.820496, Likelihood Loss 780.169189, KL Loss 5.789056 BCE Loss 47.862247
# Epoch 2/10, Batch 301/475, Total Loss 631.874390, Likelihood Loss 588.099976, KL Loss 4.701777 BCE Loss 39.072651
# Epoch 2/10, Batch 401/475, Total Loss 634.446167, Likelihood Loss 589.995178, KL Loss 5.356063 BCE Loss 39.094933
# ====================================================
#
#
# Epoch 2/10, Train Total Loss 578.264282, Eval Total Loss 556.469421
#
#
# ====================================================
# Epoch 3/10, Batch 1/475, Total Loss 554.139099, Likelihood Loss 514.084229, KL Loss 4.890020 BCE Loss 35.164833
# Epoch 3/10, Batch 101/475, Total Loss 401.943817, Likelihood Loss 371.663879, KL Loss 3.236496 BCE Loss 27.043419
# Epoch 3/10, Batch 201/475, Total Loss 474.315887, Likelihood Loss 437.986328, KL Loss 4.635506 BCE Loss 31.694054
# Epoch 3/10, Batch 301/475, Total Loss 454.405182, Likelihood Loss 422.631897, KL Loss 4.194988 BCE Loss 27.578304
# Epoch 3/10, Batch 401/475, Total Loss 479.717499, Likelihood Loss 444.369263, KL Loss 4.716630 BCE Loss 30.631582
# ====================================================
#
#
# Epoch 3/10, Train Total Loss 424.976471, Eval Total Loss 433.617828
#
#
# ====================================================
# Epoch 4/10, Batch 1/475, Total Loss 404.558899, Likelihood Loss 372.762207, KL Loss 4.473377 BCE Loss 27.323303
# Epoch 4/10, Batch 101/475, Total Loss 340.526520, Likelihood Loss 314.498779, KL Loss 3.288911 BCE Loss 22.738817
# Epoch 4/10, Batch 201/475, Total Loss 381.395782, Likelihood Loss 350.544434, KL Loss 4.425912 BCE Loss 26.425442
# Epoch 4/10, Batch 301/475, Total Loss 357.697968, Likelihood Loss 331.464294, KL Loss 4.087545 BCE Loss 22.146107
# Epoch 4/10, Batch 401/475, Total Loss 400.668365, Likelihood Loss 369.427765, KL Loss 4.703887 BCE Loss 26.536709
# ====================================================
#
#
# Epoch 4/10, Train Total Loss 346.940857, Eval Total Loss 387.230164
#
#
# ====================================================
# Epoch 5/10, Batch 1/475, Total Loss 335.921295, Likelihood Loss 307.906647, KL Loss 4.501994 BCE Loss 23.512671
# Epoch 5/10, Batch 101/475, Total Loss 276.667145, Likelihood Loss 253.760254, KL Loss 3.425591 BCE Loss 19.481295
# Epoch 5/10, Batch 201/475, Total Loss 324.639709, Likelihood Loss 296.171570, KL Loss 4.865333 BCE Loss 23.602825
# Epoch 5/10, Batch 301/475, Total Loss 322.270721, Likelihood Loss 297.224823, KL Loss 4.346233 BCE Loss 20.699669
# Epoch 5/10, Batch 401/475, Total Loss 302.872406, Likelihood Loss 275.342621, KL Loss 5.008792 BCE Loss 22.520985
# ====================================================
#
#
# Epoch 5/10, Train Total Loss 298.612091, Eval Total Loss 337.974030
#
#
# ====================================================
# Epoch 6/10, Batch 1/475, Total Loss 285.671143, Likelihood Loss 260.893829, KL Loss 4.915634 BCE Loss 19.861681
# Epoch 6/10, Batch 101/475, Total Loss 242.545349, Likelihood Loss 221.804123, KL Loss 3.734298 BCE Loss 17.006927
# Epoch 6/10, Batch 201/475, Total Loss 359.850494, Likelihood Loss 328.111633, KL Loss 5.553471 BCE Loss 26.185390
# Epoch 6/10, Batch 301/475, Total Loss 304.267548, Likelihood Loss 278.212036, KL Loss 4.963569 BCE Loss 21.091938
# Epoch 6/10, Batch 401/475, Total Loss 310.846252, Likelihood Loss 282.854248, KL Loss 5.575953 BCE Loss 22.416039
# ====================================================
#
#
# Epoch 6/10, Train Total Loss 321.251678, Eval Total Loss 338.893433
#
#
# ====================================================
# Epoch 7/10, Batch 1/475, Total Loss 290.705475, Likelihood Loss 264.302124, KL Loss 5.646187 BCE Loss 20.757181
# Epoch 7/10, Batch 101/475, Total Loss 221.873947, Likelihood Loss 201.548615, KL Loss 4.191593 BCE Loss 16.133743
# Epoch 7/10, Batch 201/475, Total Loss 280.794708, Likelihood Loss 253.179596, KL Loss 5.842051 BCE Loss 21.773064
# Epoch 7/10, Batch 301/475, Total Loss 256.726685, Likelihood Loss 231.125473, KL Loss 5.516903 BCE Loss 20.084314
# Epoch 7/10, Batch 401/475, Total Loss 253.941223, Likelihood Loss 228.234192, KL Loss 5.814572 BCE Loss 19.892454
# ====================================================
#
#
# Epoch 7/10, Train Total Loss 247.866730, Eval Total Loss 320.295197
#
#
# ====================================================
# Epoch 8/10, Batch 1/475, Total Loss 252.948822, Likelihood Loss 228.145874, KL Loss 5.914984 BCE Loss 18.887978
# Epoch 8/10, Batch 101/475, Total Loss 172.001465, Likelihood Loss 153.689880, KL Loss 4.279314 BCE Loss 14.032269
# Epoch 8/10, Batch 201/475, Total Loss 230.566010, Likelihood Loss 206.721130, KL Loss 5.707640 BCE Loss 18.137239
# Epoch 8/10, Batch 301/475, Total Loss 215.126266, Likelihood Loss 194.500977, KL Loss 5.264965 BCE Loss 15.360316
# Epoch 8/10, Batch 401/475, Total Loss 210.138885, Likelihood Loss 186.556473, KL Loss 6.030104 BCE Loss 17.552303
# ====================================================
#
#
# Epoch 8/10, Train Total Loss 255.080521, Eval Total Loss 283.054413
#
#
# ====================================================
# Epoch 9/10, Batch 1/475, Total Loss 217.218277, Likelihood Loss 193.646454, KL Loss 6.121504 BCE Loss 17.450314
# Epoch 9/10, Batch 101/475, Total Loss 158.410889, Likelihood Loss 140.827011, KL Loss 4.384565 BCE Loss 13.199306
# Epoch 9/10, Batch 201/475, Total Loss 198.017288, Likelihood Loss 175.581116, KL Loss 5.805969 BCE Loss 16.630203
# Epoch 9/10, Batch 301/475, Total Loss 246.276016, Likelihood Loss 225.707214, KL Loss 5.450614 BCE Loss 15.118200
# Epoch 9/10, Batch 401/475, Total Loss 257.494568, Likelihood Loss 233.606750, KL Loss 5.862404 BCE Loss 18.025436
# ====================================================
#
#
# Epoch 9/10, Train Total Loss 240.845963, Eval Total Loss 271.204376
#
#
# ====================================================
# Epoch 10/10, Batch 1/475, Total Loss 215.827271, Likelihood Loss 191.881180, KL Loss 6.441078 BCE Loss 17.504999
# Epoch 10/10, Batch 101/475, Total Loss 168.376770, Likelihood Loss 150.388290, KL Loss 4.720078 BCE Loss 13.268394
# Epoch 10/10, Batch 201/475, Total Loss 208.228409, Likelihood Loss 185.843567, KL Loss 6.309218 BCE Loss 16.075623
# Epoch 10/10, Batch 301/475, Total Loss 210.460495, Likelihood Loss 188.440094, KL Loss 5.938094 BCE Loss 16.082302
# Epoch 10/10, Batch 401/475, Total Loss 181.657730, Likelihood Loss 159.199066, KL Loss 6.648888 BCE Loss 15.809770
# ====================================================
#
#
# Epoch 10/10, Train Total Loss 201.850235, Eval Total Loss 276.419342
#
#
# ====================================================
